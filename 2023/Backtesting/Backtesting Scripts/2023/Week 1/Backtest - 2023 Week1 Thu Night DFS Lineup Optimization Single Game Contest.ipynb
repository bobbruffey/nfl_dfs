# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def single_game_player_df(week, year, day, file_name,
                         #qb_file, rb_file, wr_file,
                         #te_file, def_file,
                         team1,
                         team2):

    fanduel = pd.read_csv(file_name)
    fanduel = fanduel[fanduel['keep']=='x']
    fanduel = fanduel[(fanduel['Injury Indicator'] != 'IR') &
                  (fanduel['Injury Indicator'] != 'O') &
                  (fanduel['Injury Indicator'] != 'D')]
    fanduel2 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel2 = fanduel2[fanduel2['Position'] != 'D']
    fanduel2['player_wk_year'] = fanduel2['Nickname'] + " " + week + " " + year

    fanduel3 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel3 = fanduel3[fanduel3['Position'] == 'D']
    fanduel3['player_wk_year'] = fanduel3['Team'] + " " + week + " " + year

    fanduel4 = fanduel2.append(fanduel3)
    fanduel4 = fanduel4[['Player ID + Player Name', 'Position', 
                     'Team','Salary', 'Injury Indicator',
                    'player_wk_year','FPPG','Tier']]
    #fanduel4.sort_values(by = 'Salary', ascending = False)

    fanduel4['pos_rank'] = fanduel4.groupby(['Team','Position'])['Salary'].rank(ascending = False).astype(int)
    fanduel4['pos_rank'] = fanduel4['Position'] + fanduel4['pos_rank'].astype(str)

    fanduel5 = fanduel4[fanduel4['pos_rank'].isin(['QB1','RB1','RB2','RB3','WR1',
                                               'WR2','WR3','WR4','WR5',
                                              'TE1','TE2','TE3','D1','K1'])]

#     qb_df = pd.read_csv(qb_file)
#     qb_df['position'] = 'qb'
#     rb_df = pd.read_csv(rb_file)
#     rb_df['position'] = 'rb'
#     wr_df = pd.read_csv(wr_file)
#     wr_df['position'] = 'wr'
#     te_df = pd.read_csv(te_file)
#     te_df['position'] = 'te'
#     def_df = pd.read_csv(def_file)
#     def_df['position'] = 'def'
#     def_df = def_df.rename(columns = {'team_wk_year':'player_wk_year'})

#     df = qb_df.append(rb_df)
#     df = df.append(wr_df)
#     df = df.append(te_df)
#     df = df.append(def_df)

#     df = df.reset_index()
#     df = df.drop(columns = ['Unnamed: 0', 'index'])

#     df = df[(df['team_wk_year'].str.contains(team1)) |
#             (df['team_wk_year'].str.contains(team2))]
#     df_final = pd.merge(fanduel5, df, how = 'left', 
#                     on = 'player_wk_year', suffixes = (None, None))

    #df_final['Prob2'] = df_final[['FPPG', 'Prob']].mean(skipna=True, axis = 1)
    #df_final['Prob2'] = df_final['FPPG']
    df_final = fanduel5
    df_final['Prob2'] = df_final['Tier']
    df_final = df_final.drop_duplicates(subset = 'player_wk_year', keep = 'last')
    df_final = df_final.sort_values(by = 'Prob2', ascending = False)

    return df_final

# %%
#team1 = fav
#team2 = underdog
df_final = single_game_player_df(week = '1',
                        year = '2023',
                        day = 'THu',
                        file_name = 'C:/Users/bobbr/OneDrive/Documents/The Plan/NFL/2023/Week 1/2023_week1_thu_night_players.csv',
#                         qb_file = 'week9_scored_qb.csv',
#                         rb_file = 'week9_scored_rb.csv',
#                         wr_file = 'week9_scored_wr.csv',
#                         te_file = 'week9_scored_te.csv',
#                         def_file = 'week9_scored_def.csv',
                        team1 = 'KC',
                        team2 = 'DET')

# %%
df_final = df_final[['Player ID + Player Name','Position', 'Team', 'Salary',
                    'player_wk_year','Prob2','Tier']]#,'FPPG','Prob']]

# %%
df_final
# Out:
#                  Player ID + Player Name Position Team  Salary  \
# 0            92766-57439:Patrick Mahomes       QB   KC   18000
# 3          92766-86997:Amon-Ra St. Brown       WR  DET   13500
# 1                 92766-38435:Jared Goff       QB  DET   15500
# 4           92766-73273:David Montgomery       RB  DET   13000
# 5              92766-92575:Isiah Pacheco       RB   KC   11500
# 6              92766-129368:Jahmyr Gibbs       RB  DET   11000
# 7           92766-22103:Marvin Jones Jr.       WR  DET   10500
# 8   92766-40647:Marquez Valdes-Scantling       WR   KC   10000
# 9             92766-86052:Kadarius Toney       WR   KC    9500
# 10           92766-41642:Harrison Butker        K   KC    9500
# 11           92766-54608:Jerick McKinnon       RB   KC    9000
# 13           92766-90949:Riley Patterson        K  DET    8500
# 12        92766-12536:Kansas City Chiefs        D   KC    9000
# 20              92766-105646:Sam LaPorta       TE  DET    6500
# 28                 92766-93143:Noah Gray       TE   KC    5500
# 15             92766-53097:Josh Reynolds       WR  DET    8000
# 14               92766-112062:Skyy Moore       WR   KC    8000
# 19              92766-111311:Rashee Rice       WR   KC    7000
# 18             92766-70422:Kalif Raymond       WR  DET    7000
# 21          92766-53498:Richie James Jr.       WR   KC    6500
# 27              92766-91046:Brock Wright       TE  DET    5500
# 16     92766-85741:Clyde Edwards-Helaire       RB   KC    7500
# 35                92766-27403:Blake Bell       TE   KC    5000
# 17             92766-12532:Detroit Lions        D  DET    7500
# 52             92766-93531:Antoine Green       WR  DET    5000
# 59            92766-85986:James Mitchell       TE  DET    5000
# 61           92766-104424:Craig Reynolds       RB  DET    5000
#
#                      player_wk_year  Prob2  Tier
# 0            Patrick Mahomes 1 2023    5.0   5.0
# 3          Amon-Ra St. Brown 1 2023    5.0   5.0
# 1                 Jared Goff 1 2023    5.0   5.0
# 4           David Montgomery 1 2023    4.0   4.0
# 5              Isiah Pacheco 1 2023    4.0   4.0
# 6               Jahmyr Gibbs 1 2023    4.0   4.0
# 7           Marvin Jones Jr. 1 2023    3.0   3.0
# 8   Marquez Valdes-Scantling 1 2023    3.0   3.0
# 9             Kadarius Toney 1 2023    3.0   3.0
# 10           Harrison Butker 1 2023    3.0   3.0
# 11           Jerick McKinnon 1 2023    3.0   3.0
# 13           Riley Patterson 1 2023    3.0   3.0
# 12                        KC 1 2023    3.0   3.0
# 20               Sam LaPorta 1 2023    2.0   2.0
# 28                 Noah Gray 1 2023    2.0   2.0
# 15             Josh Reynolds 1 2023    2.0   2.0
# 14                Skyy Moore 1 2023    2.0   2.0
# 19               Rashee Rice 1 2023    1.0   1.0
# 18             Kalif Raymond 1 2023    1.0   1.0
# 21          Richie James Jr. 1 2023    1.0   1.0
# 27              Brock Wright 1 2023    1.0   1.0
# 16     Clyde Edwards-Helaire 1 2023    1.0   1.0
# 35                Blake Bell 1 2023    1.0   1.0
# 17                       DET 1 2023    1.0   1.0
# 52             Antoine Green 1 2023    0.0   0.0
# 59            James Mitchell 1 2023    0.0   0.0
# 61            Craig Reynolds 1 2023    0.0   0.0

# %%
def create_single_game_simulations(df_final, team1, team2, 
                                   team1_pos, team2_pos
                                  # outcomes
                                  ):#,
                                 # players1, players2,
                                 # players3, players4):
    print('team1:')
    print(team1)
    print('team2:')
    print(team2)
    result = pd.DataFrame() 
    team1_df = df_final[df_final['Team'] == team1]
    team1_df['pos_rank'] = team1_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team1_df['pos_rank'] = team1_df['Position'] + team1_df['pos_rank'].astype(str)
    team2_df = df_final[df_final['Team'] == team2]
    team2_df['pos_rank'] = team2_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team2_df['pos_rank'] = team2_df['Position'] + team2_df['pos_rank'].astype(str)
    
    
    #outcomes = ['HL',
    #            'HM',
    #            'HH',
    #            'ML',
    #            'MM',
    #            'MH'#,
                #'LL',
                #'LM',
                #'LH'
     #          ]
    
    #for outcome in outcomes:
    #    print(outcome)
    #    if (outcome == 'HL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','QB1','RB1','WR1'])]
    #    elif (outcome == 'HM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'TE1','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','K1'])]
    #    elif (outcome == 'HH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'WR4','WR5','TE1','TE2','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3','TE1'
    #                                                    ])]
    #    elif (outcome == 'ML'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','K1'])]
    #    elif (outcome == 'MM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','TE1',
    #                                                        'WR3','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2'])]
    #    elif (outcome == 'MH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','TE1','WR1','WR2',
    #                                                       'WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3'])]
    #    elif (outcome == 'LL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #    elif (outcome == 'LM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #    elif (outcome == 'LH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1','TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1', 'TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
 
    team1_df2 = team1_df[team1_df['pos_rank'].isin(team1_pos)]
    team2_df2 = team2_df[team2_df['pos_rank'].isin(team2_pos)]
    
    team1_team2 = team1_df2.append(team2_df2)
    df_final_qb = team1_team2.sort_values('Prob2',ascending= False)
    df1 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df1 = df1.rename(columns = {'Player ID + Player Name':'flex1',
                                             'Salary':'flex1_sal','Prob2':'flex1_prob'})
    df2 = df_final_qb[['Player ID + Player Name', 'Team','Salary', 'Prob2']]
    df2 = df2.rename(columns = {'Player ID + Player Name':'flex2',
                                             'Salary':'flex2_sal','Prob2':'flex2_prob'})
    df3 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df3 = df3.rename(columns = {'Player ID + Player Name':'flex3',
                                            'Salary':'flex3_sal','Prob2':'flex3_prob'})
    df4 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df4 = df4.rename(columns = {'Player ID + Player Name':'flex4',
                                             'Salary':'flex4_sal','Prob2':'flex4_prob'})
    df5 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df5 = df5.rename(columns = {'Player ID + Player Name':'flex5',
                                             'Salary':'flex5_sal','Prob2':'flex5_prob'})

    sim_df = pd.merge(df1, df2, how = 'cross')
    sim_df = pd.merge(sim_df, df3, how = 'cross')
    sim_df = pd.merge(sim_df, df4, how = 'cross')
    sim_df = pd.merge(sim_df, df5, how = 'cross')
        
        
    sim_df = sim_df[(sim_df['flex1'] != sim_df['flex2']) & (sim_df['flex1'] != sim_df['flex3']) &
                (sim_df['flex1'] != sim_df['flex4']) & (sim_df['flex1'] != sim_df['flex5']) &
                (sim_df['flex2'] != sim_df['flex3']) & (sim_df['flex2'] != sim_df['flex4']) &
                (sim_df['flex2'] != sim_df['flex5']) & (sim_df['flex3'] != sim_df['flex4']) &
                (sim_df['flex3'] != sim_df['flex5']) & (sim_df['flex4'] != sim_df['flex5'])]

    sim_df['total_salary'] = sim_df['flex1_sal'] + sim_df['flex2_sal'] + sim_df['flex3_sal'] + sim_df['flex4_sal'] + sim_df['flex5_sal']
    sim_df['total_proj'] = sim_df['flex1_prob'] + sim_df['flex2_prob'] + sim_df['flex3_prob'] + sim_df['flex4_prob'] + sim_df['flex5_prob']

    sim_df = sim_df[sim_df['total_salary'] <= 60000]
    sim_df = sim_df[sim_df['total_salary'] > 57000]
    #if (len(sim_df) == 0):
    #    continue

    final= sim_df[['flex1', 'flex2', 'flex3', 'flex4', 'flex5','total_proj']]
    final['total_proj'] = final['total_proj'].astype(str)
        #final['total_salary'] = final['total_salary'].astype(str)
    print(len(final))
    n = len(final)
       # if (len(final) < 10000):
       #     n = len(final)
       # else:
       #     n = 10000
    final2 = pd.DataFrame()
    for i in range(0,n):
          #  print(i)
        l = final.iloc[i,:].values.tolist()
            #print(l)
        l.sort()
           # if ((players1 in l) |
           #     (players2 in l) |
           #    (players3 in l) |
           #     (players4 in l)
           #    ):
               # print(l)
        temp = pd.DataFrame([l])
            
        final2 = final2.append(temp)
            
    final2 = final2.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
        
    df_team_check = df_final_qb[['Player ID + Player Name','Team']]
        
    for i in range(1,6):
        print(i)
        final2 = pd.merge(final2, df_team_check, how = 'inner', left_on = i,
                          right_on = 'Player ID + Player Name',
                          suffixes = (None,None))
        team_col = 'Team' + str(i)
        final2[team_col] = final2['Team']
        final2 = final2.drop(columns = ['Team','Player ID + Player Name'])
    keep_list = []
    team1_v_team2 = []
    for i in range(0,len(final2)):
        team1_count = 0
        team2_count = 0
            #keep_list = []
        teams = final2[['Team1','Team2','Team3','Team4','Team5']]
        l = teams.iloc[i,:].values.tolist()
            #print(l)
        for j in l:
             #   print(j)
                
            if (j == team1):
                team1_count = team1_count + 1
            elif (j == team2):
                team2_count = team2_count + 1
             #   print(team1_count)
             #   print(team2_count)
        if ((team1_count > 4) | (team2_count > 4)):
            keep = 'No'
        else:
            keep = 'Yes'
                
        if ((team1_count == 2) & (team2_count == 3)):
            team1_team2 = '2:3'
        elif ((team1_count == 3) & (team2_count == 2)):
            team1_team2 = '3:2'
        elif ((team1_count == 4) & (team2_count == 1)):
            team1_team2 = '4:1'
        elif ((team1_count == 1) & (team2_count == 4)):
            team1_team2 = '1:4'
        else:
            team1_team2 = 'none'
                
          #  print(keep)
        keep_list.append(keep)
        team1_v_team2.append(team1_team2)
            #print(keep_list)
    final2['keep'] = keep_list
    final2['team1_team2_count'] = team1_v_team2
               
       # if(len(final2) < 33):
       #     m = len(final2)
       # else: 
       #     m = 33
       # final2 = final2.head(m)
    result = result.append(final2)
    
    result = result[result['keep'] == 'Yes']
    #result = result[[0,1,2,3,4,5]]
    result = result.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

    
    return result

# %%
#fav: KC
#spread: -4
#o/u: 52.5
#team1 =favorite
#team2 =underdog

test = create_single_game_simulations(df_final = df_final,
                                      team1 = 'KC',
                                      team2 = 'DET',
                                      team1_pos = ['QB1','RB1','RB2','RB3','TE1','TE2',
                                                  'WR1','WR2','WR3','WR4','WR5',
                                                   'K1','D1'],
                                      team2_pos = ['QB1','RB1','RB2','TE1','TE2',
                                                   'WR1','WR2','WR3',
                                                   'K1','D1'])
                                      #outcomes = ['LH']#,
                                   #  players1 = '81393-22015:Russell Wilson',
                                   #  players2 = '81393-69213:Michael Pittman Jr.',
                                   #  players3 = '81393-6616:Matt Ryan',
                                  # #  players4 = "81556-85701:Ja'Marr Chase"
                                   #  )
# Out:
# team1:
# KC
# team2:
# DET
# 156720
# 1
# 2
# 3
# 4
# 5

# %%
test.shape
# Out:
# (1284, 13)

# %%
test = test.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

# %%
test.sort_values(0, ascending = False).head(50)
# Out:
#          0                               1  \
# 702   21.0       92766-129368:Jahmyr Gibbs
# 590   20.0  92766-12536:Kansas City Chiefs
# 104   20.0       92766-129368:Jahmyr Gibbs
# 861   20.0          92766-38435:Jared Goff
# 184   20.0       92766-129368:Jahmyr Gibbs
# 714   20.0       92766-129368:Jahmyr Gibbs
# 510   20.0        92766-105646:Sam LaPorta
# 219   20.0       92766-129368:Jahmyr Gibbs
# 586   20.0       92766-129368:Jahmyr Gibbs
# 222   20.0       92766-129368:Jahmyr Gibbs
# 808   20.0  92766-12536:Kansas City Chiefs
# 583   20.0       92766-129368:Jahmyr Gibbs
# 225   20.0       92766-129368:Jahmyr Gibbs
# 495   20.0       92766-129368:Jahmyr Gibbs
# 581   20.0       92766-129368:Jahmyr Gibbs
# 111   20.0  92766-12536:Kansas City Chiefs
# 844   20.0  92766-12536:Kansas City Chiefs
# 715   20.0          92766-38435:Jared Goff
# 563   20.0          92766-38435:Jared Goff
# 713   20.0          92766-38435:Jared Goff
# 596   20.0          92766-38435:Jared Goff
# 711   20.0          92766-38435:Jared Goff
# 106   20.0       92766-129368:Jahmyr Gibbs
# 518   20.0  92766-12536:Kansas City Chiefs
# 575   20.0  92766-12536:Kansas City Chiefs
# 576   20.0        92766-105646:Sam LaPorta
# 703   20.0  92766-12536:Kansas City Chiefs
# 578   20.0       92766-129368:Jahmyr Gibbs
# 712   20.0          92766-38435:Jared Goff
# 509   20.0         92766-112062:Skyy Moore
# 164   20.0  92766-12536:Kansas City Chiefs
# 704   20.0    92766-22103:Marvin Jones Jr.
# 1059  20.0       92766-129368:Jahmyr Gibbs
# 851   20.0          92766-38435:Jared Goff
# 99    20.0       92766-129368:Jahmyr Gibbs
# 852   20.0       92766-129368:Jahmyr Gibbs
# 281   20.0  92766-12536:Kansas City Chiefs
# 95    20.0       92766-129368:Jahmyr Gibbs
# 1065  20.0          92766-38435:Jared Goff
# 97    20.0       92766-129368:Jahmyr Gibbs
# 684   20.0       92766-129368:Jahmyr Gibbs
# 600   20.0       92766-129368:Jahmyr Gibbs
# 599   20.0          92766-38435:Jared Goff
# 452   20.0  92766-12536:Kansas City Chiefs
# 1020  20.0       92766-129368:Jahmyr Gibbs
# 598   20.0          92766-38435:Jared Goff
# 103   20.0  92766-12536:Kansas City Chiefs
# 849   20.0          92766-38435:Jared Goff
# 94    20.0  92766-12536:Kansas City Chiefs
# 820   20.0       92766-129368:Jahmyr Gibbs
#
#                                          2  \
# 702                 92766-38435:Jared Goff
# 590                 92766-38435:Jared Goff
# 104           92766-22103:Marvin Jones Jr.
# 861           92766-73273:David Montgomery
# 184           92766-22103:Marvin Jones Jr.
# 714           92766-73273:David Montgomery
# 510              92766-129368:Jahmyr Gibbs
# 219                 92766-38435:Jared Goff
# 586   92766-40647:Marquez Valdes-Scantling
# 222                 92766-38435:Jared Goff
# 808              92766-129368:Jahmyr Gibbs
# 583            92766-41642:Harrison Butker
# 225                 92766-38435:Jared Goff
# 495                 92766-38435:Jared Goff
# 581            92766-54608:Jerick McKinnon
# 111              92766-129368:Jahmyr Gibbs
# 844                 92766-38435:Jared Goff
# 715             92766-86052:Kadarius Toney
# 563   92766-40647:Marquez Valdes-Scantling
# 713   92766-40647:Marquez Valdes-Scantling
# 596            92766-54608:Jerick McKinnon
# 711            92766-54608:Jerick McKinnon
# 106                 92766-38435:Jared Goff
# 518           92766-22103:Marvin Jones Jr.
# 575              92766-129368:Jahmyr Gibbs
# 576                 92766-38435:Jared Goff
# 703                 92766-38435:Jared Goff
# 578           92766-22103:Marvin Jones Jr.
# 712            92766-41642:Harrison Butker
# 509              92766-129368:Jahmyr Gibbs
# 164                 92766-38435:Jared Goff
# 704                 92766-38435:Jared Goff
# 1059           92766-57439:Patrick Mahomes
# 851            92766-41642:Harrison Butker
# 99                  92766-38435:Jared Goff
# 852                 92766-38435:Jared Goff
# 281              92766-129368:Jahmyr Gibbs
# 95            92766-22103:Marvin Jones Jr.
# 1065          92766-73273:David Montgomery
# 97                  92766-38435:Jared Goff
# 684                 92766-38435:Jared Goff
# 600           92766-73273:David Montgomery
# 599   92766-40647:Marquez Valdes-Scantling
# 452              92766-129368:Jahmyr Gibbs
# 1020                92766-38435:Jared Goff
# 598            92766-41642:Harrison Butker
# 103              92766-129368:Jahmyr Gibbs
# 849            92766-54608:Jerick McKinnon
# 94               92766-129368:Jahmyr Gibbs
# 820            92766-54608:Jerick McKinnon
#
#                                          3  \
# 702          92766-86997:Amon-Ra St. Brown
# 590             92766-86052:Kadarius Toney
# 104                 92766-38435:Jared Goff
# 861             92766-86052:Kadarius Toney
# 184                 92766-38435:Jared Goff
# 714          92766-86997:Amon-Ra St. Brown
# 510                 92766-38435:Jared Goff
# 219   92766-40647:Marquez Valdes-Scantling
# 586           92766-73273:David Montgomery
# 222            92766-54608:Jerick McKinnon
# 808                 92766-38435:Jared Goff
# 583           92766-73273:David Montgomery
# 225            92766-41642:Harrison Butker
# 495            92766-54608:Jerick McKinnon
# 581           92766-73273:David Montgomery
# 111                 92766-38435:Jared Goff
# 844           92766-73273:David Montgomery
# 715          92766-86997:Amon-Ra St. Brown
# 563            92766-54608:Jerick McKinnon
# 713          92766-86997:Amon-Ra St. Brown
# 596             92766-86052:Kadarius Toney
# 711          92766-86997:Amon-Ra St. Brown
# 106   92766-40647:Marquez Valdes-Scantling
# 518                 92766-38435:Jared Goff
# 575           92766-73273:David Montgomery
# 576           92766-73273:David Montgomery
# 703          92766-86997:Amon-Ra St. Brown
# 578           92766-73273:David Montgomery
# 712          92766-86997:Amon-Ra St. Brown
# 509                 92766-38435:Jared Goff
# 164            92766-54608:Jerick McKinnon
# 704          92766-86997:Amon-Ra St. Brown
# 1059         92766-86997:Amon-Ra St. Brown
# 851           92766-73273:David Montgomery
# 99             92766-41642:Harrison Butker
# 852             92766-86052:Kadarius Toney
# 281           92766-22103:Marvin Jones Jr.
# 95                  92766-38435:Jared Goff
# 1065         92766-86997:Amon-Ra St. Brown
# 97    92766-40647:Marquez Valdes-Scantling
# 684           92766-73273:David Montgomery
# 600             92766-86052:Kadarius Toney
# 599             92766-86052:Kadarius Toney
# 452                 92766-38435:Jared Goff
# 1020          92766-73273:David Montgomery
# 598             92766-86052:Kadarius Toney
# 103                 92766-38435:Jared Goff
# 849           92766-73273:David Montgomery
# 94                  92766-38435:Jared Goff
# 820            92766-57439:Patrick Mahomes
#
#                                          4                              5  \
# 702            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 590          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 104            92766-41642:Harrison Butker  92766-86997:Amon-Ra St. Brown
# 861          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 184             92766-86052:Kadarius Toney  92766-86997:Amon-Ra St. Brown
# 714            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 510          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 219             92766-86052:Kadarius Toney  92766-86997:Amon-Ra St. Brown
# 586          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 222             92766-86052:Kadarius Toney  92766-86997:Amon-Ra St. Brown
# 808          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 583          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 225             92766-86052:Kadarius Toney  92766-86997:Amon-Ra St. Brown
# 495           92766-73273:David Montgomery      92766-92575:Isiah Pacheco
# 581          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 111   92766-40647:Marquez Valdes-Scantling  92766-86997:Amon-Ra St. Brown
# 844          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 715            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 563          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 713            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 596          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 711            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 106            92766-41642:Harrison Butker  92766-86997:Amon-Ra St. Brown
# 518          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 575          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 576          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 703            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 578          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 712            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 509          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 164           92766-73273:David Montgomery  92766-86997:Amon-Ra St. Brown
# 704            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 1059             92766-92575:Isiah Pacheco          92766-93143:Noah Gray
# 851          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 99             92766-54608:Jerick McKinnon  92766-86997:Amon-Ra St. Brown
# 852          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 281                 92766-38435:Jared Goff  92766-86997:Amon-Ra St. Brown
# 95             92766-54608:Jerick McKinnon  92766-86997:Amon-Ra St. Brown
# 1065             92766-92575:Isiah Pacheco          92766-93143:Noah Gray
# 97             92766-54608:Jerick McKinnon  92766-86997:Amon-Ra St. Brown
# 684            92766-90949:Riley Patterson      92766-92575:Isiah Pacheco
# 600          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 599          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 452           92766-73273:David Montgomery      92766-92575:Isiah Pacheco
# 1020         92766-86997:Amon-Ra St. Brown          92766-93143:Noah Gray
# 598          92766-86997:Amon-Ra St. Brown      92766-92575:Isiah Pacheco
# 103            92766-41642:Harrison Butker  92766-86997:Amon-Ra St. Brown
# 849          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
# 94             92766-54608:Jerick McKinnon  92766-86997:Amon-Ra St. Brown
# 820          92766-86997:Amon-Ra St. Brown    92766-90949:Riley Patterson
#
#      Team1 Team2 Team3 Team4 Team5 keep team1_team2_count
# 702    DET   DET   DET   DET    KC  Yes               1:4
# 590     KC   DET    KC   DET    KC  Yes               3:2
# 104    DET   DET   DET    KC   DET  Yes               1:4
# 861    DET   DET    KC   DET   DET  Yes               1:4
# 184    DET   DET   DET    KC   DET  Yes               1:4
# 714    DET   DET   DET   DET    KC  Yes               1:4
# 510    DET   DET   DET   DET    KC  Yes               1:4
# 219    DET   DET    KC    KC   DET  Yes               2:3
# 586    DET    KC   DET   DET    KC  Yes               2:3
# 222    DET   DET    KC    KC   DET  Yes               2:3
# 808     KC   DET   DET   DET   DET  Yes               1:4
# 583    DET    KC   DET   DET    KC  Yes               2:3
# 225    DET   DET    KC    KC   DET  Yes               2:3
# 495    DET   DET    KC   DET    KC  Yes               2:3
# 581    DET    KC   DET   DET    KC  Yes               2:3
# 111     KC   DET   DET    KC   DET  Yes               2:3
# 844     KC   DET   DET   DET   DET  Yes               1:4
# 715    DET    KC   DET   DET    KC  Yes               2:3
# 563    DET    KC    KC   DET    KC  Yes               3:2
# 713    DET    KC   DET   DET    KC  Yes               2:3
# 596    DET    KC    KC   DET    KC  Yes               3:2
# 711    DET    KC   DET   DET    KC  Yes               2:3
# 106    DET   DET    KC    KC   DET  Yes               2:3
# 518     KC   DET   DET   DET    KC  Yes               2:3
# 575     KC   DET   DET   DET    KC  Yes               2:3
# 576    DET   DET   DET   DET    KC  Yes               1:4
# 703     KC   DET   DET   DET    KC  Yes               2:3
# 578    DET   DET   DET   DET    KC  Yes               1:4
# 712    DET    KC   DET   DET    KC  Yes               2:3
# 509     KC   DET   DET   DET    KC  Yes               2:3
# 164     KC   DET    KC   DET   DET  Yes               2:3
# 704    DET   DET   DET   DET    KC  Yes               1:4
# 1059   DET    KC   DET    KC    KC  Yes               3:2
# 851    DET    KC   DET   DET   DET  Yes               1:4
# 99     DET   DET    KC    KC   DET  Yes               2:3
# 852    DET   DET    KC   DET   DET  Yes               1:4
# 281     KC   DET   DET   DET   DET  Yes               1:4
# 95     DET   DET   DET    KC   DET  Yes               1:4
# 1065   DET   DET   DET    KC    KC  Yes               2:3
# 97     DET   DET    KC    KC   DET  Yes               2:3
# 684    DET   DET   DET   DET    KC  Yes               1:4
# 600    DET   DET    KC   DET    KC  Yes               2:3
# 599    DET    KC    KC   DET    KC  Yes               3:2
# 452     KC   DET   DET   DET    KC  Yes               2:3
# 1020   DET   DET   DET   DET    KC  Yes               1:4
# 598    DET    KC    KC   DET    KC  Yes               3:2
# 103     KC   DET   DET    KC   DET  Yes               2:3
# 849    DET    KC   DET   DET   DET  Yes               1:4
# 94      KC   DET   DET    KC   DET  Yes               2:3
# 820    DET    KC    KC   DET   DET  Yes               2:3

# %%
#vegas odds:
#fav: KC
#spread: -3.5
#o/u: 52.5

# %%
#team1 = BUF, so as heavy fav we will subset only 4:1 and 3:2
#fav should always get a '4:1'
team_ratio = ['4:1','3:2','2:3'] #'1:4']

# %%
test = test.sort_values(0, ascending = False)#.head(150)
test2 = test[test['team1_team2_count'].isin(team_ratio)]

# %%
test2#.to_csv('thu_night_wk13_lineups_test.csv')
# Out:
#          0                               1  \
# 590   20.0  92766-12536:Kansas City Chiefs
# 219   20.0       92766-129368:Jahmyr Gibbs
# 586   20.0       92766-129368:Jahmyr Gibbs
# 222   20.0       92766-129368:Jahmyr Gibbs
# 583   20.0       92766-129368:Jahmyr Gibbs
# ...    ...                             ...
# 1140  15.0        92766-111311:Rashee Rice
# 893   15.0        92766-111311:Rashee Rice
# 975   15.0        92766-111311:Rashee Rice
# 976   15.0       92766-12532:Detroit Lions
# 1137  15.0       92766-12532:Detroit Lions
#
#                                          2  \
# 590                 92766-38435:Jared Goff
# 219                 92766-38435:Jared Goff
# 586   92766-40647:Marquez Valdes-Scantling
# 222                 92766-38435:Jared Goff
# 583            92766-41642:Harrison Butker
# ...                                    ...
# 1140          92766-22103:Marvin Jones Jr.
# 893              92766-12532:Detroit Lions
# 975                 92766-38435:Jared Goff
# 976                 92766-38435:Jared Goff
# 1137        92766-12536:Kansas City Chiefs
#
#                                          3                                  4  \
# 590             92766-86052:Kadarius Toney      92766-86997:Amon-Ra St. Brown
# 219   92766-40647:Marquez Valdes-Scantling         92766-86052:Kadarius Toney
# 586           92766-73273:David Montgomery      92766-86997:Amon-Ra St. Brown
# 222            92766-54608:Jerick McKinnon         92766-86052:Kadarius Toney
# 583           92766-73273:David Montgomery      92766-86997:Amon-Ra St. Brown
# ...                                    ...                                ...
# 1140                92766-38435:Jared Goff        92766-57439:Patrick Mahomes
# 893                 92766-38435:Jared Goff        92766-57439:Patrick Mahomes
# 975            92766-57439:Patrick Mahomes  92766-85741:Clyde Edwards-Helaire
# 976            92766-57439:Patrick Mahomes  92766-85741:Clyde Edwards-Helaire
# 1137                92766-38435:Jared Goff        92766-57439:Patrick Mahomes
#
#                                       5 Team1 Team2 Team3 Team4 Team5 keep  \
# 590           92766-92575:Isiah Pacheco    KC   DET    KC   DET    KC  Yes
# 219       92766-86997:Amon-Ra St. Brown   DET   DET    KC    KC   DET  Yes
# 586           92766-92575:Isiah Pacheco   DET    KC   DET   DET    KC  Yes
# 222       92766-86997:Amon-Ra St. Brown   DET   DET    KC    KC   DET  Yes
# 583           92766-92575:Isiah Pacheco   DET    KC   DET   DET    KC  Yes
# ...                                 ...   ...   ...   ...   ...   ...  ...
# 1140  92766-85741:Clyde Edwards-Helaire    KC   DET   DET    KC    KC  Yes
# 893          92766-86052:Kadarius Toney    KC   DET   DET    KC    KC  Yes
# 975          92766-86052:Kadarius Toney    KC   DET    KC    KC    KC  Yes
# 976          92766-86052:Kadarius Toney   DET   DET    KC    KC    KC  Yes
# 1137  92766-85741:Clyde Edwards-Helaire   DET    KC   DET    KC    KC  Yes
#
#      team1_team2_count
# 590                3:2
# 219                2:3
# 586                2:3
# 222                2:3
# 583                2:3
# ...                ...
# 1140               3:2
# 893                3:2
# 975                4:1
# 976                3:2
# 1137               3:2
#
# [1151 rows x 13 columns]

# %%
df_final
# Out:
#                  Player ID + Player Name Position Team  Salary  \
# 0            92766-57439:Patrick Mahomes       QB   KC   18000
# 3          92766-86997:Amon-Ra St. Brown       WR  DET   13500
# 1                 92766-38435:Jared Goff       QB  DET   15500
# 4           92766-73273:David Montgomery       RB  DET   13000
# 5              92766-92575:Isiah Pacheco       RB   KC   11500
# 6              92766-129368:Jahmyr Gibbs       RB  DET   11000
# 7           92766-22103:Marvin Jones Jr.       WR  DET   10500
# 8   92766-40647:Marquez Valdes-Scantling       WR   KC   10000
# 9             92766-86052:Kadarius Toney       WR   KC    9500
# 10           92766-41642:Harrison Butker        K   KC    9500
# 11           92766-54608:Jerick McKinnon       RB   KC    9000
# 13           92766-90949:Riley Patterson        K  DET    8500
# 12        92766-12536:Kansas City Chiefs        D   KC    9000
# 20              92766-105646:Sam LaPorta       TE  DET    6500
# 28                 92766-93143:Noah Gray       TE   KC    5500
# 15             92766-53097:Josh Reynolds       WR  DET    8000
# 14               92766-112062:Skyy Moore       WR   KC    8000
# 19              92766-111311:Rashee Rice       WR   KC    7000
# 18             92766-70422:Kalif Raymond       WR  DET    7000
# 21          92766-53498:Richie James Jr.       WR   KC    6500
# 27              92766-91046:Brock Wright       TE  DET    5500
# 16     92766-85741:Clyde Edwards-Helaire       RB   KC    7500
# 35                92766-27403:Blake Bell       TE   KC    5000
# 17             92766-12532:Detroit Lions        D  DET    7500
# 52             92766-93531:Antoine Green       WR  DET    5000
# 59            92766-85986:James Mitchell       TE  DET    5000
# 61           92766-104424:Craig Reynolds       RB  DET    5000
#
#                      player_wk_year  Prob2  Tier
# 0            Patrick Mahomes 1 2023    5.0   5.0
# 3          Amon-Ra St. Brown 1 2023    5.0   5.0
# 1                 Jared Goff 1 2023    5.0   5.0
# 4           David Montgomery 1 2023    4.0   4.0
# 5              Isiah Pacheco 1 2023    4.0   4.0
# 6               Jahmyr Gibbs 1 2023    4.0   4.0
# 7           Marvin Jones Jr. 1 2023    3.0   3.0
# 8   Marquez Valdes-Scantling 1 2023    3.0   3.0
# 9             Kadarius Toney 1 2023    3.0   3.0
# 10           Harrison Butker 1 2023    3.0   3.0
# 11           Jerick McKinnon 1 2023    3.0   3.0
# 13           Riley Patterson 1 2023    3.0   3.0
# 12                        KC 1 2023    3.0   3.0
# 20               Sam LaPorta 1 2023    2.0   2.0
# 28                 Noah Gray 1 2023    2.0   2.0
# 15             Josh Reynolds 1 2023    2.0   2.0
# 14                Skyy Moore 1 2023    2.0   2.0
# 19               Rashee Rice 1 2023    1.0   1.0
# 18             Kalif Raymond 1 2023    1.0   1.0
# 21          Richie James Jr. 1 2023    1.0   1.0
# 27              Brock Wright 1 2023    1.0   1.0
# 16     Clyde Edwards-Helaire 1 2023    1.0   1.0
# 35                Blake Bell 1 2023    1.0   1.0
# 17                       DET 1 2023    1.0   1.0
# 52             Antoine Green 1 2023    0.0   0.0
# 59            James Mitchell 1 2023    0.0   0.0
# 61            Craig Reynolds 1 2023    0.0   0.0

# %%
def create_mvp_lineups(test_df,
                       df_final,
                       team_ratios,
                      counts,
                      mvps):

    test_df = pd.DataFrame()
    team1_team2 = team_ratios #['4:1','4:1','4:1' ,'4:1', '3:2','3:2','3:2','3:2']
    count = counts #[40,20,10,5,40,20,10,15]
    mvp = mvps #['84053-62239:Josh Allen','84053-25079:Stefon Diggs', '84053-12526:Buffalo Bills','84053-6642:Nick Folk',
      #'84053-62239:Josh Allen','84053-25079:Stefon Diggs',
      #'84053-111540:Rhamondre Stevenson','84053-90584:Mac Jones']
    n = len(team1_team2)

    for z in range(0,n):
    
        teams = team1_team2[z]
        counts = count[z]
        mvps_filter = mvp[z]
        print(teams)
        test_new = test2[test2['team1_team2_count'] == teams]#.head(counts)
        print(len(test_new))
        #x = 0
       # while(x < counts):
        j = 0
        for pos in range(0,len(test_new)):
        #j = 0
        #pos = 0
        #while ((j <= counts) or (pos < len(test_new)) ):
        
            df_final_mvp = df_final['Player ID + Player Name'][df_final['Player ID + Player Name'].isin([mvps_filter])].values.tolist()
            df_final_1 = df_final['Player ID + Player Name'].values.tolist()
            df_final_2 = df_final['Player ID + Player Name'].values.tolist()
            df_final_3 = df_final['Player ID + Player Name'].values.tolist()
            df_final_4 = df_final['Player ID + Player Name'].values.tolist()

            l = test_new.iloc[pos, :].values.tolist()


            l_mvp = []
            l_1 = []
            l_2 = []
            l_3 = []
            l_4 = []

            for i in range(1,6):
               # print(l[i])
                if ((l[i] in df_final_mvp) & (len(l_mvp) < 1)):
                    l_mvp = l[i]
                    df_final_mvp.remove(l[i])
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])

                elif ((l[i] in (df_final_1)) & (len(l_1) < 1)):
                    l_1 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                    
                elif ((l[i] in (df_final_2)) & (len(l_2) < 1)):
                    l_2 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_3)) & (len(l_3) < 1)):
                    l_3 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_4)) & (len(l_4) < 1)):
                    l_4 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
            
            final_l = [l_mvp, l_1, l_2, l_3, l_4]
            final_l = pd.DataFrame([final_l])
            if (len(l_mvp) > 2):
               # pos = pos + 1
                j = j + 1
            else:
              #  pos = pos + 1
                j = j
           # print(pos)
            #print(final_l)
            test_df = test_df.append(final_l)
            test_df = test_df[test_df[0].str.len() > 2]
            if (j == counts):
                break

            
    return test_df

# %%
df_final
# Out:
#                  Player ID + Player Name Position Team  Salary  \
# 0            92766-57439:Patrick Mahomes       QB   KC   18000
# 3          92766-86997:Amon-Ra St. Brown       WR  DET   13500
# 1                 92766-38435:Jared Goff       QB  DET   15500
# 4           92766-73273:David Montgomery       RB  DET   13000
# 5              92766-92575:Isiah Pacheco       RB   KC   11500
# 6              92766-129368:Jahmyr Gibbs       RB  DET   11000
# 7           92766-22103:Marvin Jones Jr.       WR  DET   10500
# 8   92766-40647:Marquez Valdes-Scantling       WR   KC   10000
# 9             92766-86052:Kadarius Toney       WR   KC    9500
# 10           92766-41642:Harrison Butker        K   KC    9500
# 11           92766-54608:Jerick McKinnon       RB   KC    9000
# 13           92766-90949:Riley Patterson        K  DET    8500
# 12        92766-12536:Kansas City Chiefs        D   KC    9000
# 20              92766-105646:Sam LaPorta       TE  DET    6500
# 28                 92766-93143:Noah Gray       TE   KC    5500
# 15             92766-53097:Josh Reynolds       WR  DET    8000
# 14               92766-112062:Skyy Moore       WR   KC    8000
# 19              92766-111311:Rashee Rice       WR   KC    7000
# 18             92766-70422:Kalif Raymond       WR  DET    7000
# 21          92766-53498:Richie James Jr.       WR   KC    6500
# 27              92766-91046:Brock Wright       TE  DET    5500
# 16     92766-85741:Clyde Edwards-Helaire       RB   KC    7500
# 35                92766-27403:Blake Bell       TE   KC    5000
# 17             92766-12532:Detroit Lions        D  DET    7500
# 52             92766-93531:Antoine Green       WR  DET    5000
# 59            92766-85986:James Mitchell       TE  DET    5000
# 61           92766-104424:Craig Reynolds       RB  DET    5000
#
#                      player_wk_year  Prob2  Tier
# 0            Patrick Mahomes 1 2023    5.0   5.0
# 3          Amon-Ra St. Brown 1 2023    5.0   5.0
# 1                 Jared Goff 1 2023    5.0   5.0
# 4           David Montgomery 1 2023    4.0   4.0
# 5              Isiah Pacheco 1 2023    4.0   4.0
# 6               Jahmyr Gibbs 1 2023    4.0   4.0
# 7           Marvin Jones Jr. 1 2023    3.0   3.0
# 8   Marquez Valdes-Scantling 1 2023    3.0   3.0
# 9             Kadarius Toney 1 2023    3.0   3.0
# 10           Harrison Butker 1 2023    3.0   3.0
# 11           Jerick McKinnon 1 2023    3.0   3.0
# 13           Riley Patterson 1 2023    3.0   3.0
# 12                        KC 1 2023    3.0   3.0
# 20               Sam LaPorta 1 2023    2.0   2.0
# 28                 Noah Gray 1 2023    2.0   2.0
# 15             Josh Reynolds 1 2023    2.0   2.0
# 14                Skyy Moore 1 2023    2.0   2.0
# 19               Rashee Rice 1 2023    1.0   1.0
# 18             Kalif Raymond 1 2023    1.0   1.0
# 21          Richie James Jr. 1 2023    1.0   1.0
# 27              Brock Wright 1 2023    1.0   1.0
# 16     Clyde Edwards-Helaire 1 2023    1.0   1.0
# 35                Blake Bell 1 2023    1.0   1.0
# 17                       DET 1 2023    1.0   1.0
# 52             Antoine Green 1 2023    0.0   0.0
# 59            James Mitchell 1 2023    0.0   0.0
# 61            Craig Reynolds 1 2023    0.0   0.0

# %%
team_ratios = [
               '4:1','4:1',#'4:1','4:1','4:1','4:1','4:1',
    
                '3:2','3:2',#'3:2','3:2','3:2','3:2','3:2'
    
               '2:3','2:3','2:3','2:3'#,#'2:3',#'2:3'#,
    
              # '1:4','1:4','1:4','1:4'#,'1:4'
    
               
              ]
counts = [
    
    50,20,
    80,30,
    50,30,20,20
    
         ]
   
mvps = [
    '92766-57439:Patrick Mahomes',
    '92766-92575:Isiah Pacheco',

    '92766-57439:Patrick Mahomes',
    '92766-92575:Isiah Pacheco',
    
    '92766-38435:Jared Goff',
    '92766-86997:Amon-Ra St. Brown','92766-73273:David Montgomery',
    '92766-129368:Jahmyr Gibbs'
    
       ]


test_df = create_mvp_lineups(test_df = test2,
                       df_final = df_final,
                       team_ratios = team_ratios,
                      counts = counts,
                      mvps = mvps)
# Out:
# 4:1
# 238
# 4:1
# 238
# 3:2
# 501
# 3:2
# 501
# 2:3
# 412
# 2:3
# 412
# 2:3
# 412
# 2:3
# 412

# %%
test_df
# Out:
#                               0                                     1  \
# 0   92766-57439:Patrick Mahomes        92766-12536:Kansas City Chiefs
# 0   92766-57439:Patrick Mahomes        92766-12536:Kansas City Chiefs
# 0   92766-57439:Patrick Mahomes  92766-40647:Marquez Valdes-Scantling
# 0   92766-57439:Patrick Mahomes        92766-12536:Kansas City Chiefs
# 0   92766-57439:Patrick Mahomes        92766-12536:Kansas City Chiefs
# ..                          ...                                   ...
# 0     92766-129368:Jahmyr Gibbs        92766-12536:Kansas City Chiefs
# 0     92766-129368:Jahmyr Gibbs        92766-12536:Kansas City Chiefs
# 0     92766-129368:Jahmyr Gibbs           92766-54608:Jerick McKinnon
# 0     92766-129368:Jahmyr Gibbs        92766-12536:Kansas City Chiefs
# 0     92766-129368:Jahmyr Gibbs        92766-12536:Kansas City Chiefs
#
#                                        2                              3  \
# 0   92766-40647:Marquez Valdes-Scantling    92766-41642:Harrison Butker
# 0   92766-40647:Marquez Valdes-Scantling    92766-54608:Jerick McKinnon
# 0            92766-41642:Harrison Butker    92766-54608:Jerick McKinnon
# 0            92766-41642:Harrison Butker    92766-54608:Jerick McKinnon
# 0              92766-129368:Jahmyr Gibbs    92766-54608:Jerick McKinnon
# ..                                   ...                            ...
# 0                 92766-38435:Jared Goff    92766-41642:Harrison Butker
# 0                 92766-38435:Jared Goff    92766-54608:Jerick McKinnon
# 0            92766-57439:Patrick Mahomes  92766-86997:Amon-Ra St. Brown
# 0                 92766-38435:Jared Goff     92766-86052:Kadarius Toney
# 0            92766-57439:Patrick Mahomes  92766-86997:Amon-Ra St. Brown
#
#                                 4
# 0   92766-86997:Amon-Ra St. Brown
# 0   92766-86997:Amon-Ra St. Brown
# 0   92766-86997:Amon-Ra St. Brown
# 0   92766-86997:Amon-Ra St. Brown
# 0       92766-92575:Isiah Pacheco
# ..                            ...
# 0   92766-86997:Amon-Ra St. Brown
# 0   92766-86997:Amon-Ra St. Brown
# 0     92766-90949:Riley Patterson
# 0   92766-86997:Amon-Ra St. Brown
# 0     92766-90949:Riley Patterson
#
# [300 rows x 5 columns]

# %%
#test_df.to_csv('backtest_wk9_thu_phi_hou_predicted_lineups.csv')
test_df.to_csv('Backtest_2023_wk1_thu_kc_det_predicted_lineups.csv')

# %%
# if (len(test_df) < 150):
#     n = len(test_df)
# else:
#     n = len(test_df)
# test_df.head(n).to_csv('week11_gb_ten_test.csv')
