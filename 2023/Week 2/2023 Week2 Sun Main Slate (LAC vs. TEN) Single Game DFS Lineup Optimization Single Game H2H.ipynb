# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def single_game_player_df(week, year, day, file_name,
                         #qb_file, rb_file, wr_file,
                         #te_file, def_file,
                         team1,
                         team2):

    
    fanduel = pd.read_csv(file_name)
    fanduel = fanduel[fanduel['keep']=='x']
    fanduel = fanduel[(fanduel['Injury Indicator'] != 'IR') &
                  (fanduel['Injury Indicator'] != 'O') &
                  (fanduel['Injury Indicator'] != 'D')]
    fanduel2 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel2 = fanduel2[fanduel2['Position'] != 'D']
    fanduel2['player_wk_year'] = fanduel2['Nickname'] + " " + week + " " + year

    fanduel3 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel3 = fanduel3[fanduel3['Position'] == 'D']
    fanduel3['player_wk_year'] = fanduel3['Team'] + " " + week + " " + year

    fanduel4 = fanduel2.append(fanduel3)
    fanduel4 = fanduel4[['Player ID + Player Name', 'Position', 
                     'Team','Salary', 'Injury Indicator',
                    'player_wk_year','FPPG','Tier']]
    #fanduel4.sort_values(by = 'Salary', ascending = False)

    fanduel4['pos_rank'] = fanduel4.groupby(['Team','Position'])['Salary'].rank(ascending = False).astype(int)
    fanduel4['pos_rank'] = fanduel4['Position'] + fanduel4['pos_rank'].astype(str)

    fanduel5 = fanduel4[fanduel4['pos_rank'].isin(['QB1','RB1','RB2','RB3','WR1',
                                               'WR2','WR3','WR4','WR5',
                                              'TE1','TE2','TE3','D1','K1'])]

#     qb_df = pd.read_csv(qb_file)
#     qb_df['position'] = 'qb'
#     rb_df = pd.read_csv(rb_file)
#     rb_df['position'] = 'rb'
#     wr_df = pd.read_csv(wr_file)
#     wr_df['position'] = 'wr'
#     te_df = pd.read_csv(te_file)
#     te_df['position'] = 'te'
#     def_df = pd.read_csv(def_file)
#     def_df['position'] = 'def'
#     def_df = def_df.rename(columns = {'team_wk_year':'player_wk_year'})

#     df = qb_df.append(rb_df)
#     df = df.append(wr_df)
#     df = df.append(te_df)
#     df = df.append(def_df)

#     df = df.reset_index()
#     df = df.drop(columns = ['Unnamed: 0', 'index'])

#     df = df[(df['team_wk_year'].str.contains(team1)) |
#             (df['team_wk_year'].str.contains(team2))]
#     df_final = pd.merge(fanduel5, df, how = 'left', 
#                     on = 'player_wk_year', suffixes = (None, None))

    #df_final['Prob2'] = df_final[['FPPG', 'Prob']].mean(skipna=True, axis = 1)
    #df_final['Prob2'] = df_final['FPPG']
    df_final = fanduel5
    df_final['Prob2'] = df_final['Tier']
    df_final = df_final.drop_duplicates(subset = 'player_wk_year', keep = 'last')
    df_final = df_final.sort_values(by = 'Prob2', ascending = False)

    return df_final

# %%
#team1 = fav
#team2 = underdog
df_final = single_game_player_df(week = '2',
                        year = '2023',
                        day = 'Sun',
                        file_name = '2023_week2_sun_main_single_game_players.csv',
#                         qb_file = 'week9_scored_qb.csv',
#                         rb_file = 'week9_scored_rb.csv',
#                         wr_file = 'week9_scored_wr.csv',
#                         te_file = 'week9_scored_te.csv',
#                         def_file = 'week9_scored_def.csv',
                        team1 = 'LAC',
                        team2 = 'TEN')

df_final = df_final[(df_final['Team'] == 'LAC') |
                     (df_final['Team'] == 'TEN')]

# %%
df_final = df_final[['Player ID + Player Name','Position', 'Team', 'Salary',
                    'player_wk_year','Prob2','Tier']]#,'FPPG','Prob']]

# %%
df_final
# Out:
#               Player ID + Player Name Position Team  Salary  \
# 1           93784-39280:Derrick Henry       RB  TEN   15000
# 2          93784-69189:Justin Herbert       QB  LAC   16000
# 23                          Nick Folk        K  TEN    9000
# 25          93784-91872:Joshua Kelley       RB  LAC   11000
# 74       93784-12534:Tennessee Titans        D  TEN    8500
# 22                     Cameron Dicker        K  LAC    9000
# 13        93784-16606:DeAndre Hopkins       WR  TEN   13000
# 16          93784-39829:Mike Williams       WR  LAC   12000
# 5            93784-29253:Keenan Allen       WR  LAC   12500
# 21         93784-21948:Ryan Tannehill       QB  TEN   14000
# 63     93784-104278:Donald Parham Jr.       TE  LAC    7000
# 70   93784-12548:Los Angeles Chargers        D  LAC    8500
# 35         93784-57299:Gerald Everett       TE  LAC    9500
# 36  93784-64389:Nick Westbrook-Ikhine       WR  TEN    9500
# 38         93784-110259:Treylon Burks       WR  TEN   10000
# 58          93784-107293:Tyjae Spears       RB  TEN    7500
# 57           93784-88297:Chig Okonkwo       TE  TEN    7500
# 55          93784-87418:Joshua Palmer       WR  LAC    8000
# 73         93784-185878:Elijah Dotson       RB  LAC    5000
# 46      93784-120639:Quentin Johnston       WR  LAC    8000
#
#                   player_wk_year  Prob2  Tier
# 1           Derrick Henry 2 2023    5.0   5.0
# 2          Justin Herbert 2 2023    5.0   5.0
# 23              Nick Folk 2 2023    4.0   4.0
# 25          Joshua Kelley 2 2023    4.0   4.0
# 74                    TEN 2 2023    4.0   4.0
# 22         Cameron Dicker 2 2023    4.0   4.0
# 13        DeAndre Hopkins 2 2023    4.0   4.0
# 16          Mike Williams 2 2023    4.0   4.0
# 5            Keenan Allen 2 2023    4.0   4.0
# 21         Ryan Tannehill 2 2023    4.0   4.0
# 63      Donald Parham Jr. 2 2023    3.0   3.0
# 70                    LAC 2 2023    3.0   3.0
# 35         Gerald Everett 2 2023    3.0   3.0
# 36  Nick Westbrook-Ikhine 2 2023    3.0   3.0
# 38          Treylon Burks 2 2023    2.0   2.0
# 58           Tyjae Spears 2 2023    2.0   2.0
# 57           Chig Okonkwo 2 2023    2.0   2.0
# 55          Joshua Palmer 2 2023    2.0   2.0
# 73          Elijah Dotson 2 2023    1.0   1.0
# 46       Quentin Johnston 2 2023    1.0   1.0

# %%
def create_single_game_simulations(df_final, team1, team2, 
                                   team1_pos, team2_pos
                                  # outcomes
                                  ):#,
                                 # players1, players2,
                                 # players3, players4):
    print('team1:')
    print(team1)
    print('team2:')
    print(team2)
    result = pd.DataFrame() 
    team1_df = df_final[df_final['Team'] == team1]
    team1_df['pos_rank'] = team1_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team1_df['pos_rank'] = team1_df['Position'] + team1_df['pos_rank'].astype(str)
    team2_df = df_final[df_final['Team'] == team2]
    team2_df['pos_rank'] = team2_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team2_df['pos_rank'] = team2_df['Position'] + team2_df['pos_rank'].astype(str)
    
    
    #outcomes = ['HL',
    #            'HM',
    #            'HH',
    #            'ML',
    #            'MM',
    #            'MH'#,
                #'LL',
                #'LM',
                #'LH'
     #          ]
    
    #for outcome in outcomes:
    #    print(outcome)
    #    if (outcome == 'HL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','QB1','RB1','WR1'])]
    #    elif (outcome == 'HM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'TE1','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','K1'])]
    #    elif (outcome == 'HH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'WR4','WR5','TE1','TE2','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3','TE1'
    #                                                    ])]
    #    elif (outcome == 'ML'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','K1'])]
    #    elif (outcome == 'MM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','TE1',
    #                                                        'WR3','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2'])]
    #    elif (outcome == 'MH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','TE1','WR1','WR2',
    #                                                       'WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3'])]
    #    elif (outcome == 'LL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #    elif (outcome == 'LM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #    elif (outcome == 'LH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1','TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1', 'TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
 
    team1_df2 = team1_df[team1_df['pos_rank'].isin(team1_pos)]
    team2_df2 = team2_df[team2_df['pos_rank'].isin(team2_pos)]
    
    team1_team2 = team1_df2.append(team2_df2)
    df_final_qb = team1_team2.sort_values('Prob2',ascending= False)
    df1 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df1 = df1.rename(columns = {'Player ID + Player Name':'flex1',
                                             'Salary':'flex1_sal','Prob2':'flex1_prob'})
    df2 = df_final_qb[['Player ID + Player Name', 'Team','Salary', 'Prob2']]
    df2 = df2.rename(columns = {'Player ID + Player Name':'flex2',
                                             'Salary':'flex2_sal','Prob2':'flex2_prob'})
    df3 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df3 = df3.rename(columns = {'Player ID + Player Name':'flex3',
                                            'Salary':'flex3_sal','Prob2':'flex3_prob'})
    df4 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df4 = df4.rename(columns = {'Player ID + Player Name':'flex4',
                                             'Salary':'flex4_sal','Prob2':'flex4_prob'})
    df5 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df5 = df5.rename(columns = {'Player ID + Player Name':'flex5',
                                             'Salary':'flex5_sal','Prob2':'flex5_prob'})

    sim_df = pd.merge(df1, df2, how = 'cross')
    sim_df = pd.merge(sim_df, df3, how = 'cross')
    sim_df = pd.merge(sim_df, df4, how = 'cross')
    sim_df = pd.merge(sim_df, df5, how = 'cross')
        
        
    sim_df = sim_df[(sim_df['flex1'] != sim_df['flex2']) & (sim_df['flex1'] != sim_df['flex3']) &
                (sim_df['flex1'] != sim_df['flex4']) & (sim_df['flex1'] != sim_df['flex5']) &
                (sim_df['flex2'] != sim_df['flex3']) & (sim_df['flex2'] != sim_df['flex4']) &
                (sim_df['flex2'] != sim_df['flex5']) & (sim_df['flex3'] != sim_df['flex4']) &
                (sim_df['flex3'] != sim_df['flex5']) & (sim_df['flex4'] != sim_df['flex5'])]

    sim_df['total_salary'] = sim_df['flex1_sal'] + sim_df['flex2_sal'] + sim_df['flex3_sal'] + sim_df['flex4_sal'] + sim_df['flex5_sal']
    sim_df['total_proj'] = sim_df['flex1_prob'] + sim_df['flex2_prob'] + sim_df['flex3_prob'] + sim_df['flex4_prob'] + sim_df['flex5_prob']

    sim_df = sim_df[sim_df['total_salary'] <= 60000]
    sim_df = sim_df[sim_df['total_salary'] > 57000]
    #if (len(sim_df) == 0):
    #    continue

    final= sim_df[['flex1', 'flex2', 'flex3', 'flex4', 'flex5','total_proj']]
    final['total_proj'] = final['total_proj'].astype(str)
        #final['total_salary'] = final['total_salary'].astype(str)
    print(len(final))
    n = len(final)
       # if (len(final) < 10000):
       #     n = len(final)
       # else:
       #     n = 10000
    final2 = pd.DataFrame()
    for i in range(0,n):
          #  print(i)
        l = final.iloc[i,:].values.tolist()
            #print(l)
        l.sort()
           # if ((players1 in l) |
           #     (players2 in l) |
           #    (players3 in l) |
           #     (players4 in l)
           #    ):
               # print(l)
        temp = pd.DataFrame([l])
            
        final2 = final2.append(temp)
            
    final2 = final2.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
        
    df_team_check = df_final_qb[['Player ID + Player Name','Team']]
        
    for i in range(1,6):
        print(i)
        final2 = pd.merge(final2, df_team_check, how = 'inner', left_on = i,
                          right_on = 'Player ID + Player Name',
                          suffixes = (None,None))
        team_col = 'Team' + str(i)
        final2[team_col] = final2['Team']
        final2 = final2.drop(columns = ['Team','Player ID + Player Name'])
    keep_list = []
    team1_v_team2 = []
    for i in range(0,len(final2)):
        team1_count = 0
        team2_count = 0
            #keep_list = []
        teams = final2[['Team1','Team2','Team3','Team4','Team5']]
        l = teams.iloc[i,:].values.tolist()
            #print(l)
        for j in l:
             #   print(j)
                
            if (j == team1):
                team1_count = team1_count + 1
            elif (j == team2):
                team2_count = team2_count + 1
             #   print(team1_count)
             #   print(team2_count)
        if ((team1_count > 4) | (team2_count > 4)):
            keep = 'No'
        else:
            keep = 'Yes'
                
        if ((team1_count == 2) & (team2_count == 3)):
            team1_team2 = '2:3'
        elif ((team1_count == 3) & (team2_count == 2)):
            team1_team2 = '3:2'
        elif ((team1_count == 4) & (team2_count == 1)):
            team1_team2 = '4:1'
        elif ((team1_count == 1) & (team2_count == 4)):
            team1_team2 = '1:4'
        else:
            team1_team2 = 'none'
                
          #  print(keep)
        keep_list.append(keep)
        team1_v_team2.append(team1_team2)
            #print(keep_list)
    final2['keep'] = keep_list
    final2['team1_team2_count'] = team1_v_team2
               
       # if(len(final2) < 33):
       #     m = len(final2)
       # else: 
       #     m = 33
       # final2 = final2.head(m)
    result = result.append(final2)
    
    result = result[result['keep'] == 'Yes']
    #result = result[[0,1,2,3,4,5]]
    result = result.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

    
    return result

# %%
#fav: LAC
#spread: -2.5
#o/u: 45.5
#team1 =favorite
#team2 =underdog

test = create_single_game_simulations(df_final = df_final,
                                      team1 = 'LAC',
                                      team2 = 'TEN',
                                      team1_pos = ['QB1','RB1','RB2',
                                                   'TE1','TE2',
                                                  'WR1','WR2','WR3','WR4',
                                                   'K1','D1'],
                                      team2_pos = ['QB1','RB1','RB2',
                                                   'TE1',
                                                   'WR1','WR2','WR3',
                                                   'K1','D1'])
                                      #outcomes = ['LH']#,
                                   #  players1 = '81393-22015:Russell Wilson',
                                   #  players2 = '81393-69213:Michael Pittman Jr.',
                                   #  players3 = '81393-6616:Matt Ryan',
                                  # #  players4 = "81556-85701:Ja'Marr Chase"
                                   #  )
# Out:
# team1:
# LAC
# team2:
# TEN
# 128160
# 1
# 2
# 3
# 4
# 5

# %%
test.shape
# Out:
# (1043, 13)

# %%
test = test.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
test.to_csv('2023_week2_lac_ten_all_predicted_lineups.csv')

# %%
test.sort_values(0, ascending = False).head(50)
# Out:
#         0                                 1  \
# 307  22.0         93784-39280:Derrick Henry
# 294  22.0      93784-12534:Tennessee Titans
# 257  22.0      93784-12534:Tennessee Titans
# 86   22.0      93784-12534:Tennessee Titans
# 89   21.0      93784-12534:Tennessee Titans
# 292  21.0       93784-16606:DeAndre Hopkins
# 94    93784-91872:Joshua Kelley              Cameron Dicker   TEN   TEN   LAC
# 304              Cameron Dicker                   Nick Folk   TEN   LAC   LAC
# 306              Cameron Dicker                   Nick Folk   TEN   TEN   LAC
# 0    93784-69189:Justin Herbert              Cameron Dicker   LAC   TEN   LAC
# 112   93784-91872:Joshua Kelley              Cameron Dicker   TEN   TEN   TEN
# 87    93784-91872:Joshua Kelley              Cameron Dicker   LAC   TEN   LAC
# 308              Cameron Dicker                   Nick Folk   LAC   LAC   LAC
# 309              Cameron Dicker                   Nick Folk   TEN   LAC   LAC
# 83    93784-91872:Joshua Kelley              Cameron Dicker   LAC   TEN   LAC
# 310              Cameron Dicker                   Nick Folk   TEN   LAC   LAC
# 311              Cameron Dicker                   Nick Folk   TEN   LAC   TEN
# 312              Cameron Dicker                   Nick Folk   TEN   LAC   TEN
# 79    93784-91872:Joshua Kelley              Cameron Dicker   TEN   TEN   LAC
# 78    93784-91872:Joshua Kelley              Cameron Dicker   LAC   TEN   LAC
# 313              Cameron Dicker                   Nick Folk   TEN   TEN   TEN
# 720   93784-39280:Derrick Henry   93784-91872:Joshua Kelley   TEN   TEN   LAC
# 291              Cameron Dicker                   Nick Folk   LAC   TEN   LAC
# 283   93784-91872:Joshua Kelley                   Nick Folk   TEN   TEN   TEN
# 341   93784-39829:Mike Williams                   Nick Folk   TEN   TEN   TEN
# 168   93784-39280:Derrick Henry              Cameron Dicker   TEN   TEN   TEN
# 834   93784-39829:Mike Williams  93784-69189:Justin Herbert   LAC   TEN   TEN
# 200  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   LAC
# 189  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   TEN
# 186  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   LAC
# 208  93784-69189:Justin Herbert                   Nick Folk   LAC   LAC   TEN
# 840   93784-39829:Mike Williams  93784-69189:Justin Herbert   TEN   LAC   TEN
# 180  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   LAC
# 211  93784-69189:Justin Herbert                   Nick Folk   LAC   TEN   TEN
# 175  93784-69189:Justin Herbert                   Nick Folk   TEN   LAC   LAC
# 221  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   LAC
# 171  93784-69189:Justin Herbert                   Nick Folk   LAC   TEN   LAC
# 226  93784-69189:Justin Herbert                   Nick Folk   TEN   TEN   LAC
# 265   93784-91872:Joshua Kelley                   Nick Folk   TEN   TEN   LAC
# 163   93784-39280:Derrick Henry              Cameron Dicker   TEN   TEN   LAC
# 874   93784-39280:Derrick Henry  93784-69189:Justin Herbert   LAC   TEN   LAC
# 157   93784-39280:Derrick Henry              Cameron Dicker   TEN   TEN   LAC
# 151   93784-39829:Mike Williams              Cameron Dicker   TEN   TEN   TEN
# 146   93784-39829:Mike Williams              Cameron Dicker   TEN   TEN   TEN
#
#     Team4 Team5 keep team1_team2_count
# 307   LAC   TEN  Yes               3:2
# 294   LAC   TEN  Yes               2:3
# 257   LAC   TEN  Yes               2:3
# 86    LAC   LAC  Yes               3:2
# 89    LAC   LAC  Yes               3:2
# 292   LAC   TEN  Yes               2:3
# 293   LAC   TEN  Yes               2:3
# 295   LAC   TEN  Yes               3:2
# 297   LAC   TEN  Yes               3:2
# 299   LAC   TEN  Yes               4:1
# 301   LAC   TEN  Yes               3:2
# 302   LAC   TEN  Yes               2:3
# 94    LAC   LAC  Yes               3:2
# 304   LAC   TEN  Yes               3:2
# 306   LAC   TEN  Yes               2:3
# 0     LAC   LAC  Yes               4:1
# 112   LAC   LAC  Yes               2:3
# 87    LAC   LAC  Yes               4:1
# 308   LAC   TEN  Yes               4:1
# 309   LAC   TEN  Yes               3:2
# 83    LAC   LAC  Yes               4:1
# 310   LAC   TEN  Yes               3:2
# 311   LAC   TEN  Yes               2:3
# 312   LAC   TEN  Yes               2:3
# 79    LAC   LAC  Yes               3:2
# 78    LAC   LAC  Yes               4:1
# 313   LAC   TEN  Yes               1:4
# 720   TEN   LAC  Yes               2:3
# 291   LAC   TEN  Yes               3:2
# 283   LAC   TEN  Yes               1:4
# 341   LAC   TEN  Yes               1:4
# 168   TEN   LAC  Yes               1:4
# 834   LAC   LAC  Yes               3:2
# 200   LAC   TEN  Yes               2:3
# 189   LAC   TEN  Yes               1:4
# 186   LAC   TEN  Yes               2:3
# 208   LAC   TEN  Yes               3:2
# 840   LAC   LAC  Yes               3:2
# 180   LAC   TEN  Yes               2:3
# 211   LAC   TEN  Yes               2:3
# 175   LAC   TEN  Yes               3:2
# 221   LAC   TEN  Yes               2:3
# 171   LAC   TEN  Yes               3:2
# 226   LAC   TEN  Yes               2:3
# 265   LAC   TEN  Yes               2:3
# 163   TEN   LAC  Yes               2:3
# 874   TEN   LAC  Yes               3:2
# 157   TEN   LAC  Yes               2:3
# 151   LAC   LAC  Yes               2:3
# 146   LAC   LAC  Yes               2:3

# %%
#vegas odds:
#fav:buf
#spread: -8
#o/u: 47

# %%
#team1 = BUF, so as heavy fav we will subset only 4:1 and 3:2
#fav should always get a '4:1'
team_ratio = ['4:1','3:2','2:3','1:4']

# %%
test = test.sort_values(0, ascending = False)#.head(150)
test2 = test[test['team1_team2_count'].isin(team_ratio)]

# %%
test2#.to_csv('thu_night_wk13_lineups_test.csv')
# Out:
#          0                             1                              2  \
# 307   22.0     93784-39280:Derrick Henry     93784-69189:Justin Herbert
# 294   22.0  93784-12534:Tennessee Titans      93784-39280:Derrick Henry
# 257   22.0  93784-12534:Tennessee Titans      93784-39280:Derrick Henry
# 86    22.0  93784-12534:Tennessee Titans      93784-39280:Derrick Henry
# 89    21.0  93784-12534:Tennessee Titans    93784-16606:DeAndre Hopkins
# ...    ...                           ...                            ...
# 851   16.0    93784-110259:Treylon Burks  93784-120639:Quentin Johnston
# 817   16.0    93784-110259:Treylon Burks  93784-120639:Quentin Johnston
# 790   15.0    93784-110259:Treylon Burks  93784-120639:Quentin Johnston
# 832   15.0    93784-110259:Treylon Burks  93784-120639:Quentin Johnston
# 1067  15.0    93784-110259:Treylon Burks  93784-120639:Quentin Johnston
#
#                                 3                                  4  \
# 307     93784-91872:Joshua Kelley                     Cameron Dicker
# 294    93784-69189:Justin Herbert                     Cameron Dicker
# 257    93784-69189:Justin Herbert          93784-91872:Joshua Kelley
# 86     93784-69189:Justin Herbert          93784-91872:Joshua Kelley
# 89     93784-69189:Justin Herbert          93784-91872:Joshua Kelley
# ...                           ...                                ...
# 851      93784-29253:Keenan Allen          93784-39829:Mike Williams
# 817     93784-39280:Derrick Henry         93784-57299:Gerald Everett
# 790    93784-21948:Ryan Tannehill  93784-64389:Nick Westbrook-Ikhine
# 832    93784-21948:Ryan Tannehill         93784-57299:Gerald Everett
# 1067  93784-16606:DeAndre Hopkins         93784-21948:Ryan Tannehill
#
#                                5 Team1 Team2 Team3 Team4 Team5 keep  \
# 307                    Nick Folk   TEN   LAC   LAC   LAC   TEN  Yes
# 294                    Nick Folk   TEN   TEN   LAC   LAC   TEN  Yes
# 257                    Nick Folk   TEN   TEN   LAC   LAC   TEN  Yes
# 86                Cameron Dicker   TEN   TEN   LAC   LAC   LAC  Yes
# 89                Cameron Dicker   TEN   TEN   LAC   LAC   LAC  Yes
# ...                          ...   ...   ...   ...   ...   ...  ...
# 851   93784-69189:Justin Herbert   TEN   LAC   LAC   LAC   LAC  Yes
# 817   93784-69189:Justin Herbert   TEN   LAC   TEN   LAC   LAC  Yes
# 790   93784-69189:Justin Herbert   TEN   LAC   TEN   TEN   LAC  Yes
# 832   93784-69189:Justin Herbert   TEN   LAC   TEN   LAC   LAC  Yes
# 1067    93784-29253:Keenan Allen   TEN   LAC   TEN   TEN   LAC  Yes
#
#      team1_team2_count
# 307                3:2
# 294                2:3
# 257                2:3
# 86                 3:2
# 89                 3:2
# ...                ...
# 851                4:1
# 817                3:2
# 790                2:3
# 832                3:2
# 1067               2:3
#
# [1043 rows x 13 columns]

# %%
df_final
# Out:
#               Player ID + Player Name Position Team  Salary  \
# 1           93784-39280:Derrick Henry       RB  TEN   15000
# 2          93784-69189:Justin Herbert       QB  LAC   16000
# 23                          Nick Folk        K  TEN    9000
# 25          93784-91872:Joshua Kelley       RB  LAC   11000
# 74       93784-12534:Tennessee Titans        D  TEN    8500
# 22                     Cameron Dicker        K  LAC    9000
# 13        93784-16606:DeAndre Hopkins       WR  TEN   13000
# 16          93784-39829:Mike Williams       WR  LAC   12000
# 5            93784-29253:Keenan Allen       WR  LAC   12500
# 21         93784-21948:Ryan Tannehill       QB  TEN   14000
# 63     93784-104278:Donald Parham Jr.       TE  LAC    7000
# 70   93784-12548:Los Angeles Chargers        D  LAC    8500
# 35         93784-57299:Gerald Everett       TE  LAC    9500
# 36  93784-64389:Nick Westbrook-Ikhine       WR  TEN    9500
# 38         93784-110259:Treylon Burks       WR  TEN   10000
# 58          93784-107293:Tyjae Spears       RB  TEN    7500
# 57           93784-88297:Chig Okonkwo       TE  TEN    7500
# 55          93784-87418:Joshua Palmer       WR  LAC    8000
# 73         93784-185878:Elijah Dotson       RB  LAC    5000
# 46      93784-120639:Quentin Johnston       WR  LAC    8000
#
#                   player_wk_year  Prob2  Tier
# 1           Derrick Henry 2 2023    5.0   5.0
# 2          Justin Herbert 2 2023    5.0   5.0
# 23              Nick Folk 2 2023    4.0   4.0
# 25          Joshua Kelley 2 2023    4.0   4.0
# 74                    TEN 2 2023    4.0   4.0
# 22         Cameron Dicker 2 2023    4.0   4.0
# 13        DeAndre Hopkins 2 2023    4.0   4.0
# 16          Mike Williams 2 2023    4.0   4.0
# 5            Keenan Allen 2 2023    4.0   4.0
# 21         Ryan Tannehill 2 2023    4.0   4.0
# 63      Donald Parham Jr. 2 2023    3.0   3.0
# 70                    LAC 2 2023    3.0   3.0
# 35         Gerald Everett 2 2023    3.0   3.0
# 36  Nick Westbrook-Ikhine 2 2023    3.0   3.0
# 38          Treylon Burks 2 2023    2.0   2.0
# 58           Tyjae Spears 2 2023    2.0   2.0
# 57           Chig Okonkwo 2 2023    2.0   2.0
# 55          Joshua Palmer 2 2023    2.0   2.0
# 73          Elijah Dotson 2 2023    1.0   1.0
# 46       Quentin Johnston 2 2023    1.0   1.0

# %%
def create_mvp_lineups(test_df,
                       df_final,
                       team_ratios,
                      counts,
                      mvps):

    test_df = pd.DataFrame()
    team1_team2 = team_ratios #['4:1','4:1','4:1' ,'4:1', '3:2','3:2','3:2','3:2']
    count = counts #[40,20,10,5,40,20,10,15]
    mvp = mvps #['84053-62239:Josh Allen','84053-25079:Stefon Diggs', '84053-12526:Buffalo Bills','84053-6642:Nick Folk',
      #'84053-62239:Josh Allen','84053-25079:Stefon Diggs',
      #'84053-111540:Rhamondre Stevenson','84053-90584:Mac Jones']
    n = len(team1_team2)

    for z in range(0,n):
    
        teams = team1_team2[z]
        counts = count[z]
        mvps_filter = mvp[z]
        print(teams)
        test_new = test2[test2['team1_team2_count'] == teams]#.head(counts)
        print(len(test_new))
        #x = 0
       # while(x < counts):
        j = 0
        for pos in range(0,len(test_new)):
        #j = 0
        #pos = 0
        #while ((j <= counts) or (pos < len(test_new)) ):
        
            df_final_mvp = df_final['Player ID + Player Name'][df_final['Player ID + Player Name'].isin([mvps_filter])].values.tolist()
            df_final_1 = df_final['Player ID + Player Name'].values.tolist()
            df_final_2 = df_final['Player ID + Player Name'].values.tolist()
            df_final_3 = df_final['Player ID + Player Name'].values.tolist()
            df_final_4 = df_final['Player ID + Player Name'].values.tolist()

            l = test_new.iloc[pos, :].values.tolist()


            l_mvp = []
            l_1 = []
            l_2 = []
            l_3 = []
            l_4 = []

            for i in range(1,6):
               # print(l[i])
                if ((l[i] in df_final_mvp) & (len(l_mvp) < 1)):
                    l_mvp = l[i]
                    df_final_mvp.remove(l[i])
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])

                elif ((l[i] in (df_final_1)) & (len(l_1) < 1)):
                    l_1 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                    
                elif ((l[i] in (df_final_2)) & (len(l_2) < 1)):
                    l_2 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_3)) & (len(l_3) < 1)):
                    l_3 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_4)) & (len(l_4) < 1)):
                    l_4 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
            
            final_l = [l_mvp, l_1, l_2, l_3, l_4]
            final_l = pd.DataFrame([final_l])
            if (len(l_mvp) > 2):
               # pos = pos + 1
                j = j + 1
            else:
              #  pos = pos + 1
                j = j
           # print(pos)
            #print(final_l)
            test_df = test_df.append(final_l)
            test_df = test_df[test_df[0].str.len() > 2]
            if (j == counts):
                break

            
    return test_df

# %%
df_final
# Out:
#               Player ID + Player Name Position Team  Salary  \
# 1           93784-39280:Derrick Henry       RB  TEN   15000
# 2          93784-69189:Justin Herbert       QB  LAC   16000
# 23                          Nick Folk        K  TEN    9000
# 25          93784-91872:Joshua Kelley       RB  LAC   11000
# 74       93784-12534:Tennessee Titans        D  TEN    8500
# 22                     Cameron Dicker        K  LAC    9000
# 13        93784-16606:DeAndre Hopkins       WR  TEN   13000
# 16          93784-39829:Mike Williams       WR  LAC   12000
# 5            93784-29253:Keenan Allen       WR  LAC   12500
# 21         93784-21948:Ryan Tannehill       QB  TEN   14000
# 63     93784-104278:Donald Parham Jr.       TE  LAC    7000
# 70   93784-12548:Los Angeles Chargers        D  LAC    8500
# 35         93784-57299:Gerald Everett       TE  LAC    9500
# 36  93784-64389:Nick Westbrook-Ikhine       WR  TEN    9500
# 38         93784-110259:Treylon Burks       WR  TEN   10000
# 58          93784-107293:Tyjae Spears       RB  TEN    7500
# 57           93784-88297:Chig Okonkwo       TE  TEN    7500
# 55          93784-87418:Joshua Palmer       WR  LAC    8000
# 73         93784-185878:Elijah Dotson       RB  LAC    5000
# 46      93784-120639:Quentin Johnston       WR  LAC    8000
#
#                   player_wk_year  Prob2  Tier
# 1           Derrick Henry 2 2023    5.0   5.0
# 2          Justin Herbert 2 2023    5.0   5.0
# 23              Nick Folk 2 2023    4.0   4.0
# 25          Joshua Kelley 2 2023    4.0   4.0
# 74                    TEN 2 2023    4.0   4.0
# 22         Cameron Dicker 2 2023    4.0   4.0
# 13        DeAndre Hopkins 2 2023    4.0   4.0
# 16          Mike Williams 2 2023    4.0   4.0
# 5            Keenan Allen 2 2023    4.0   4.0
# 21         Ryan Tannehill 2 2023    4.0   4.0
# 63      Donald Parham Jr. 2 2023    3.0   3.0
# 70                    LAC 2 2023    3.0   3.0
# 35         Gerald Everett 2 2023    3.0   3.0
# 36  Nick Westbrook-Ikhine 2 2023    3.0   3.0
# 38          Treylon Burks 2 2023    2.0   2.0
# 58           Tyjae Spears 2 2023    2.0   2.0
# 57           Chig Okonkwo 2 2023    2.0   2.0
# 55          Joshua Palmer 2 2023    2.0   2.0
# 73          Elijah Dotson 2 2023    1.0   1.0
# 46       Quentin Johnston 2 2023    1.0   1.0

# %%
team_ratios = [
              # '4:1',#'4:1','4:1','4:1',#'4:1',#'4:1','4:1',
    
                '3:2',#'3:2','3:2','3:2'#,'3:2',#'3:2','3:2'
    
               '2:3'#,'2:3','2:3',#'2:3'#,#'2:3',#'2:3'#,
    
              # '1:4','1:4','1:4'#,'1:4'#,'1:4'
    
               
              ]
counts = [
    
    20,
    20
    
         ]
   
mvps = [
    
    '93784-69189:Justin Herbert',

    '93784-39280:Derrick Henry'
    
       ]


test_df = create_mvp_lineups(test_df = test2,
                       df_final = df_final,
                       team_ratios = team_ratios,
                      counts = counts,
                      mvps = mvps)
# Out:
# 3:2
# 403
# 2:3
# 357

# %%
test_df
# Out:
#                             0                                  1  \
# 0  93784-69189:Justin Herbert          93784-39280:Derrick Henry
# 0  93784-69189:Justin Herbert       93784-12534:Tennessee Titans
# 0  93784-69189:Justin Herbert       93784-12534:Tennessee Titans
# 0  93784-69189:Justin Herbert   93784-12548:Los Angeles Chargers
# 0  93784-69189:Justin Herbert        93784-16606:DeAndre Hopkins
# 0   93784-12548:Los Angeles Chargers    93784-39280:Derrick Henry
# 0           93784-29253:Keenan Allen    93784-39829:Mike Williams
# 0          93784-39280:Derrick Henry    93784-39829:Mike Williams
# 0       93784-12534:Tennessee Titans     93784-29253:Keenan Allen
# 0          93784-39280:Derrick Henry    93784-91872:Joshua Kelley
# 0          93784-39280:Derrick Henry    93784-91872:Joshua Kelley
# 0          93784-39829:Mike Williams               Cameron Dicker
# 0        93784-16606:DeAndre Hopkins    93784-39280:Derrick Henry
# 0         93784-69189:Justin Herbert               Cameron Dicker
# 0         93784-69189:Justin Herbert    93784-91872:Joshua Kelley
# 0          93784-39829:Mike Williams               Cameron Dicker
# 0          93784-39829:Mike Williams               Cameron Dicker
# 0         93784-69189:Justin Herbert               Cameron Dicker
# 0          93784-91872:Joshua Kelley               Cameron Dicker
# 0         93784-21948:Ryan Tannehill    93784-91872:Joshua Kelley
# 0           93784-29253:Keenan Allen               Cameron Dicker
# 0           93784-29253:Keenan Allen               Cameron Dicker
# 0        93784-16606:DeAndre Hopkins     93784-29253:Keenan Allen
# 0         93784-57299:Gerald Everett   93784-69189:Justin Herbert
# 0        93784-16606:DeAndre Hopkins   93784-69189:Justin Herbert
# 0         93784-21948:Ryan Tannehill     93784-29253:Keenan Allen
# 0        93784-16606:DeAndre Hopkins     93784-29253:Keenan Allen
# 0         93784-21948:Ryan Tannehill    93784-39829:Mike Williams
# 0        93784-16606:DeAndre Hopkins    93784-39829:Mike Williams
# 0       93784-12534:Tennessee Titans  93784-16606:DeAndre Hopkins
# 0          93784-39829:Mike Williams    93784-91872:Joshua Kelley
# 0        93784-16606:DeAndre Hopkins    93784-39829:Mike Williams
# 0  93784-64389:Nick Westbrook-Ikhine   93784-69189:Justin Herbert
#
#                             4
# 0                   Nick Folk
# 0              Cameron Dicker
# 0              Cameron Dicker
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0              Cameron Dicker
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0   93784-39829:Mike Williams
# 0                   Nick Folk
# 0   93784-39829:Mike Williams
# 0                   Nick Folk
# 0                   Nick Folk
# 0   93784-39280:Derrick Henry
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0              Cameron Dicker
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0                   Nick Folk
# 0              Cameron Dicker
# 0                   Nick Folk
# 0                   Nick Folk
# 0   93784-91872:Joshua Kelley
# 0                   Nick Folk
# 0                   Nick Folk
# 0              Cameron Dicker
# 0              Cameron Dicker
# 0              Cameron Dicker
# 0              Cameron Dicker
# 0  93784-69189:Justin Herbert
# 0                   Nick Folk
# 0   93784-91872:Joshua Kelley
# 0              Cameron Dicker

# %%
#test_df.to_csv('backtest_wk9_thu_phi_hou_predicted_lineups.csv')
#test_df.to_csv('2023_wk2_thu_phi_min_predicted_lineups.csv')

# %%
# if (len(test_df) < 150):
#     n = len(test_df)
# else:
#     n = len(test_df)
# test_df.head(n).to_csv('week11_gb_ten_test.csv')
