# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def single_game_player_df(week, year, day, file_name,
                         #qb_file, rb_file, wr_file,
                         #te_file, def_file,
                         team1,
                         team2):

    fanduel = pd.read_csv(file_name)
    fanduel = fanduel[fanduel['keep']=='x']
    fanduel = fanduel[(fanduel['Injury Indicator'] != 'IR') &
                  (fanduel['Injury Indicator'] != 'O') &
                  (fanduel['Injury Indicator'] != 'D')]
    fanduel2 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel2 = fanduel2[fanduel2['Position'] != 'D']
    fanduel2['player_wk_year'] = fanduel2['Nickname'] + " " + week + " " + year

    fanduel3 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel3 = fanduel3[fanduel3['Position'] == 'D']
    fanduel3['player_wk_year'] = fanduel3['Team'] + " " + week + " " + year

    fanduel4 = fanduel2.append(fanduel3)
    fanduel4 = fanduel4[['Player ID + Player Name', 'Position', 
                     'Team','Salary', 'Injury Indicator',
                    'player_wk_year','FPPG','Tier']]
    #fanduel4.sort_values(by = 'Salary', ascending = False)

    fanduel4['pos_rank'] = fanduel4.groupby(['Team','Position'])['Salary'].rank(ascending = False).astype(int)
    fanduel4['pos_rank'] = fanduel4['Position'] + fanduel4['pos_rank'].astype(str)

    fanduel5 = fanduel4[fanduel4['pos_rank'].isin(['QB1','RB1','RB2','RB3','WR1',
                                               'WR2','WR3','WR4','WR5',
                                              'TE1','TE2','TE3','D1','K1'])]

#     qb_df = pd.read_csv(qb_file)
#     qb_df['position'] = 'qb'
#     rb_df = pd.read_csv(rb_file)
#     rb_df['position'] = 'rb'
#     wr_df = pd.read_csv(wr_file)
#     wr_df['position'] = 'wr'
#     te_df = pd.read_csv(te_file)
#     te_df['position'] = 'te'
#     def_df = pd.read_csv(def_file)
#     def_df['position'] = 'def'
#     def_df = def_df.rename(columns = {'team_wk_year':'player_wk_year'})

#     df = qb_df.append(rb_df)
#     df = df.append(wr_df)
#     df = df.append(te_df)
#     df = df.append(def_df)

#     df = df.reset_index()
#     df = df.drop(columns = ['Unnamed: 0', 'index'])

#     df = df[(df['team_wk_year'].str.contains(team1)) |
#             (df['team_wk_year'].str.contains(team2))]
#     df_final = pd.merge(fanduel5, df, how = 'left', 
#                     on = 'player_wk_year', suffixes = (None, None))

    #df_final['Prob2'] = df_final[['FPPG', 'Prob']].mean(skipna=True, axis = 1)
    #df_final['Prob2'] = df_final['FPPG']
    df_final = fanduel5
    df_final['Prob2'] = df_final['Tier']
    df_final = df_final.drop_duplicates(subset = 'player_wk_year', keep = 'last')
    df_final = df_final.sort_values(by = 'Prob2', ascending = False)

    return df_final

# %%
#team1 = fav
#team2 = underdog
df_final = single_game_player_df(week = '2',
                        year = '2023',
                        day = 'Sun',
                        file_name = '2023_week2_sun_night_players.csv',
#                         qb_file = 'week9_scored_qb.csv',
#                         rb_file = 'week9_scored_rb.csv',
#                         wr_file = 'week9_scored_wr.csv',
#                         te_file = 'week9_scored_te.csv',
#                         def_file = 'week9_scored_def.csv',
                        team1 = 'MIA',
                        team2 = 'NE')

# %%
df_final = df_final[['Player ID + Player Name','Position', 'Team', 'Salary',
                    'player_wk_year','Prob2','Tier']]#,'FPPG','Prob']]

# %%
df_final
# Out:
#              Player ID + Player Name Position Team  Salary  \
# 0            93976-53681:Tyreek Hill       WR  MIA   17000
# 2              93976-90584:Mac Jones       QB   NE   15500
# 4          93976-90573:Jaylen Waddle       WR  MIA   13500
# 1         93976-90572:Tua Tagovailoa       QB  MIA   16500
# 3   93976-111540:Rhamondre Stevenson       RB   NE   14000
# 5         93976-28744:Raheem Mostert       RB  MIA   12000
# 6        93976-80289:Kendrick Bourne       WR   NE   11000
# 7           93976-40845:Hunter Henry       TE   NE   10000
# 9          93976-52767:Jason Sanders        K  MIA    9000
# 13       93976-38791:Ezekiel Elliott       RB   NE    8000
# 17       93976-52495:Braxton Berrios       WR  MIA    7500
# 8         93976-12539:Miami Dolphins        D  MIA    9500
# 19          93976-56265:Mike Gesicki       TE   NE    7000
# 18         93976-42046:Durham Smythe       TE  MIA    7000
# 11           93976-86750:Chad Ryland        K   NE    8500
# 14        93976-41997:River Cracraft       WR  MIA    8000
# 10   93976-55987:JuJu Smith-Schuster       WR   NE    9000
# 12  93976-12541:New England Patriots        D   NE    8500
# 16      93976-111876:Demario Douglas       WR   NE    7500
# 15        93976-33260:DeVante Parker       WR   NE    8000
#
#                 player_wk_year  Prob2  Tier
# 0           Tyreek Hill 2 2023    5.0   5.0
# 2             Mac Jones 2 2023    5.0   5.0
# 4         Jaylen Waddle 2 2023    5.0   5.0
# 1        Tua Tagovailoa 2 2023    5.0   5.0
# 3   Rhamondre Stevenson 2 2023    4.0   4.0
# 5        Raheem Mostert 2 2023    4.0   4.0
# 6       Kendrick Bourne 2 2023    4.0   4.0
# 7          Hunter Henry 2 2023    4.0   4.0
# 9         Jason Sanders 2 2023    4.0   4.0
# 13      Ezekiel Elliott 2 2023    4.0   4.0
# 17      Braxton Berrios 2 2023    3.0   3.0
# 8                   MIA 2 2023    3.0   3.0
# 19         Mike Gesicki 2 2023    3.0   3.0
# 18        Durham Smythe 2 2023    3.0   3.0
# 11          Chad Ryland 2 2023    3.0   3.0
# 14       River Cracraft 2 2023    3.0   3.0
# 10  JuJu Smith-Schuster 2 2023    3.0   3.0
# 12                   NE 2 2023    3.0   3.0
# 16      Demario Douglas 2 2023    2.0   2.0
# 15       DeVante Parker 2 2023    2.0   2.0

# %%
def create_single_game_simulations(df_final, team1, team2, 
                                   team1_pos, team2_pos
                                  # outcomes
                                  ):#,
                                 # players1, players2,
                                 # players3, players4):
    print('team1:')
    print(team1)
    print('team2:')
    print(team2)
    result = pd.DataFrame() 
    team1_df = df_final[df_final['Team'] == team1]
    team1_df['pos_rank'] = team1_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team1_df['pos_rank'] = team1_df['Position'] + team1_df['pos_rank'].astype(str)
    team2_df = df_final[df_final['Team'] == team2]
    team2_df['pos_rank'] = team2_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team2_df['pos_rank'] = team2_df['Position'] + team2_df['pos_rank'].astype(str)
    
    
    #outcomes = ['HL',
    #            'HM',
    #            'HH',
    #            'ML',
    #            'MM',
    #            'MH'#,
                #'LL',
                #'LM',
                #'LH'
     #          ]
    
    #for outcome in outcomes:
    #    print(outcome)
    #    if (outcome == 'HL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','QB1','RB1','WR1'])]
    #    elif (outcome == 'HM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'TE1','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','K1'])]
    #    elif (outcome == 'HH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'WR4','WR5','TE1','TE2','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3','TE1'
    #                                                    ])]
    #    elif (outcome == 'ML'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','K1'])]
    #    elif (outcome == 'MM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','TE1',
    #                                                        'WR3','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2'])]
    #    elif (outcome == 'MH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','TE1','WR1','WR2',
    #                                                       'WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3'])]
    #    elif (outcome == 'LL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #    elif (outcome == 'LM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #    elif (outcome == 'LH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1','TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1', 'TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
 
    team1_df2 = team1_df[team1_df['pos_rank'].isin(team1_pos)]
    team2_df2 = team2_df[team2_df['pos_rank'].isin(team2_pos)]
    
    team1_team2 = team1_df2.append(team2_df2)
    df_final_qb = team1_team2.sort_values('Prob2',ascending= False)
    df1 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df1 = df1.rename(columns = {'Player ID + Player Name':'flex1',
                                             'Salary':'flex1_sal','Prob2':'flex1_prob'})
    df2 = df_final_qb[['Player ID + Player Name', 'Team','Salary', 'Prob2']]
    df2 = df2.rename(columns = {'Player ID + Player Name':'flex2',
                                             'Salary':'flex2_sal','Prob2':'flex2_prob'})
    df3 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df3 = df3.rename(columns = {'Player ID + Player Name':'flex3',
                                            'Salary':'flex3_sal','Prob2':'flex3_prob'})
    df4 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df4 = df4.rename(columns = {'Player ID + Player Name':'flex4',
                                             'Salary':'flex4_sal','Prob2':'flex4_prob'})
    df5 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df5 = df5.rename(columns = {'Player ID + Player Name':'flex5',
                                             'Salary':'flex5_sal','Prob2':'flex5_prob'})

    sim_df = pd.merge(df1, df2, how = 'cross')
    sim_df = pd.merge(sim_df, df3, how = 'cross')
    sim_df = pd.merge(sim_df, df4, how = 'cross')
    sim_df = pd.merge(sim_df, df5, how = 'cross')
        
        
    sim_df = sim_df[(sim_df['flex1'] != sim_df['flex2']) & (sim_df['flex1'] != sim_df['flex3']) &
                (sim_df['flex1'] != sim_df['flex4']) & (sim_df['flex1'] != sim_df['flex5']) &
                (sim_df['flex2'] != sim_df['flex3']) & (sim_df['flex2'] != sim_df['flex4']) &
                (sim_df['flex2'] != sim_df['flex5']) & (sim_df['flex3'] != sim_df['flex4']) &
                (sim_df['flex3'] != sim_df['flex5']) & (sim_df['flex4'] != sim_df['flex5'])]

    sim_df['total_salary'] = sim_df['flex1_sal'] + sim_df['flex2_sal'] + sim_df['flex3_sal'] + sim_df['flex4_sal'] + sim_df['flex5_sal']
    sim_df['total_proj'] = sim_df['flex1_prob'] + sim_df['flex2_prob'] + sim_df['flex3_prob'] + sim_df['flex4_prob'] + sim_df['flex5_prob']

    sim_df = sim_df[sim_df['total_salary'] <= 60000]
    sim_df = sim_df[sim_df['total_salary'] > 57000]
    #if (len(sim_df) == 0):
    #    continue

    final= sim_df[['flex1', 'flex2', 'flex3', 'flex4', 'flex5','total_proj']]
    final['total_proj'] = final['total_proj'].astype(str)
        #final['total_salary'] = final['total_salary'].astype(str)
    print(len(final))
    n = len(final)
       # if (len(final) < 10000):
       #     n = len(final)
       # else:
       #     n = 10000
    final2 = pd.DataFrame()
    for i in range(0,n):
          #  print(i)
        l = final.iloc[i,:].values.tolist()
            #print(l)
        l.sort()
           # if ((players1 in l) |
           #     (players2 in l) |
           #    (players3 in l) |
           #     (players4 in l)
           #    ):
               # print(l)
        temp = pd.DataFrame([l])
            
        final2 = final2.append(temp)
            
    final2 = final2.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
        
    df_team_check = df_final_qb[['Player ID + Player Name','Team']]
        
    for i in range(1,6):
        print(i)
        final2 = pd.merge(final2, df_team_check, how = 'inner', left_on = i,
                          right_on = 'Player ID + Player Name',
                          suffixes = (None,None))
        team_col = 'Team' + str(i)
        final2[team_col] = final2['Team']
        final2 = final2.drop(columns = ['Team','Player ID + Player Name'])
    keep_list = []
    team1_v_team2 = []
    for i in range(0,len(final2)):
        team1_count = 0
        team2_count = 0
            #keep_list = []
        teams = final2[['Team1','Team2','Team3','Team4','Team5']]
        l = teams.iloc[i,:].values.tolist()
            #print(l)
        for j in l:
             #   print(j)
                
            if (j == team1):
                team1_count = team1_count + 1
            elif (j == team2):
                team2_count = team2_count + 1
             #   print(team1_count)
             #   print(team2_count)
        if ((team1_count > 4) | (team2_count > 4)):
            keep = 'No'
        else:
            keep = 'Yes'
                
        if ((team1_count == 2) & (team2_count == 3)):
            team1_team2 = '2:3'
        elif ((team1_count == 3) & (team2_count == 2)):
            team1_team2 = '3:2'
        elif ((team1_count == 4) & (team2_count == 1)):
            team1_team2 = '4:1'
        elif ((team1_count == 1) & (team2_count == 4)):
            team1_team2 = '1:4'
        else:
            team1_team2 = 'none'
                
          #  print(keep)
        keep_list.append(keep)
        team1_v_team2.append(team1_team2)
            #print(keep_list)
    final2['keep'] = keep_list
    final2['team1_team2_count'] = team1_v_team2
               
       # if(len(final2) < 33):
       #     m = len(final2)
       # else: 
       #     m = 33
       # final2 = final2.head(m)
    result = result.append(final2)
    
    result = result[result['keep'] == 'Yes']
    #result = result[[0,1,2,3,4,5]]
    result = result.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

    
    return result

# %%
#fav: MIA
#spread: -2.5
#o/u: 45.5
#team1 =favorite
#team2 =underdog

test = create_single_game_simulations(df_final = df_final,
                                      team1 = 'MIA',
                                      team2 = 'NE',
                                      team1_pos = ['QB1','RB1','RB2','TE1',
                                                  'WR1','WR2','WR3','WR4',
                                                   'K1','D1'],
                                      team2_pos = ['QB1','RB1','RB2','TE1','TE2',
                                                   'WR1','WR2','WR3','WR4',
                                                   'K1','D1'])
                                      #outcomes = ['LH']#,
                                   #  players1 = '81393-22015:Russell Wilson',
                                   #  players2 = '81393-69213:Michael Pittman Jr.',
                                   #  players3 = '81393-6616:Matt Ryan',
                                  # #  players4 = "81556-85701:Ja'Marr Chase"
                                   #  )
# Out:
# team1:
# MIA
# team2:
# NE
# 183600
# 1
# 2
# 3
# 4
# 5

# %%
test.shape
# Out:
# (1494, 13)

# %%
test = test.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
test.to_csv('2023_week2_ne_mia_all_predicted_lineups.csv')

# %%
test.sort_values(0, ascending = False).head(50)
# Out:
#          0                                 1                                2  \
# 1107  22.0       93976-38791:Ezekiel Elliott        93976-52767:Jason Sanders
# 82    22.0        93976-28744:Raheem Mostert         93976-40845:Hunter Henry
# 33    22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 531   22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 1129  22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 23    22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 1285  22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 119   22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 1225  22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 1278  22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 1022  22.0       93976-38791:Ezekiel Elliott        93976-52767:Jason Sanders
# 15    22.0          93976-40845:Hunter Henry        93976-52767:Jason Sanders
# 401   22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 1112  22.0          93976-40845:Hunter Henry        93976-52767:Jason Sanders
# 287   22.0       93976-38791:Ezekiel Elliott        93976-52767:Jason Sanders
# 1190  22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 1032  22.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 86    22.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 87    22.0  93976-111540:Rhamondre Stevenson      93976-38791:Ezekiel Elliott
# 299   21.0       93976-38791:Ezekiel Elliott         93976-56265:Mike Gesicki
# 282   21.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 306   21.0         93976-52767:Jason Sanders         93976-56265:Mike Gesicki
# 304   21.0          93976-40845:Hunter Henry         93976-56265:Mike Gesicki
# 1098  21.0        93976-28744:Raheem Mostert         93976-40845:Hunter Henry
# 290   21.0       93976-52495:Braxton Berrios        93976-52767:Jason Sanders
# 286   21.0         93976-42046:Durham Smythe        93976-52767:Jason Sanders
# 291   21.0        93976-41997:River Cracraft        93976-52767:Jason Sanders
# 1093  21.0        93976-28744:Raheem Mostert        93976-52767:Jason Sanders
# 293   21.0       93976-38791:Ezekiel Elliott      93976-52495:Braxton Berrios
# 1094  21.0  93976-111540:Rhamondre Stevenson        93976-52767:Jason Sanders
# 1087  21.0        93976-28744:Raheem Mostert      93976-38791:Ezekiel Elliott
# 0     21.0         93976-42046:Durham Smythe          93976-53681:Tyreek Hill
# 1080  21.0          93976-40845:Hunter Henry        93976-52767:Jason Sanders
# 333   21.0       93976-38791:Ezekiel Elliott        93976-52767:Jason Sanders
# 1042  21.0          93976-40845:Hunter Henry        93976-42046:Durham Smythe
# 343   21.0       93976-38791:Ezekiel Elliott         93976-40845:Hunter Henry
# 1043  21.0        93976-12539:Miami Dolphins      93976-38791:Ezekiel Elliott
# 1044  21.0  93976-12541:New England Patriots      93976-38791:Ezekiel Elliott
# 338   21.0          93976-40845:Hunter Henry        93976-52767:Jason Sanders
# 1051  21.0  93976-111540:Rhamondre Stevenson         93976-40845:Hunter Henry
# 1052  21.0  93976-111540:Rhamondre Stevenson       93976-28744:Raheem Mostert
# 1057  21.0  93976-111540:Rhamondre Stevenson       93976-28744:Raheem Mostert
# 310   21.0       93976-38791:Ezekiel Elliott  93976-55987:JuJu Smith-Schuster
# 326   21.0  93976-12541:New England Patriots      93976-38791:Ezekiel Elliott
# 324   21.0          93976-40845:Hunter Henry        93976-42046:Durham Smythe
# 1064  21.0       93976-38791:Ezekiel Elliott          93976-53681:Tyreek Hill
# 1069  21.0          93976-40845:Hunter Henry          93976-53681:Tyreek Hill
# 1101  21.0  93976-111540:Rhamondre Stevenson      93976-38791:Ezekiel Elliott
# 1071  21.0         93976-52767:Jason Sanders          93976-53681:Tyreek Hill
# 315   21.0       93976-38791:Ezekiel Elliott       93976-41997:River Cracraft
#
#                                     3                            4  \
# 1107      93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 82          93976-52767:Jason Sanders    93976-90573:Jaylen Waddle
# 33        93976-80289:Kendrick Bourne    93976-90573:Jaylen Waddle
# 531         93976-52767:Jason Sanders      93976-53681:Tyreek Hill
# 1129      93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 23        93976-80289:Kendrick Bourne    93976-90573:Jaylen Waddle
# 1285        93976-52767:Jason Sanders      93976-53681:Tyreek Hill
# 119          93976-40845:Hunter Henry    93976-90573:Jaylen Waddle
# 1225         93976-40845:Hunter Henry   93976-90572:Tua Tagovailoa
# 1278        93976-52767:Jason Sanders      93976-53681:Tyreek Hill
# 1022          93976-53681:Tyreek Hill  93976-80289:Kendrick Bourne
# 15        93976-80289:Kendrick Bourne    93976-90573:Jaylen Waddle
# 401         93976-52767:Jason Sanders   93976-90572:Tua Tagovailoa
# 1112      93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 287       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 1190        93976-52767:Jason Sanders   93976-90572:Tua Tagovailoa
# 1032          93976-53681:Tyreek Hill  93976-80289:Kendrick Bourne
# 86          93976-52767:Jason Sanders    93976-90573:Jaylen Waddle
# 87          93976-52767:Jason Sanders    93976-90573:Jaylen Waddle
# 299       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 282          93976-56265:Mike Gesicki   93976-90572:Tua Tagovailoa
# 306       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 304       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 1098         93976-56265:Mike Gesicki   93976-90572:Tua Tagovailoa
# 290       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 286       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 291       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 1093         93976-56265:Mike Gesicki   93976-90572:Tua Tagovailoa
# 293       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 1094         93976-56265:Mike Gesicki   93976-90572:Tua Tagovailoa
# 1087          93976-53681:Tyreek Hill      93976-86750:Chad Ryland
# 0            93976-56265:Mike Gesicki    93976-90573:Jaylen Waddle
# 1080          93976-53681:Tyreek Hill      93976-86750:Chad Ryland
# 333   93976-55987:JuJu Smith-Schuster   93976-90572:Tua Tagovailoa
# 1042          93976-53681:Tyreek Hill  93976-80289:Kendrick Bourne
# 343   93976-55987:JuJu Smith-Schuster   93976-90572:Tua Tagovailoa
# 1043          93976-53681:Tyreek Hill  93976-80289:Kendrick Bourne
# 1044          93976-53681:Tyreek Hill  93976-80289:Kendrick Bourne
# 338   93976-55987:JuJu Smith-Schuster   93976-90572:Tua Tagovailoa
# 1051        93976-52767:Jason Sanders  93976-80289:Kendrick Bourne
# 1052        93976-52767:Jason Sanders  93976-80289:Kendrick Bourne
# 1057      93976-38791:Ezekiel Elliott  93976-80289:Kendrick Bourne
# 310       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 326       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 324       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 1064      93976-80289:Kendrick Bourne      93976-86750:Chad Ryland
# 1069      93976-80289:Kendrick Bourne      93976-86750:Chad Ryland
# 1101         93976-56265:Mike Gesicki   93976-90572:Tua Tagovailoa
# 1071      93976-80289:Kendrick Bourne      93976-86750:Chad Ryland
# 315       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
#
#                               5 Team1 Team2 Team3 Team4 Team5 keep  \
# 1107  93976-90573:Jaylen Waddle    NE   MIA    NE   MIA   MIA  Yes
# 82        93976-90584:Mac Jones   MIA    NE   MIA   MIA    NE  Yes
# 33        93976-90584:Mac Jones   MIA    NE    NE   MIA    NE  Yes
# 531       93976-90584:Mac Jones    NE    NE   MIA   MIA    NE  Yes
# 1129  93976-90573:Jaylen Waddle    NE    NE    NE   MIA   MIA  Yes
# 23        93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 1285  93976-90573:Jaylen Waddle   MIA    NE   MIA   MIA   MIA  Yes
# 119       93976-90584:Mac Jones   MIA    NE    NE   MIA    NE  Yes
# 1225  93976-90573:Jaylen Waddle   MIA    NE    NE   MIA   MIA  Yes
# 1278  93976-90573:Jaylen Waddle    NE    NE   MIA   MIA   MIA  Yes
# 1022  93976-90573:Jaylen Waddle    NE   MIA   MIA    NE   MIA  Yes
# 15        93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 401       93976-90584:Mac Jones    NE    NE   MIA   MIA    NE  Yes
# 1112  93976-90573:Jaylen Waddle    NE   MIA    NE   MIA   MIA  Yes
# 287       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 1190  93976-90573:Jaylen Waddle   MIA    NE   MIA   MIA   MIA  Yes
# 1032  93976-90573:Jaylen Waddle    NE    NE   MIA    NE   MIA  Yes
# 86        93976-90584:Mac Jones   MIA    NE   MIA   MIA    NE  Yes
# 87        93976-90584:Mac Jones    NE    NE   MIA   MIA    NE  Yes
# 299       93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 282       93976-90584:Mac Jones   MIA    NE    NE   MIA    NE  Yes
# 306       93976-90584:Mac Jones   MIA    NE    NE   MIA    NE  Yes
# 304       93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 1098  93976-90573:Jaylen Waddle   MIA    NE    NE   MIA   MIA  Yes
# 290       93976-90584:Mac Jones   MIA   MIA    NE   MIA    NE  Yes
# 286       93976-90584:Mac Jones   MIA   MIA    NE   MIA    NE  Yes
# 291       93976-90584:Mac Jones   MIA   MIA    NE   MIA    NE  Yes
# 1093  93976-90573:Jaylen Waddle   MIA   MIA    NE   MIA   MIA  Yes
# 293       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 1094  93976-90573:Jaylen Waddle    NE   MIA    NE   MIA   MIA  Yes
# 1087  93976-90573:Jaylen Waddle   MIA    NE   MIA    NE   MIA  Yes
# 0         93976-90584:Mac Jones   MIA   MIA    NE   MIA    NE  Yes
# 1080  93976-90573:Jaylen Waddle    NE   MIA   MIA    NE   MIA  Yes
# 333       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 1042  93976-90573:Jaylen Waddle    NE   MIA   MIA    NE   MIA  Yes
# 343       93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 1043  93976-90573:Jaylen Waddle   MIA    NE   MIA    NE   MIA  Yes
# 1044  93976-90573:Jaylen Waddle    NE    NE   MIA    NE   MIA  Yes
# 338       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 1051  93976-90573:Jaylen Waddle    NE    NE   MIA    NE   MIA  Yes
# 1052  93976-90573:Jaylen Waddle    NE   MIA   MIA    NE   MIA  Yes
# 1057  93976-90573:Jaylen Waddle    NE   MIA    NE    NE   MIA  Yes
# 310       93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 326       93976-90584:Mac Jones    NE    NE    NE   MIA    NE  Yes
# 324       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
# 1064  93976-90573:Jaylen Waddle    NE   MIA    NE    NE   MIA  Yes
# 1069  93976-90573:Jaylen Waddle    NE   MIA    NE    NE   MIA  Yes
# 1101  93976-90573:Jaylen Waddle    NE    NE    NE   MIA   MIA  Yes
# 1071  93976-90573:Jaylen Waddle   MIA   MIA    NE    NE   MIA  Yes
# 315       93976-90584:Mac Jones    NE   MIA    NE   MIA    NE  Yes
#
#      team1_team2_count
# 1107               3:2
# 82                 3:2
# 33                 2:3
# 531                2:3
# 1129               2:3
# 23                 1:4
# 1285               4:1
# 119                2:3
# 1225               3:2
# 1278               3:2
# 1022               3:2
# 15                 2:3
# 401                2:3
# 1112               3:2
# 287                2:3
# 1190               4:1
# 1032               2:3
# 86                 3:2
# 87                 2:3
# 299                1:4
# 282                2:3
# 306                2:3
# 304                1:4
# 1098               3:2
# 290                3:2
# 286                3:2
# 291                3:2
# 1093               4:1
# 293                2:3
# 1094               3:2
# 1087               3:2
# 0                  3:2
# 1080               3:2
# 333                2:3
# 1042               3:2
# 343                1:4
# 1043               3:2
# 1044               2:3
# 338                2:3
# 1051               2:3
# 1052               3:2
# 1057               2:3
# 310                1:4
# 326                1:4
# 324                2:3
# 1064               2:3
# 1069               2:3
# 1101               2:3
# 1071               3:2
# 315                2:3

# %%
#vegas odds:
#fav: MIA
#spread: -2.5
#o/u: 45.5

# %%
#team1 = BUF, so as heavy fav we will subset only 4:1 and 3:2
#fav should always get a '4:1'
team_ratio = ['4:1','3:2','2:3','1:4']

# %%
test = test.sort_values(0, ascending = False)#.head(150)
test2 = test[test['team1_team2_count'].isin(team_ratio)]

# %%
test2#.to_csv('thu_night_wk13_lineups_test.csv')
# Out:
#          0                                 1  \
# 1107  22.0       93976-38791:Ezekiel Elliott
# 82    22.0        93976-28744:Raheem Mostert
# 33    22.0        93976-28744:Raheem Mostert
# 531   22.0       93976-38791:Ezekiel Elliott
# 1129  22.0       93976-38791:Ezekiel Elliott
# ...    ...                               ...
# 955   17.0      93976-111876:Demario Douglas
# 956   17.0      93976-111876:Demario Douglas
# 1474  17.0  93976-111540:Rhamondre Stevenson
# 1002  17.0  93976-111540:Rhamondre Stevenson
# 773   17.0      93976-111876:Demario Douglas
#
#                                      2                            3  \
# 1107         93976-52767:Jason Sanders  93976-80289:Kendrick Bourne
# 82            93976-40845:Hunter Henry    93976-52767:Jason Sanders
# 33         93976-38791:Ezekiel Elliott  93976-80289:Kendrick Bourne
# 531           93976-40845:Hunter Henry    93976-52767:Jason Sanders
# 1129          93976-40845:Hunter Henry  93976-80289:Kendrick Bourne
# ...                                ...                          ...
# 955   93976-12541:New England Patriots   93976-33260:DeVante Parker
# 956         93976-12539:Miami Dolphins   93976-33260:DeVante Parker
# 1474        93976-12539:Miami Dolphins   93976-33260:DeVante Parker
# 1002      93976-111876:Demario Douglas   93976-28744:Raheem Mostert
# 773         93976-33260:DeVante Parker      93976-53681:Tyreek Hill
#
#                                4                                5 Team1 Team2  \
# 1107  93976-90572:Tua Tagovailoa        93976-90573:Jaylen Waddle    NE   MIA
# 82     93976-90573:Jaylen Waddle            93976-90584:Mac Jones   MIA    NE
# 33     93976-90573:Jaylen Waddle            93976-90584:Mac Jones   MIA    NE
# 531      93976-53681:Tyreek Hill            93976-90584:Mac Jones    NE    NE
# 1129  93976-90572:Tua Tagovailoa        93976-90573:Jaylen Waddle    NE    NE
# ...                          ...                              ...   ...   ...
# 955      93976-53681:Tyreek Hill       93976-90572:Tua Tagovailoa    NE    NE
# 956      93976-53681:Tyreek Hill       93976-90572:Tua Tagovailoa    NE   MIA
# 1474     93976-53681:Tyreek Hill  93976-55987:JuJu Smith-Schuster    NE   MIA
# 1002  93976-33260:DeVante Parker       93976-90572:Tua Tagovailoa    NE    NE
# 773      93976-86750:Chad Ryland       93976-90572:Tua Tagovailoa    NE    NE
#
#      Team3 Team4 Team5 keep team1_team2_count
# 1107    NE   MIA   MIA  Yes               3:2
# 82     MIA   MIA    NE  Yes               3:2
# 33      NE   MIA    NE  Yes               2:3
# 531    MIA   MIA    NE  Yes               2:3
# 1129    NE   MIA   MIA  Yes               2:3
# ...    ...   ...   ...  ...               ...
# 955     NE   MIA   MIA  Yes               2:3
# 956     NE   MIA   MIA  Yes               3:2
# 1474    NE   MIA    NE  Yes               2:3
# 1002   MIA    NE   MIA  Yes               2:3
# 773    MIA    NE   MIA  Yes               2:3
#
# [1494 rows x 13 columns]

# %%
df_final
# Out:
#              Player ID + Player Name Position Team  Salary  \
# 0            93976-53681:Tyreek Hill       WR  MIA   17000
# 2              93976-90584:Mac Jones       QB   NE   15500
# 4          93976-90573:Jaylen Waddle       WR  MIA   13500
# 1         93976-90572:Tua Tagovailoa       QB  MIA   16500
# 3   93976-111540:Rhamondre Stevenson       RB   NE   14000
# 5         93976-28744:Raheem Mostert       RB  MIA   12000
# 6        93976-80289:Kendrick Bourne       WR   NE   11000
# 7           93976-40845:Hunter Henry       TE   NE   10000
# 9          93976-52767:Jason Sanders        K  MIA    9000
# 13       93976-38791:Ezekiel Elliott       RB   NE    8000
# 17       93976-52495:Braxton Berrios       WR  MIA    7500
# 8         93976-12539:Miami Dolphins        D  MIA    9500
# 19          93976-56265:Mike Gesicki       TE   NE    7000
# 18         93976-42046:Durham Smythe       TE  MIA    7000
# 11           93976-86750:Chad Ryland        K   NE    8500
# 14        93976-41997:River Cracraft       WR  MIA    8000
# 10   93976-55987:JuJu Smith-Schuster       WR   NE    9000
# 12  93976-12541:New England Patriots        D   NE    8500
# 16      93976-111876:Demario Douglas       WR   NE    7500
# 15        93976-33260:DeVante Parker       WR   NE    8000
#
#                 player_wk_year  Prob2  Tier
# 0           Tyreek Hill 2 2023    5.0   5.0
# 2             Mac Jones 2 2023    5.0   5.0
# 4         Jaylen Waddle 2 2023    5.0   5.0
# 1        Tua Tagovailoa 2 2023    5.0   5.0
# 3   Rhamondre Stevenson 2 2023    4.0   4.0
# 5        Raheem Mostert 2 2023    4.0   4.0
# 6       Kendrick Bourne 2 2023    4.0   4.0
# 7          Hunter Henry 2 2023    4.0   4.0
# 9         Jason Sanders 2 2023    4.0   4.0
# 13      Ezekiel Elliott 2 2023    4.0   4.0
# 17      Braxton Berrios 2 2023    3.0   3.0
# 8                   MIA 2 2023    3.0   3.0
# 19         Mike Gesicki 2 2023    3.0   3.0
# 18        Durham Smythe 2 2023    3.0   3.0
# 11          Chad Ryland 2 2023    3.0   3.0
# 14       River Cracraft 2 2023    3.0   3.0
# 10  JuJu Smith-Schuster 2 2023    3.0   3.0
# 12                   NE 2 2023    3.0   3.0
# 16      Demario Douglas 2 2023    2.0   2.0
# 15       DeVante Parker 2 2023    2.0   2.0

# %%
def create_mvp_lineups(test_df,
                       df_final,
                       team_ratios,
                      counts,
                      mvps):

    test_df = pd.DataFrame()
    team1_team2 = team_ratios #['4:1','4:1','4:1' ,'4:1', '3:2','3:2','3:2','3:2']
    count = counts #[40,20,10,5,40,20,10,15]
    mvp = mvps #['84053-62239:Josh Allen','84053-25079:Stefon Diggs', '84053-12526:Buffalo Bills','84053-6642:Nick Folk',
      #'84053-62239:Josh Allen','84053-25079:Stefon Diggs',
      #'84053-111540:Rhamondre Stevenson','84053-90584:Mac Jones']
    n = len(team1_team2)

    for z in range(0,n):
    
        teams = team1_team2[z]
        counts = count[z]
        mvps_filter = mvp[z]
        print(teams)
        test_new = test2[test2['team1_team2_count'] == teams]#.head(counts)
        print(len(test_new))
        #x = 0
       # while(x < counts):
        j = 0
        for pos in range(0,len(test_new)):
        #j = 0
        #pos = 0
        #while ((j <= counts) or (pos < len(test_new)) ):
        
            df_final_mvp = df_final['Player ID + Player Name'][df_final['Player ID + Player Name'].isin([mvps_filter])].values.tolist()
            df_final_1 = df_final['Player ID + Player Name'].values.tolist()
            df_final_2 = df_final['Player ID + Player Name'].values.tolist()
            df_final_3 = df_final['Player ID + Player Name'].values.tolist()
            df_final_4 = df_final['Player ID + Player Name'].values.tolist()

            l = test_new.iloc[pos, :].values.tolist()


            l_mvp = []
            l_1 = []
            l_2 = []
            l_3 = []
            l_4 = []

            for i in range(1,6):
               # print(l[i])
                if ((l[i] in df_final_mvp) & (len(l_mvp) < 1)):
                    l_mvp = l[i]
                    df_final_mvp.remove(l[i])
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])

                elif ((l[i] in (df_final_1)) & (len(l_1) < 1)):
                    l_1 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                    
                elif ((l[i] in (df_final_2)) & (len(l_2) < 1)):
                    l_2 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_3)) & (len(l_3) < 1)):
                    l_3 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_4)) & (len(l_4) < 1)):
                    l_4 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
            
            final_l = [l_mvp, l_1, l_2, l_3, l_4]
            final_l = pd.DataFrame([final_l])
            if (len(l_mvp) > 2):
               # pos = pos + 1
                j = j + 1
            else:
              #  pos = pos + 1
                j = j
           # print(pos)
            #print(final_l)
            test_df = test_df.append(final_l)
            test_df = test_df[test_df[0].str.len() > 2]
            if (j == counts):
                break

            
    return test_df

# %%
df_final
# Out:
#              Player ID + Player Name Position Team  Salary  \
# 0            93976-53681:Tyreek Hill       WR  MIA   17000
# 2              93976-90584:Mac Jones       QB   NE   15500
# 4          93976-90573:Jaylen Waddle       WR  MIA   13500
# 1         93976-90572:Tua Tagovailoa       QB  MIA   16500
# 3   93976-111540:Rhamondre Stevenson       RB   NE   14000
# 5         93976-28744:Raheem Mostert       RB  MIA   12000
# 6        93976-80289:Kendrick Bourne       WR   NE   11000
# 7           93976-40845:Hunter Henry       TE   NE   10000
# 9          93976-52767:Jason Sanders        K  MIA    9000
# 13       93976-38791:Ezekiel Elliott       RB   NE    8000
# 17       93976-52495:Braxton Berrios       WR  MIA    7500
# 8         93976-12539:Miami Dolphins        D  MIA    9500
# 19          93976-56265:Mike Gesicki       TE   NE    7000
# 18         93976-42046:Durham Smythe       TE  MIA    7000
# 11           93976-86750:Chad Ryland        K   NE    8500
# 14        93976-41997:River Cracraft       WR  MIA    8000
# 10   93976-55987:JuJu Smith-Schuster       WR   NE    9000
# 12  93976-12541:New England Patriots        D   NE    8500
# 16      93976-111876:Demario Douglas       WR   NE    7500
# 15        93976-33260:DeVante Parker       WR   NE    8000
#
#                 player_wk_year  Prob2  Tier
# 0           Tyreek Hill 2 2023    5.0   5.0
# 2             Mac Jones 2 2023    5.0   5.0
# 4         Jaylen Waddle 2 2023    5.0   5.0
# 1        Tua Tagovailoa 2 2023    5.0   5.0
# 3   Rhamondre Stevenson 2 2023    4.0   4.0
# 5        Raheem Mostert 2 2023    4.0   4.0
# 6       Kendrick Bourne 2 2023    4.0   4.0
# 7          Hunter Henry 2 2023    4.0   4.0
# 9         Jason Sanders 2 2023    4.0   4.0
# 13      Ezekiel Elliott 2 2023    4.0   4.0
# 17      Braxton Berrios 2 2023    3.0   3.0
# 8                   MIA 2 2023    3.0   3.0
# 19         Mike Gesicki 2 2023    3.0   3.0
# 18        Durham Smythe 2 2023    3.0   3.0
# 11          Chad Ryland 2 2023    3.0   3.0
# 14       River Cracraft 2 2023    3.0   3.0
# 10  JuJu Smith-Schuster 2 2023    3.0   3.0
# 12                   NE 2 2023    3.0   3.0
# 16      Demario Douglas 2 2023    2.0   2.0
# 15       DeVante Parker 2 2023    2.0   2.0

# %%
team_ratios = [
               '4:1','4:1','4:1','4:1',#'4:1',#'4:1','4:1',
    
                '3:2','3:2','3:2','3:2',#'3:2',#'3:2','3:2'
    
               '2:3','2:3','2:3','2:3','2:3',#'2:3'#,
    
               '1:4','1:4','1:4','1:4','1:4'
    
               
              ]
counts = [
    
    10,7,15,5,
    15,10,20,7,
    15,7,7,7,5,
    10,5,5,5,3
         ]
   
mvps = [
    '93976-53681:Tyreek Hill',
    '93976-90573:Jaylen Waddle',
    '93976-90572:Tua Tagovailoa',
    '93976-28744:Raheem Mostert',

    '93976-53681:Tyreek Hill',
    '93976-90573:Jaylen Waddle',
    '93976-90572:Tua Tagovailoa',
    '93976-28744:Raheem Mostert',
    
    '93976-90584:Mac Jones',
    '93976-111540:Rhamondre Stevenson',
    '93976-80289:Kendrick Bourne',
    '93976-40845:Hunter Henry',
    '93976-38791:Ezekiel Elliott',
    
    '93976-90584:Mac Jones',
    '93976-111540:Rhamondre Stevenson',
    '93976-80289:Kendrick Bourne',
    '93976-40845:Hunter Henry',
    '93976-38791:Ezekiel Elliott'
    
       ]


test_df = create_mvp_lineups(test_df = test2,
                       df_final = df_final,
                       team_ratios = team_ratios,
                      counts = counts,
                      mvps = mvps)
# Out:
# 4:1
# 192
# 4:1
# 192
# 4:1
# 192
# 4:1
# 192
# 3:2
# 525
# 3:2
# 525
# 3:2
# 525
# 3:2
# 525
# 2:3
# 558
# 2:3
# 558
# 2:3
# 558
# 2:3
# 558
# 2:3
# 558
# 1:4
# 219
# 1:4
# 219
# 1:4
# 219
# 1:4
# 219
# 1:4
# 219

# %%
test_df
# Out:
#                               0                                 1  \
# 0       93976-53681:Tyreek Hill        93976-28744:Raheem Mostert
# 0       93976-53681:Tyreek Hill       93976-52495:Braxton Berrios
# 0       93976-53681:Tyreek Hill       93976-38791:Ezekiel Elliott
# 0       93976-53681:Tyreek Hill          93976-40845:Hunter Henry
# 0       93976-53681:Tyreek Hill       93976-38791:Ezekiel Elliott
# ..                          ...                               ...
# 0      93976-40845:Hunter Henry  93976-111540:Rhamondre Stevenson
# 0      93976-40845:Hunter Henry       93976-38791:Ezekiel Elliott
# 0   93976-38791:Ezekiel Elliott          93976-40845:Hunter Henry
# 0   93976-38791:Ezekiel Elliott          93976-56265:Mike Gesicki
# 0   93976-38791:Ezekiel Elliott          93976-40845:Hunter Henry
#
#                                   2                            3  \
# 0       93976-38791:Ezekiel Elliott    93976-52767:Jason Sanders
# 0         93976-52767:Jason Sanders  93976-80289:Kendrick Bourne
# 0       93976-52495:Braxton Berrios    93976-52767:Jason Sanders
# 0       93976-52495:Braxton Berrios    93976-52767:Jason Sanders
# 0        93976-41997:River Cracraft    93976-52767:Jason Sanders
# ..                              ...                          ...
# 0         93976-52767:Jason Sanders  93976-80289:Kendrick Bourne
# 0           93976-53681:Tyreek Hill      93976-86750:Chad Ryland
# 0       93976-80289:Kendrick Bourne    93976-90573:Jaylen Waddle
# 0       93976-80289:Kendrick Bourne   93976-90572:Tua Tagovailoa
# 0   93976-55987:JuJu Smith-Schuster   93976-90572:Tua Tagovailoa
#
#                              4
# 0    93976-90573:Jaylen Waddle
# 0    93976-90573:Jaylen Waddle
# 0   93976-90572:Tua Tagovailoa
# 0   93976-90572:Tua Tagovailoa
# 0   93976-90572:Tua Tagovailoa
# ..                         ...
# 0        93976-90584:Mac Jones
# 0        93976-90584:Mac Jones
# 0        93976-90584:Mac Jones
# 0        93976-90584:Mac Jones
# 0        93976-90584:Mac Jones
#
# [158 rows x 5 columns]

# %%
#test_df.to_csv('backtest_wk9_thu_phi_hou_predicted_lineups.csv')
test_df.to_csv('2023_wk2_sun_mia_ne_predicted_lineups.csv')

# %%
# if (len(test_df) < 150):
#     n = len(test_df)
# else:
#     n = len(test_df)
# test_df.head(n).to_csv('week11_gb_ten_test.csv')
