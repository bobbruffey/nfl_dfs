# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def single_game_player_df(week, year, day, file_name,
                         #qb_file, rb_file, wr_file,
                         #te_file, def_file,
                         team1,
                         team2):

    
    fanduel = pd.read_csv(file_name)
    fanduel = fanduel[fanduel['keep']=='x']
    fanduel = fanduel[(fanduel['Injury Indicator'] != 'IR') &
                  (fanduel['Injury Indicator'] != 'O') &
                  (fanduel['Injury Indicator'] != 'D')]
    fanduel2 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel2 = fanduel2[fanduel2['Position'] != 'D']
    fanduel2['player_wk_year'] = fanduel2['Nickname'] + " " + week + " " + year

    fanduel3 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel3 = fanduel3[fanduel3['Position'] == 'D']
    fanduel3['player_wk_year'] = fanduel3['Team'] + " " + week + " " + year

    fanduel4 = fanduel2.append(fanduel3)
    fanduel4 = fanduel4[['Player ID + Player Name', 'Position', 
                     'Team','Salary', 'Injury Indicator',
                    'player_wk_year','FPPG','Tier']]
    #fanduel4.sort_values(by = 'Salary', ascending = False)

    fanduel4['pos_rank'] = fanduel4.groupby(['Team','Position'])['Salary'].rank(ascending = False).astype(int)
    fanduel4['pos_rank'] = fanduel4['Position'] + fanduel4['pos_rank'].astype(str)

    fanduel5 = fanduel4[fanduel4['pos_rank'].isin(['QB1','RB1','RB2','RB3','WR1',
                                               'WR2','WR3','WR4','WR5',
                                              'TE1','TE2','TE3','D1','K1'])]

#     qb_df = pd.read_csv(qb_file)
#     qb_df['position'] = 'qb'
#     rb_df = pd.read_csv(rb_file)
#     rb_df['position'] = 'rb'
#     wr_df = pd.read_csv(wr_file)
#     wr_df['position'] = 'wr'
#     te_df = pd.read_csv(te_file)
#     te_df['position'] = 'te'
#     def_df = pd.read_csv(def_file)
#     def_df['position'] = 'def'
#     def_df = def_df.rename(columns = {'team_wk_year':'player_wk_year'})

#     df = qb_df.append(rb_df)
#     df = df.append(wr_df)
#     df = df.append(te_df)
#     df = df.append(def_df)

#     df = df.reset_index()
#     df = df.drop(columns = ['Unnamed: 0', 'index'])

#     df = df[(df['team_wk_year'].str.contains(team1)) |
#             (df['team_wk_year'].str.contains(team2))]
#     df_final = pd.merge(fanduel5, df, how = 'left', 
#                     on = 'player_wk_year', suffixes = (None, None))

    #df_final['Prob2'] = df_final[['FPPG', 'Prob']].mean(skipna=True, axis = 1)
    #df_final['Prob2'] = df_final['FPPG']
    df_final = fanduel5
    df_final['Prob2'] = df_final['Tier']
    df_final = df_final.drop_duplicates(subset = 'player_wk_year', keep = 'last')
    df_final = df_final.sort_values(by = 'Prob2', ascending = False)

    return df_final

# %%
#team1 = fav
#team2 = underdog
df_final = single_game_player_df(week = '2',
                        year = '2023',
                        day = 'Sun',
                        file_name = '2023_week2_sun_main_single_game_players.csv',
#                         qb_file = 'week9_scored_qb.csv',
#                         rb_file = 'week9_scored_rb.csv',
#                         wr_file = 'week9_scored_wr.csv',
#                         te_file = 'week9_scored_te.csv',
#                         def_file = 'week9_scored_def.csv',
                        team1 = 'HOU',
                        team2 = 'IND')

df_final = df_final[(df_final['Team'] == 'HOU') |
                     (df_final['Team'] == 'IND')]

# %%
df_final = df_final[['Player ID + Player Name','Position', 'Team', 'Salary',
                    'player_wk_year','Prob2','Tier']]#,'FPPG','Prob']]

# %%
df_final
# Out:
#             Player ID + Player Name Position Team  Salary  \
# 7   93784-129315:Anthony Richardson       QB  IND   17000
# 77                 Ka'imi Fairbairn        K  HOU    9000
# 30         93784-29685:Robert Woods       WR  HOU   11500
# 29        93784-86055:Dameon Pierce       RB  HOU   13000
# 53   93784-12535:Indianapolis Colts        D  IND   10000
# 20         93784-129471:C.J. Stroud       QB  HOU   15000
# 79       93784-12556:Houston Texans        D  HOU    9000
# 12  93784-69213:Michael Pittman Jr.       WR  IND   14000
# 59        93784-71143:Kylen Granson       TE  IND    7000
# 78                         Matt Gay        K  IND    8500
# 43          93784-86312:Alec Pierce       WR  IND   10500
# 27         93784-91419:Nico Collins       WR  HOU   12500
# 28            93784-70027:Zack Moss       RB  IND   12000
# 45     93784-70603:Devin Singletary       RB  HOU    7500
# 32         93784-93134:Deon Jackson       RB  IND    9500
# 67          93784-24533:Mo Alie-Cox       TE  IND    6500
# 42          93784-129305:Josh Downs       WR  IND    8000
# 54           93784-129291:Tank Dell       WR  HOU    7500
# 56       93784-55042:Dalton Schultz       TE  HOU    8500
# 61           93784-58041:Mike Boone       RB  HOU    5000
# 69       93784-147049:Drew Ogletree       TE  IND    5000
# 68    93784-93026:Teagan Quitoriano       TE  HOU    5000
# 47            93784-70133:Jake Funk       RB  IND    5500
#
#                 player_wk_year  Prob2  Tier
# 7    Anthony Richardson 2 2023    5.0   5.0
# 77               Fa'imi 2 2023    4.0   4.0
# 30         Robert Woods 2 2023    4.0   4.0
# 29        Dameon Pierce 2 2023    4.0   4.0
# 53                  IND 2 2023    4.0   4.0
# 20          C.J. Stroud 2 2023    4.0   4.0
# 79                  HOU 2 2023    4.0   4.0
# 12  Michael Pittman Jr. 2 2023    4.0   4.0
# 59        Kylen Granson 2 2023    3.0   3.0
# 78             Matt Gay 2 2023    3.0   3.0
# 43          Alec Pierce 2 2023    3.0   3.0
# 27         Nico Collins 2 2023    3.0   3.0
# 28            Zack Moss 2 2023    3.0   3.0
# 45     Devin Singletary 2 2023    2.0   2.0
# 32         Deon Jackson 2 2023    2.0   2.0
# 67          Mo Alie-Cox 2 2023    2.0   2.0
# 42           Josh Downs 2 2023    2.0   2.0
# 54            Tank Dell 2 2023    2.0   2.0
# 56       Dalton Schultz 2 2023    2.0   2.0
# 61           Mike Boone 2 2023    1.0   1.0
# 69        Drew Ogletree 2 2023    1.0   1.0
# 68    Teagan Quitoriano 2 2023    1.0   1.0
# 47            Jake Funk 2 2023    1.0   1.0

# %%
def create_single_game_simulations(df_final, team1, team2, 
                                   team1_pos, team2_pos
                                  # outcomes
                                  ):#,
                                 # players1, players2,
                                 # players3, players4):
    print('team1:')
    print(team1)
    print('team2:')
    print(team2)
    result = pd.DataFrame() 
    team1_df = df_final[df_final['Team'] == team1]
    team1_df['pos_rank'] = team1_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team1_df['pos_rank'] = team1_df['Position'] + team1_df['pos_rank'].astype(str)
    team2_df = df_final[df_final['Team'] == team2]
    team2_df['pos_rank'] = team2_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team2_df['pos_rank'] = team2_df['Position'] + team2_df['pos_rank'].astype(str)
    
    
    #outcomes = ['HL',
    #            'HM',
    #            'HH',
    #            'ML',
    #            'MM',
    #            'MH'#,
                #'LL',
                #'LM',
                #'LH'
     #          ]
    
    #for outcome in outcomes:
    #    print(outcome)
    #    if (outcome == 'HL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','QB1','RB1','WR1'])]
    #    elif (outcome == 'HM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'TE1','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','K1'])]
    #    elif (outcome == 'HH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'WR4','WR5','TE1','TE2','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3','TE1'
    #                                                    ])]
    #    elif (outcome == 'ML'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','K1'])]
    #    elif (outcome == 'MM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','TE1',
    #                                                        'WR3','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2'])]
    #    elif (outcome == 'MH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','TE1','WR1','WR2',
    #                                                       'WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3'])]
    #    elif (outcome == 'LL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #    elif (outcome == 'LM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #    elif (outcome == 'LH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1','TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1', 'TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
 
    team1_df2 = team1_df[team1_df['pos_rank'].isin(team1_pos)]
    team2_df2 = team2_df[team2_df['pos_rank'].isin(team2_pos)]
    
    team1_team2 = team1_df2.append(team2_df2)
    df_final_qb = team1_team2.sort_values('Prob2',ascending= False)
    df1 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df1 = df1.rename(columns = {'Player ID + Player Name':'flex1',
                                             'Salary':'flex1_sal','Prob2':'flex1_prob'})
    df2 = df_final_qb[['Player ID + Player Name', 'Team','Salary', 'Prob2']]
    df2 = df2.rename(columns = {'Player ID + Player Name':'flex2',
                                             'Salary':'flex2_sal','Prob2':'flex2_prob'})
    df3 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df3 = df3.rename(columns = {'Player ID + Player Name':'flex3',
                                            'Salary':'flex3_sal','Prob2':'flex3_prob'})
    df4 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df4 = df4.rename(columns = {'Player ID + Player Name':'flex4',
                                             'Salary':'flex4_sal','Prob2':'flex4_prob'})
    df5 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df5 = df5.rename(columns = {'Player ID + Player Name':'flex5',
                                             'Salary':'flex5_sal','Prob2':'flex5_prob'})

    sim_df = pd.merge(df1, df2, how = 'cross')
    sim_df = pd.merge(sim_df, df3, how = 'cross')
    sim_df = pd.merge(sim_df, df4, how = 'cross')
    sim_df = pd.merge(sim_df, df5, how = 'cross')
        
        
    sim_df = sim_df[(sim_df['flex1'] != sim_df['flex2']) & (sim_df['flex1'] != sim_df['flex3']) &
                (sim_df['flex1'] != sim_df['flex4']) & (sim_df['flex1'] != sim_df['flex5']) &
                (sim_df['flex2'] != sim_df['flex3']) & (sim_df['flex2'] != sim_df['flex4']) &
                (sim_df['flex2'] != sim_df['flex5']) & (sim_df['flex3'] != sim_df['flex4']) &
                (sim_df['flex3'] != sim_df['flex5']) & (sim_df['flex4'] != sim_df['flex5'])]

    sim_df['total_salary'] = sim_df['flex1_sal'] + sim_df['flex2_sal'] + sim_df['flex3_sal'] + sim_df['flex4_sal'] + sim_df['flex5_sal']
    sim_df['total_proj'] = sim_df['flex1_prob'] + sim_df['flex2_prob'] + sim_df['flex3_prob'] + sim_df['flex4_prob'] + sim_df['flex5_prob']

    sim_df = sim_df[sim_df['total_salary'] <= 60000]
    sim_df = sim_df[sim_df['total_salary'] > 57000]
    #if (len(sim_df) == 0):
    #    continue

    final= sim_df[['flex1', 'flex2', 'flex3', 'flex4', 'flex5','total_proj']]
    final['total_proj'] = final['total_proj'].astype(str)
        #final['total_salary'] = final['total_salary'].astype(str)
    print(len(final))
    n = len(final)
       # if (len(final) < 10000):
       #     n = len(final)
       # else:
       #     n = 10000
    final2 = pd.DataFrame()
    for i in range(0,n):
          #  print(i)
        l = final.iloc[i,:].values.tolist()
            #print(l)
        l.sort()
           # if ((players1 in l) |
           #     (players2 in l) |
           #    (players3 in l) |
           #     (players4 in l)
           #    ):
               # print(l)
        temp = pd.DataFrame([l])
            
        final2 = final2.append(temp)
            
    final2 = final2.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
        
    df_team_check = df_final_qb[['Player ID + Player Name','Team']]
        
    for i in range(1,6):
        print(i)
        final2 = pd.merge(final2, df_team_check, how = 'inner', left_on = i,
                          right_on = 'Player ID + Player Name',
                          suffixes = (None,None))
        team_col = 'Team' + str(i)
        final2[team_col] = final2['Team']
        final2 = final2.drop(columns = ['Team','Player ID + Player Name'])
    keep_list = []
    team1_v_team2 = []
    for i in range(0,len(final2)):
        team1_count = 0
        team2_count = 0
            #keep_list = []
        teams = final2[['Team1','Team2','Team3','Team4','Team5']]
        l = teams.iloc[i,:].values.tolist()
            #print(l)
        for j in l:
             #   print(j)
                
            if (j == team1):
                team1_count = team1_count + 1
            elif (j == team2):
                team2_count = team2_count + 1
             #   print(team1_count)
             #   print(team2_count)
        if ((team1_count > 4) | (team2_count > 4)):
            keep = 'No'
        else:
            keep = 'Yes'
                
        if ((team1_count == 2) & (team2_count == 3)):
            team1_team2 = '2:3'
        elif ((team1_count == 3) & (team2_count == 2)):
            team1_team2 = '3:2'
        elif ((team1_count == 4) & (team2_count == 1)):
            team1_team2 = '4:1'
        elif ((team1_count == 1) & (team2_count == 4)):
            team1_team2 = '1:4'
        else:
            team1_team2 = 'none'
                
          #  print(keep)
        keep_list.append(keep)
        team1_v_team2.append(team1_team2)
            #print(keep_list)
    final2['keep'] = keep_list
    final2['team1_team2_count'] = team1_v_team2
               
       # if(len(final2) < 33):
       #     m = len(final2)
       # else: 
       #     m = 33
       # final2 = final2.head(m)
    result = result.append(final2)
    
    result = result[result['keep'] == 'Yes']
    #result = result[[0,1,2,3,4,5]]
    result = result.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

    
    return result

# %%
#fav: HOU
#spread: -1
#o/u: 39.5
#team1 =favorite
#team2 =underdog

test = create_single_game_simulations(df_final = df_final,
                                      team1 = 'HOU',
                                      team2 = 'IND',
                                      team1_pos = ['QB1','RB1','RB2','RB3',
                                                   'TE1','TE2','TE3',
                                                  'WR1','WR2','WR3',
                                                   'K1','D1'],
                                      team2_pos = ['QB1','RB1','RB2',
                                                   'TE1','TE2',
                                                   'WR1','WR2','WR3',
                                                   'K1','D1'])
                                      #outcomes = ['LH']#,
                                   #  players1 = '81393-22015:Russell Wilson',
                                   #  players2 = '81393-69213:Michael Pittman Jr.',
                                   #  players3 = '81393-6616:Matt Ryan',
                                  # #  players4 = "81556-85701:Ja'Marr Chase"
                                   #  )
# Out:
# team1:
# HOU
# team2:
# IND
# 152640
# 1
# 2
# 3
# 4
# 5

# %%
test.shape
# Out:
# (1239, 13)

# %%
test = test.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
test.to_csv('2023_week2_hou_ind_all_predicted_lineups.csv')

# %%
test.sort_values(0, ascending = False).head(50)
# Out:
#          0                                1                                2  \
# 47    21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 3     21.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 212   21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 33    21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 1042  20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 362   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 249   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 1193  20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 35    20.0       93784-12556:Houston Texans         93784-129471:C.J. Stroud
# 36    20.0   93784-12535:Indianapolis Colts         93784-129471:C.J. Stroud
# 1245  20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 358   20.0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 256   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 1045  20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 1219  20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 365   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 889   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 102   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 196   20.0  93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 197   20.0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 1186  20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 65    20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 841   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 200   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 64    20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 1185  20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 105   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 363   20.0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 134   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 27    20.0  93784-129315:Anthony Richardson  93784-69213:Michael Pittman Jr.
# 956   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 140   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 6     20.0       93784-12556:Houston Texans         93784-129471:C.J. Stroud
# 1019  20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 427   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 9     20.0   93784-12535:Indianapolis Colts         93784-29685:Robert Woods
# 1020  20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 216   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 1119  20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 382   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 381   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 1109  20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 106   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 215   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 132   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
# 131   20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 2     20.0   93784-12535:Indianapolis Colts         93784-129471:C.J. Stroud
# 244   20.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 23    20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 366   20.0   93784-12535:Indianapolis Colts  93784-129315:Anthony Richardson
#
#                                     3                                4  \
# 47    93784-129315:Anthony Richardson  93784-69213:Michael Pittman Jr.
# 3            93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 212   93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 33    93784-129315:Anthony Richardson        93784-86055:Dameon Pierce
# 1042         93784-129471:C.J. Stroud         93784-29685:Robert Woods
# 362         93784-86055:Dameon Pierce                 Ka'imi Fairbairn
# 249          93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 1193  93784-69213:Michael Pittman Jr.        93784-71143:Kylen Granson
# 35           93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 36           93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 1245         93784-129471:C.J. Stroud         93784-29685:Robert Woods
# 358         93784-86055:Dameon Pierce                 Ka'imi Fairbairn
# 256   93784-129315:Anthony Richardson  93784-69213:Michael Pittman Jr.
# 1045  93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 1219         93784-129471:C.J. Stroud         93784-29685:Robert Woods
# 365   93784-69213:Michael Pittman Jr.                 Ka'imi Fairbairn
# 889   93784-129315:Anthony Richardson        93784-86055:Dameon Pierce
# 102   93784-129315:Anthony Richardson         93784-91419:Nico Collins
# 196          93784-29685:Robert Woods        93784-71143:Kylen Granson
# 197   93784-69213:Michael Pittman Jr.        93784-71143:Kylen Granson
# 1186         93784-29685:Robert Woods        93784-71143:Kylen Granson
# 65           93784-29685:Robert Woods         93784-91419:Nico Collins
# 841   93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 200          93784-129471:C.J. Stroud        93784-71143:Kylen Granson
# 64           93784-29685:Robert Woods         93784-91419:Nico Collins
# 1185         93784-29685:Robert Woods        93784-71143:Kylen Granson
# 105          93784-29685:Robert Woods            93784-70027:Zack Moss
# 363   93784-69213:Michael Pittman Jr.                 Ka'imi Fairbairn
# 134          93784-29685:Robert Woods          93784-86312:Alec Pierce
# 27          93784-71143:Kylen Granson        93784-86055:Dameon Pierce
# 956   93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 140   93784-69213:Michael Pittman Jr.          93784-86312:Alec Pierce
# 6     93784-69213:Michael Pittman Jr.        93784-86055:Dameon Pierce
# 1019         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 427   93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 9     93784-69213:Michael Pittman Jr.        93784-86055:Dameon Pierce
# 1020         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 216          93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 1119         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 382          93784-129471:C.J. Stroud                 Ka'imi Fairbairn
# 381          93784-129471:C.J. Stroud                 Ka'imi Fairbairn
# 1109  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 106          93784-29685:Robert Woods            93784-70027:Zack Moss
# 215          93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 132         93784-86055:Dameon Pierce          93784-86312:Alec Pierce
# 131         93784-86055:Dameon Pierce          93784-86312:Alec Pierce
# 2            93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 244   93784-129315:Anthony Richardson        93784-86055:Dameon Pierce
# 23              93784-70027:Zack Moss        93784-86055:Dameon Pierce
# 366   93784-69213:Michael Pittman Jr.                 Ka'imi Fairbairn
#
#                                     5 Team1 Team2 Team3 Team4 Team5 keep  \
# 47                   Ka'imi Fairbairn   IND   HOU   IND   IND   HOU  Yes
# 3                    Ka'imi Fairbairn   HOU   IND   HOU   HOU   HOU  Yes
# 212                  Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 33                   Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 1042        93784-71143:Kylen Granson   HOU   IND   HOU   HOU   IND  Yes
# 362                          Matt Gay   IND   IND   HOU   HOU   IND  Yes
# 249                          Matt Gay   HOU   IND   HOU   IND   IND  Yes
# 1193        93784-86055:Dameon Pierce   HOU   IND   IND   IND   HOU  Yes
# 35                   Ka'imi Fairbairn   HOU   HOU   HOU   IND   HOU  Yes
# 36                   Ka'imi Fairbairn   IND   HOU   HOU   IND   HOU  Yes
# 1245  93784-69213:Michael Pittman Jr.   IND   HOU   HOU   HOU   IND  Yes
# 358                          Matt Gay   IND   HOU   HOU   HOU   IND  Yes
# 256                          Matt Gay   IND   HOU   IND   IND   IND  Yes
# 1045        93784-71143:Kylen Granson   IND   HOU   IND   HOU   IND  Yes
# 1219        93784-86055:Dameon Pierce   IND   HOU   HOU   HOU   HOU  Yes
# 365                          Matt Gay   HOU   IND   IND   HOU   IND  Yes
# 889           93784-86312:Alec Pierce   IND   HOU   IND   HOU   IND  Yes
# 102                  Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 196                  Ka'imi Fairbairn   IND   HOU   HOU   IND   HOU  Yes
# 197                  Ka'imi Fairbairn   IND   HOU   IND   IND   HOU  Yes
# 1186        93784-86055:Dameon Pierce   IND   IND   HOU   IND   HOU  Yes
# 65                   Ka'imi Fairbairn   IND   IND   HOU   HOU   HOU  Yes
# 841          93784-91419:Nico Collins   IND   HOU   IND   HOU   HOU  Yes
# 200                  Ka'imi Fairbairn   IND   IND   HOU   IND   HOU  Yes
# 64                   Ka'imi Fairbairn   HOU   IND   HOU   HOU   HOU  Yes
# 1185        93784-86055:Dameon Pierce   HOU   IND   HOU   IND   HOU  Yes
# 105                  Ka'imi Fairbairn   HOU   IND   HOU   IND   HOU  Yes
# 363                          Matt Gay   IND   HOU   IND   HOU   IND  Yes
# 134                  Ka'imi Fairbairn   IND   IND   HOU   IND   HOU  Yes
# 27                   Ka'imi Fairbairn   IND   IND   IND   HOU   HOU  Yes
# 956           93784-86312:Alec Pierce   IND   HOU   IND   HOU   IND  Yes
# 140                  Ka'imi Fairbairn   HOU   IND   IND   IND   HOU  Yes
# 6                    Ka'imi Fairbairn   HOU   HOU   IND   HOU   HOU  Yes
# 1019        93784-71143:Kylen Granson   HOU   IND   HOU   IND   IND  Yes
# 427                          Matt Gay   IND   HOU   IND   HOU   IND  Yes
# 9                    Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 1020        93784-71143:Kylen Granson   IND   IND   HOU   IND   IND  Yes
# 216                          Matt Gay   IND   IND   HOU   HOU   IND  Yes
# 1119        93784-86055:Dameon Pierce   IND   HOU   HOU   IND   HOU  Yes
# 382                          Matt Gay   IND   IND   HOU   HOU   IND  Yes
# 381                          Matt Gay   HOU   IND   HOU   HOU   IND  Yes
# 1109            93784-70027:Zack Moss   IND   HOU   IND   HOU   IND  Yes
# 106                  Ka'imi Fairbairn   IND   IND   HOU   IND   HOU  Yes
# 215                          Matt Gay   HOU   IND   HOU   HOU   IND  Yes
# 132                  Ka'imi Fairbairn   IND   IND   HOU   IND   HOU  Yes
# 131                  Ka'imi Fairbairn   HOU   IND   HOU   IND   HOU  Yes
# 2                    Ka'imi Fairbairn   IND   HOU   HOU   HOU   HOU  Yes
# 244                          Matt Gay   IND   HOU   IND   HOU   IND  Yes
# 23                   Ka'imi Fairbairn   HOU   IND   IND   HOU   HOU  Yes
# 366                          Matt Gay   IND   IND   IND   HOU   IND  Yes
#
#      team1_team2_count
# 47                 2:3
# 3                  4:1
# 212                3:2
# 33                 3:2
# 1042               3:2
# 362                2:3
# 249                2:3
# 1193               2:3
# 35                 4:1
# 36                 3:2
# 1245               3:2
# 358                3:2
# 256                1:4
# 1045               2:3
# 1219               4:1
# 365                2:3
# 889                2:3
# 102                3:2
# 196                3:2
# 197                2:3
# 1186               2:3
# 65                 3:2
# 841                3:2
# 200                2:3
# 64                 4:1
# 1185               3:2
# 105                3:2
# 363                2:3
# 134                2:3
# 27                 2:3
# 956                2:3
# 140                2:3
# 6                  4:1
# 1019               2:3
# 427                2:3
# 9                  3:2
# 1020               1:4
# 216                2:3
# 1119               3:2
# 382                2:3
# 381                3:2
# 1109               2:3
# 106                2:3
# 215                3:2
# 132                2:3
# 131                3:2
# 2                  4:1
# 244                2:3
# 23                 3:2
# 366                1:4

# %%
#vegas odds:
#fav:buf
#spread: -8
#o/u: 47

# %%
#team1 = BUF, so as heavy fav we will subset only 4:1 and 3:2
#fav should always get a '4:1'
team_ratio = ['4:1','3:2','2:3','1:4']

# %%
test = test.sort_values(0, ascending = False)#.head(150)
test2 = test[test['team1_team2_count'].isin(team_ratio)]

# %%
test2#.to_csv('thu_night_wk13_lineups_test.csv')
# Out:
#          0                                1                                2  \
# 47    21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 3     21.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 212   21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 33    21.0   93784-12535:Indianapolis Colts       93784-12556:Houston Texans
# 1042  20.0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# ...    ...                              ...                              ...
# 513   15.0         93784-129471:C.J. Stroud            93784-70027:Zack Moss
# 514   15.0  93784-69213:Michael Pittman Jr.            93784-70027:Zack Moss
# 515   15.0  93784-129315:Anthony Richardson       93784-55042:Dalton Schultz
# 717   15.0         93784-129471:C.J. Stroud           93784-58041:Mike Boone
# 527   14.0         93784-129471:C.J. Stroud       93784-55042:Dalton Schultz
#
#                                     3                                4  \
# 47    93784-129315:Anthony Richardson  93784-69213:Michael Pittman Jr.
# 3            93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 212   93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 33    93784-129315:Anthony Richardson        93784-86055:Dameon Pierce
# 1042         93784-129471:C.J. Stroud         93784-29685:Robert Woods
# ...                               ...                              ...
# 513           93784-86312:Alec Pierce         93784-91419:Nico Collins
# 514           93784-86312:Alec Pierce         93784-91419:Nico Collins
# 515           93784-86312:Alec Pierce         93784-91419:Nico Collins
# 717   93784-69213:Michael Pittman Jr.            93784-70027:Zack Moss
# 527             93784-70027:Zack Moss         93784-91419:Nico Collins
#
#                               5 Team1 Team2 Team3 Team4 Team5 keep  \
# 47             Ka'imi Fairbairn   IND   HOU   IND   IND   HOU  Yes
# 3              Ka'imi Fairbairn   HOU   IND   HOU   HOU   HOU  Yes
# 212            Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 33             Ka'imi Fairbairn   IND   HOU   IND   HOU   HOU  Yes
# 1042  93784-71143:Kylen Granson   HOU   IND   HOU   HOU   IND  Yes
# ...                         ...   ...   ...   ...   ...   ...  ...
# 513    93784-93134:Deon Jackson   HOU   IND   IND   HOU   IND  Yes
# 514    93784-93134:Deon Jackson   IND   IND   IND   HOU   IND  Yes
# 515    93784-93134:Deon Jackson   IND   HOU   IND   HOU   IND  Yes
# 717    93784-91419:Nico Collins   HOU   HOU   IND   IND   HOU  Yes
# 527    93784-93134:Deon Jackson   HOU   HOU   IND   HOU   IND  Yes
#
#      team1_team2_count
# 47                 2:3
# 3                  4:1
# 212                3:2
# 33                 3:2
# 1042               3:2
# ...                ...
# 513                2:3
# 514                1:4
# 515                2:3
# 717                3:2
# 527                3:2
#
# [1239 rows x 13 columns]

# %%
df_final
# Out:
#             Player ID + Player Name Position Team  Salary  \
# 7   93784-129315:Anthony Richardson       QB  IND   17000
# 77                 Ka'imi Fairbairn        K  HOU    9000
# 30         93784-29685:Robert Woods       WR  HOU   11500
# 29        93784-86055:Dameon Pierce       RB  HOU   13000
# 53   93784-12535:Indianapolis Colts        D  IND   10000
# 20         93784-129471:C.J. Stroud       QB  HOU   15000
# 79       93784-12556:Houston Texans        D  HOU    9000
# 12  93784-69213:Michael Pittman Jr.       WR  IND   14000
# 59        93784-71143:Kylen Granson       TE  IND    7000
# 78                         Matt Gay        K  IND    8500
# 43          93784-86312:Alec Pierce       WR  IND   10500
# 27         93784-91419:Nico Collins       WR  HOU   12500
# 28            93784-70027:Zack Moss       RB  IND   12000
# 45     93784-70603:Devin Singletary       RB  HOU    7500
# 32         93784-93134:Deon Jackson       RB  IND    9500
# 67          93784-24533:Mo Alie-Cox       TE  IND    6500
# 42          93784-129305:Josh Downs       WR  IND    8000
# 54           93784-129291:Tank Dell       WR  HOU    7500
# 56       93784-55042:Dalton Schultz       TE  HOU    8500
# 61           93784-58041:Mike Boone       RB  HOU    5000
# 69       93784-147049:Drew Ogletree       TE  IND    5000
# 68    93784-93026:Teagan Quitoriano       TE  HOU    5000
# 47            93784-70133:Jake Funk       RB  IND    5500
#
#                 player_wk_year  Prob2  Tier
# 7    Anthony Richardson 2 2023    5.0   5.0
# 77               Fa'imi 2 2023    4.0   4.0
# 30         Robert Woods 2 2023    4.0   4.0
# 29        Dameon Pierce 2 2023    4.0   4.0
# 53                  IND 2 2023    4.0   4.0
# 20          C.J. Stroud 2 2023    4.0   4.0
# 79                  HOU 2 2023    4.0   4.0
# 12  Michael Pittman Jr. 2 2023    4.0   4.0
# 59        Kylen Granson 2 2023    3.0   3.0
# 78             Matt Gay 2 2023    3.0   3.0
# 43          Alec Pierce 2 2023    3.0   3.0
# 27         Nico Collins 2 2023    3.0   3.0
# 28            Zack Moss 2 2023    3.0   3.0
# 45     Devin Singletary 2 2023    2.0   2.0
# 32         Deon Jackson 2 2023    2.0   2.0
# 67          Mo Alie-Cox 2 2023    2.0   2.0
# 42           Josh Downs 2 2023    2.0   2.0
# 54            Tank Dell 2 2023    2.0   2.0
# 56       Dalton Schultz 2 2023    2.0   2.0
# 61           Mike Boone 2 2023    1.0   1.0
# 69        Drew Ogletree 2 2023    1.0   1.0
# 68    Teagan Quitoriano 2 2023    1.0   1.0
# 47            Jake Funk 2 2023    1.0   1.0

# %%
def create_mvp_lineups(test_df,
                       df_final,
                       team_ratios,
                      counts,
                      mvps):

    test_df = pd.DataFrame()
    team1_team2 = team_ratios #['4:1','4:1','4:1' ,'4:1', '3:2','3:2','3:2','3:2']
    count = counts #[40,20,10,5,40,20,10,15]
    mvp = mvps #['84053-62239:Josh Allen','84053-25079:Stefon Diggs', '84053-12526:Buffalo Bills','84053-6642:Nick Folk',
      #'84053-62239:Josh Allen','84053-25079:Stefon Diggs',
      #'84053-111540:Rhamondre Stevenson','84053-90584:Mac Jones']
    n = len(team1_team2)

    for z in range(0,n):
    
        teams = team1_team2[z]
        counts = count[z]
        mvps_filter = mvp[z]
        print(teams)
        test_new = test2[test2['team1_team2_count'] == teams]#.head(counts)
        print(len(test_new))
        #x = 0
       # while(x < counts):
        j = 0
        for pos in range(0,len(test_new)):
        #j = 0
        #pos = 0
        #while ((j <= counts) or (pos < len(test_new)) ):
        
            df_final_mvp = df_final['Player ID + Player Name'][df_final['Player ID + Player Name'].isin([mvps_filter])].values.tolist()
            df_final_1 = df_final['Player ID + Player Name'].values.tolist()
            df_final_2 = df_final['Player ID + Player Name'].values.tolist()
            df_final_3 = df_final['Player ID + Player Name'].values.tolist()
            df_final_4 = df_final['Player ID + Player Name'].values.tolist()

            l = test_new.iloc[pos, :].values.tolist()


            l_mvp = []
            l_1 = []
            l_2 = []
            l_3 = []
            l_4 = []

            for i in range(1,6):
               # print(l[i])
                if ((l[i] in df_final_mvp) & (len(l_mvp) < 1)):
                    l_mvp = l[i]
                    df_final_mvp.remove(l[i])
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])

                elif ((l[i] in (df_final_1)) & (len(l_1) < 1)):
                    l_1 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                    
                elif ((l[i] in (df_final_2)) & (len(l_2) < 1)):
                    l_2 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_3)) & (len(l_3) < 1)):
                    l_3 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_4)) & (len(l_4) < 1)):
                    l_4 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
            
            final_l = [l_mvp, l_1, l_2, l_3, l_4]
            final_l = pd.DataFrame([final_l])
            if (len(l_mvp) > 2):
               # pos = pos + 1
                j = j + 1
            else:
              #  pos = pos + 1
                j = j
           # print(pos)
            #print(final_l)
            test_df = test_df.append(final_l)
            test_df = test_df[test_df[0].str.len() > 2]
            if (j == counts):
                break

            
    return test_df

# %%
df_final
# Out:
#             Player ID + Player Name Position Team  Salary  \
# 7   93784-129315:Anthony Richardson       QB  IND   17000
# 77                 Ka'imi Fairbairn        K  HOU    9000
# 30         93784-29685:Robert Woods       WR  HOU   11500
# 29        93784-86055:Dameon Pierce       RB  HOU   13000
# 53   93784-12535:Indianapolis Colts        D  IND   10000
# 20         93784-129471:C.J. Stroud       QB  HOU   15000
# 79       93784-12556:Houston Texans        D  HOU    9000
# 12  93784-69213:Michael Pittman Jr.       WR  IND   14000
# 59        93784-71143:Kylen Granson       TE  IND    7000
# 78                         Matt Gay        K  IND    8500
# 43          93784-86312:Alec Pierce       WR  IND   10500
# 27         93784-91419:Nico Collins       WR  HOU   12500
# 28            93784-70027:Zack Moss       RB  IND   12000
# 45     93784-70603:Devin Singletary       RB  HOU    7500
# 32         93784-93134:Deon Jackson       RB  IND    9500
# 67          93784-24533:Mo Alie-Cox       TE  IND    6500
# 42          93784-129305:Josh Downs       WR  IND    8000
# 54           93784-129291:Tank Dell       WR  HOU    7500
# 56       93784-55042:Dalton Schultz       TE  HOU    8500
# 61           93784-58041:Mike Boone       RB  HOU    5000
# 69       93784-147049:Drew Ogletree       TE  IND    5000
# 68    93784-93026:Teagan Quitoriano       TE  HOU    5000
# 47            93784-70133:Jake Funk       RB  IND    5500
#
#                 player_wk_year  Prob2  Tier
# 7    Anthony Richardson 2 2023    5.0   5.0
# 77               Fa'imi 2 2023    4.0   4.0
# 30         Robert Woods 2 2023    4.0   4.0
# 29        Dameon Pierce 2 2023    4.0   4.0
# 53                  IND 2 2023    4.0   4.0
# 20          C.J. Stroud 2 2023    4.0   4.0
# 79                  HOU 2 2023    4.0   4.0
# 12  Michael Pittman Jr. 2 2023    4.0   4.0
# 59        Kylen Granson 2 2023    3.0   3.0
# 78             Matt Gay 2 2023    3.0   3.0
# 43          Alec Pierce 2 2023    3.0   3.0
# 27         Nico Collins 2 2023    3.0   3.0
# 28            Zack Moss 2 2023    3.0   3.0
# 45     Devin Singletary 2 2023    2.0   2.0
# 32         Deon Jackson 2 2023    2.0   2.0
# 67          Mo Alie-Cox 2 2023    2.0   2.0
# 42           Josh Downs 2 2023    2.0   2.0
# 54            Tank Dell 2 2023    2.0   2.0
# 56       Dalton Schultz 2 2023    2.0   2.0
# 61           Mike Boone 2 2023    1.0   1.0
# 69        Drew Ogletree 2 2023    1.0   1.0
# 68    Teagan Quitoriano 2 2023    1.0   1.0
# 47            Jake Funk 2 2023    1.0   1.0

# %%
team_ratios = [
               #'4:1','4:1','4:1','4:1',#'4:1',#'4:1','4:1',
    
                '3:2',#'3:2','3:2','3:2'#,'3:2',#'3:2','3:2'
    
               '2:3'#,'2:3','2:3',#'2:3'#,#'2:3',#'2:3'#,
    
               #'1:4','1:4','1:4'#,'1:4'#,'1:4'
    
               
              ]
counts = [
    
    25,#20,10,10,15
    25#,15,10,10,15
    
         ]
   
mvps = [
    '93784-129315:Anthony Richardson',

    
    '93784-129471:C.J. Stroud'
    
       ]


test_df = create_mvp_lineups(test_df = test2,
                       df_final = df_final,
                       team_ratios = team_ratios,
                      counts = counts,
                      mvps = mvps)
# Out:
# 3:2
# 429
# 2:3
# 466

# %%
test_df
# Out:
#                                  0                                1  \
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson         93784-129471:C.J. Stroud
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson         93784-29685:Robert Woods
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0  93784-129315:Anthony Richardson       93784-12556:Houston Texans
# 0  93784-129315:Anthony Richardson   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud  93784-129315:Anthony Richardson
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud       93784-12556:Houston Texans
# 0         93784-129471:C.J. Stroud  93784-129315:Anthony Richardson
# 0         93784-129471:C.J. Stroud       93784-12556:Houston Texans
# 0         93784-129471:C.J. Stroud  93784-129315:Anthony Richardson
# 0         93784-129471:C.J. Stroud  93784-129315:Anthony Richardson
# 0         93784-129471:C.J. Stroud       93784-12556:Houston Texans
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
# 0         93784-129471:C.J. Stroud   93784-12535:Indianapolis Colts
#
#                                  2                                3  \
# 0       93784-12556:Houston Texans         93784-129471:C.J. Stroud
# 0       93784-12556:Houston Texans        93784-86055:Dameon Pierce
# 0         93784-129471:C.J. Stroud         93784-29685:Robert Woods
# 0        93784-86055:Dameon Pierce                 Ka'imi Fairbairn
# 0       93784-12556:Houston Texans         93784-91419:Nico Collins
# 0         93784-29685:Robert Woods        93784-71143:Kylen Granson
# 0         93784-29685:Robert Woods         93784-91419:Nico Collins
# 0       93784-12556:Houston Texans         93784-29685:Robert Woods
# 0         93784-29685:Robert Woods        93784-71143:Kylen Granson
# 0         93784-29685:Robert Woods            93784-70027:Zack Moss
# 0         93784-129471:C.J. Stroud                 Ka'imi Fairbairn
# 0         93784-29685:Robert Woods        93784-86055:Dameon Pierce
# 0        93784-86055:Dameon Pierce          93784-86312:Alec Pierce
# 0            93784-70027:Zack Moss        93784-86055:Dameon Pierce
# 0        93784-71143:Kylen Granson        93784-86055:Dameon Pierce
# 0          93784-129305:Josh Downs         93784-129471:C.J. Stroud
# 0          93784-24533:Mo Alie-Cox         93784-29685:Robert Woods
# 0         93784-129471:C.J. Stroud       93784-55042:Dalton Schultz
# 0           93784-129291:Tank Dell         93784-129471:C.J. Stroud
# 0         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 0        93784-86055:Dameon Pierce         93784-93134:Deon Jackson
# 0        93784-86055:Dameon Pierce         93784-93134:Deon Jackson
# 0       93784-12556:Houston Texans         93784-129471:C.J. Stroud
# 0         93784-129471:C.J. Stroud         93784-93134:Deon Jackson
# 0       93784-12556:Houston Texans           93784-129291:Tank Dell
# 0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 0  93784-129315:Anthony Richardson        93784-71143:Kylen Granson
# 0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 0  93784-129315:Anthony Richardson                 Ka'imi Fairbairn
# 0  93784-129315:Anthony Richardson          93784-24533:Mo Alie-Cox
# 0          93784-129305:Josh Downs  93784-129315:Anthony Richardson
# 0        93784-71143:Kylen Granson          93784-86312:Alec Pierce
# 0       93784-12556:Houston Texans  93784-69213:Michael Pittman Jr.
# 0         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 0  93784-129315:Anthony Richardson            93784-70027:Zack Moss
# 0            93784-70027:Zack Moss        93784-71143:Kylen Granson
# 0  93784-129315:Anthony Richardson          93784-86312:Alec Pierce
# 0          93784-86312:Alec Pierce                 Ka'imi Fairbairn
# 0         93784-29685:Robert Woods        93784-71143:Kylen Granson
# 0  93784-129315:Anthony Richardson        93784-71143:Kylen Granson
# 0         93784-29685:Robert Woods  93784-69213:Michael Pittman Jr.
# 0       93784-12556:Houston Texans  93784-69213:Michael Pittman Jr.
# 0  93784-69213:Michael Pittman Jr.        93784-71143:Kylen Granson
# 0  93784-69213:Michael Pittman Jr.            93784-70027:Zack Moss
# 0       93784-12556:Houston Texans  93784-129315:Anthony Richardson
# 0  93784-129315:Anthony Richardson          93784-24533:Mo Alie-Cox
# 0  93784-69213:Michael Pittman Jr.          93784-86312:Alec Pierce
# 0       93784-12556:Houston Texans          93784-129305:Josh Downs
# 0          93784-129305:Josh Downs         93784-29685:Robert Woods
# 0  93784-69213:Michael Pittman Jr.        93784-71143:Kylen Granson
#
#                                  4
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0        93784-71143:Kylen Granson
# 0                         Matt Gay
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0         93784-91419:Nico Collins
# 0        93784-86055:Dameon Pierce
# 0                 Ka'imi Fairbairn
# 0                         Matt Gay
# 0                         Matt Gay
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0     93784-70603:Devin Singletary
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0     93784-70603:Devin Singletary
# 0                 Ka'imi Fairbairn
# 0         93784-129471:C.J. Stroud
# 0        93784-71143:Kylen Granson
# 0                 Ka'imi Fairbairn
# 0                         Matt Gay
# 0                         Matt Gay
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0                 Ka'imi Fairbairn
# 0            93784-70027:Zack Moss
# 0        93784-71143:Kylen Granson
# 0        93784-71143:Kylen Granson
# 0                 Ka'imi Fairbairn
# 0                         Matt Gay
# 0                         Matt Gay
# 0                         Matt Gay
# 0          93784-86312:Alec Pierce
# 0                         Matt Gay
# 0          93784-86312:Alec Pierce
# 0        93784-86055:Dameon Pierce
# 0                 Ka'imi Fairbairn
# 0          93784-24533:Mo Alie-Cox
# 0         93784-29685:Robert Woods
# 0                 Ka'imi Fairbairn
# 0  93784-129315:Anthony Richardson
# 0  93784-69213:Michael Pittman Jr.
# 0         93784-91419:Nico Collins

# %%
#test_df.to_csv('backtest_wk9_thu_phi_hou_predicted_lineups.csv')
#test_df.to_csv('2023_wk2_thu_phi_min_predicted_lineups.csv')

# %%
# if (len(test_df) < 150):
#     n = len(test_df)
# else:
#     n = len(test_df)
# test_df.head(n).to_csv('week11_gb_ten_test.csv')
