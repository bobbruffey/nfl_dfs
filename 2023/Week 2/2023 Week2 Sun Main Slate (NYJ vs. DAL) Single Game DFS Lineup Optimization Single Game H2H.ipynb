# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def single_game_player_df(week, year, day, file_name,
                         #qb_file, rb_file, wr_file,
                         #te_file, def_file,
                         team1,
                         team2):

    
    fanduel = pd.read_csv(file_name)
    fanduel = fanduel[fanduel['keep']=='x']
    fanduel = fanduel[(fanduel['Injury Indicator'] != 'IR') &
                  (fanduel['Injury Indicator'] != 'O') &
                  (fanduel['Injury Indicator'] != 'D')]
    fanduel2 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel2 = fanduel2[fanduel2['Position'] != 'D']
    fanduel2['player_wk_year'] = fanduel2['Nickname'] + " " + week + " " + year

    fanduel3 = fanduel[['Player ID + Player Name', 'Nickname','Position', 'Team',
                    'Salary', 'Injury Indicator','FPPG','Tier']]
    fanduel3 = fanduel3[fanduel3['Position'] == 'D']
    fanduel3['player_wk_year'] = fanduel3['Team'] + " " + week + " " + year

    fanduel4 = fanduel2.append(fanduel3)
    fanduel4 = fanduel4[['Player ID + Player Name', 'Position', 
                     'Team','Salary', 'Injury Indicator',
                    'player_wk_year','FPPG','Tier']]
    #fanduel4.sort_values(by = 'Salary', ascending = False)

    fanduel4['pos_rank'] = fanduel4.groupby(['Team','Position'])['Salary'].rank(ascending = False).astype(int)
    fanduel4['pos_rank'] = fanduel4['Position'] + fanduel4['pos_rank'].astype(str)

    fanduel5 = fanduel4[fanduel4['pos_rank'].isin(['QB1','RB1','RB2','RB3','WR1',
                                               'WR2','WR3','WR4','WR5',
                                              'TE1','TE2','TE3','D1','K1'])]

#     qb_df = pd.read_csv(qb_file)
#     qb_df['position'] = 'qb'
#     rb_df = pd.read_csv(rb_file)
#     rb_df['position'] = 'rb'
#     wr_df = pd.read_csv(wr_file)
#     wr_df['position'] = 'wr'
#     te_df = pd.read_csv(te_file)
#     te_df['position'] = 'te'
#     def_df = pd.read_csv(def_file)
#     def_df['position'] = 'def'
#     def_df = def_df.rename(columns = {'team_wk_year':'player_wk_year'})

#     df = qb_df.append(rb_df)
#     df = df.append(wr_df)
#     df = df.append(te_df)
#     df = df.append(def_df)

#     df = df.reset_index()
#     df = df.drop(columns = ['Unnamed: 0', 'index'])

#     df = df[(df['team_wk_year'].str.contains(team1)) |
#             (df['team_wk_year'].str.contains(team2))]
#     df_final = pd.merge(fanduel5, df, how = 'left', 
#                     on = 'player_wk_year', suffixes = (None, None))

    #df_final['Prob2'] = df_final[['FPPG', 'Prob']].mean(skipna=True, axis = 1)
    #df_final['Prob2'] = df_final['FPPG']
    df_final = fanduel5
    df_final['Prob2'] = df_final['Tier']
    df_final = df_final.drop_duplicates(subset = 'player_wk_year', keep = 'last')
    df_final = df_final.sort_values(by = 'Prob2', ascending = False)

    return df_final

# %%
#team1 = fav
#team2 = underdog
df_final = single_game_player_df(week = '2',
                        year = '2023',
                        day = 'Sun',
                        file_name = '2023_week2_sun_main_single_game_players.csv',
#                         qb_file = 'week9_scored_qb.csv',
#                         rb_file = 'week9_scored_rb.csv',
#                         wr_file = 'week9_scored_wr.csv',
#                         te_file = 'week9_scored_te.csv',
#                         def_file = 'week9_scored_def.csv',
                        team1 = 'DAL',
                        team2 = 'NYJ')

df_final = df_final[(df_final['Team'] == 'DAL') |
                     (df_final['Team'] == 'NYJ')]

# %%
df_final = df_final[['Player ID + Player Name','Position', 'Team', 'Salary',
                    'player_wk_year','Prob2','Tier']]#,'FPPG','Prob']]

# %%
df_final
# Out:
#           Player ID + Player Name Position Team  Salary  \
# 64     93784-12530:Dallas Cowboys        D  DAL   10000
# 75                 Brandon Aubrey        K  DAL    9000
# 6         93784-86631:CeeDee Lamb       WR  DAL   14000
# 3        93784-63759:Tony Pollard       RB  DAL   16000
# 76      93784-12544:New York Jets        D  NYJ    9500
# 14       93784-103064:Breece Hall       RB  NYJ   13500
# 11    93784-103564:Garrett Wilson       WR  NYJ   14500
# 10       93784-31716:Dak Prescott       QB  DAL   15500
# 49      93784-89680:Jake Ferguson       TE  DAL    7500
# 48      93784-60451:Tyler Conklin       TE  NYJ    7500
# 15        93784-54140:Dalvin Cook       RB  NYJ   11500
# 26        93784-90406:Zach Wilson       QB  NYJ   13000
# 31     93784-69956:Michael Gallup       WR  DAL    8500
# 33       93784-56809:Allen Lazard       WR  NYJ    8500
# 34        93784-72297:Rico Dowdle       RB  DAL    8000
# 71    93784-60957:KaVontae Turpin       WR  DAL    6000
# 60        93784-31207:C.J. Uzomah       TE  NYJ    6500
# 39     93784-93539:Michael Carter       RB  NYJ    7000
# 52       93784-14257:Randall Cobb       WR  NYJ    6500
# 65  93784-88816:Peyton Hendershot       TE  DAL    5000
#
#               player_wk_year  Prob2  Tier
# 64                DAL 2 2023    5.0   5.0
# 75     Brandon Aubrey 2 2023    5.0   5.0
# 6         CeeDee Lamb 2 2023    5.0   5.0
# 3        Tony Pollard 2 2023    5.0   5.0
# 76                NYJ 2 2023    4.0   4.0
# 14        Breece Hall 2 2023    4.0   4.0
# 11     Garrett Wilson 2 2023    4.0   4.0
# 10       Dak Prescott 2 2023    4.0   4.0
# 49      Jake Ferguson 2 2023    3.0   3.0
# 48      Tyler Conklin 2 2023    3.0   3.0
# 15        Dalvin Cook 2 2023    3.0   3.0
# 26        Zach Wilson 2 2023    3.0   3.0
# 31     Michael Gallup 2 2023    3.0   3.0
# 33       Allen Lazard 2 2023    3.0   3.0
# 34        Rico Dowdle 2 2023    2.0   2.0
# 71    KaVontae Turpin 2 2023    2.0   2.0
# 60        C.J. Uzomah 2 2023    1.0   1.0
# 39     Michael Carter 2 2023    1.0   1.0
# 52       Randall Cobb 2 2023    1.0   1.0
# 65  Peyton Hendershot 2 2023    1.0   1.0

# %%
def create_single_game_simulations(df_final, team1, team2, 
                                   team1_pos, team2_pos
                                  # outcomes
                                  ):#,
                                 # players1, players2,
                                 # players3, players4):
    print('team1:')
    print(team1)
    print('team2:')
    print(team2)
    result = pd.DataFrame() 
    team1_df = df_final[df_final['Team'] == team1]
    team1_df['pos_rank'] = team1_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team1_df['pos_rank'] = team1_df['Position'] + team1_df['pos_rank'].astype(str)
    team2_df = df_final[df_final['Team'] == team2]
    team2_df['pos_rank'] = team2_df.groupby('Position')['Salary'].rank(ascending = False).astype(int)
    team2_df['pos_rank'] = team2_df['Position'] + team2_df['pos_rank'].astype(str)
    
    
    #outcomes = ['HL',
    #            'HM',
    #            'HH',
    #            'ML',
    #            'MM',
    #            'MH'#,
                #'LL',
                #'LM',
                #'LH'
     #          ]
    
    #for outcome in outcomes:
    #    print(outcome)
    #    if (outcome == 'HL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','QB1','RB1','WR1'])]
    #    elif (outcome == 'HM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'TE1','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','K1'])]
    #    elif (outcome == 'HH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','WR3',
    #                                                        'WR4','WR5','TE1','TE2','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3','TE1'
    #                                                    ])]
    #    elif (outcome == 'ML'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','D1','K1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','K1'])]
    #    elif (outcome == 'MM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','WR1','WR2','TE1',
    #                                                        'WR3','D1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2'])]
    #    elif (outcome == 'MH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['QB1','RB1','RB2','TE1','WR1','WR2',
    #                                                       'WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['QB1','RB1','WR1','WR2','WR3'])]
    #    elif (outcome == 'LL'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['D1','K1','RB1','QB1','RB2','WR1','WR2','TE1'])]
    #    elif (outcome == 'LM'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2',
    #                                                       'WR1','WR2','WR3'])]
    #    elif (outcome == 'LH'):
    #        team1_df2 = team1_df[team1_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1','TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
    #        team2_df2 = team2_df[team2_df['pos_rank'].isin(['K1','D1','QB1','RB1','RB2','TE1', 'TE2',
    #                                                       'WR1','WR2','WR3','WR4','WR5'])]
 
    team1_df2 = team1_df[team1_df['pos_rank'].isin(team1_pos)]
    team2_df2 = team2_df[team2_df['pos_rank'].isin(team2_pos)]
    
    team1_team2 = team1_df2.append(team2_df2)
    df_final_qb = team1_team2.sort_values('Prob2',ascending= False)
    df1 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df1 = df1.rename(columns = {'Player ID + Player Name':'flex1',
                                             'Salary':'flex1_sal','Prob2':'flex1_prob'})
    df2 = df_final_qb[['Player ID + Player Name', 'Team','Salary', 'Prob2']]
    df2 = df2.rename(columns = {'Player ID + Player Name':'flex2',
                                             'Salary':'flex2_sal','Prob2':'flex2_prob'})
    df3 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df3 = df3.rename(columns = {'Player ID + Player Name':'flex3',
                                            'Salary':'flex3_sal','Prob2':'flex3_prob'})
    df4 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df4 = df4.rename(columns = {'Player ID + Player Name':'flex4',
                                             'Salary':'flex4_sal','Prob2':'flex4_prob'})
    df5 = df_final_qb[['Player ID + Player Name','Team', 'Salary', 'Prob2']]
    df5 = df5.rename(columns = {'Player ID + Player Name':'flex5',
                                             'Salary':'flex5_sal','Prob2':'flex5_prob'})

    sim_df = pd.merge(df1, df2, how = 'cross')
    sim_df = pd.merge(sim_df, df3, how = 'cross')
    sim_df = pd.merge(sim_df, df4, how = 'cross')
    sim_df = pd.merge(sim_df, df5, how = 'cross')
        
        
    sim_df = sim_df[(sim_df['flex1'] != sim_df['flex2']) & (sim_df['flex1'] != sim_df['flex3']) &
                (sim_df['flex1'] != sim_df['flex4']) & (sim_df['flex1'] != sim_df['flex5']) &
                (sim_df['flex2'] != sim_df['flex3']) & (sim_df['flex2'] != sim_df['flex4']) &
                (sim_df['flex2'] != sim_df['flex5']) & (sim_df['flex3'] != sim_df['flex4']) &
                (sim_df['flex3'] != sim_df['flex5']) & (sim_df['flex4'] != sim_df['flex5'])]

    sim_df['total_salary'] = sim_df['flex1_sal'] + sim_df['flex2_sal'] + sim_df['flex3_sal'] + sim_df['flex4_sal'] + sim_df['flex5_sal']
    sim_df['total_proj'] = sim_df['flex1_prob'] + sim_df['flex2_prob'] + sim_df['flex3_prob'] + sim_df['flex4_prob'] + sim_df['flex5_prob']

    sim_df = sim_df[sim_df['total_salary'] <= 60000]
    sim_df = sim_df[sim_df['total_salary'] > 57000]
    #if (len(sim_df) == 0):
    #    continue

    final= sim_df[['flex1', 'flex2', 'flex3', 'flex4', 'flex5','total_proj']]
    final['total_proj'] = final['total_proj'].astype(str)
        #final['total_salary'] = final['total_salary'].astype(str)
    print(len(final))
    n = len(final)
       # if (len(final) < 10000):
       #     n = len(final)
       # else:
       #     n = 10000
    final2 = pd.DataFrame()
    for i in range(0,n):
          #  print(i)
        l = final.iloc[i,:].values.tolist()
            #print(l)
        l.sort()
           # if ((players1 in l) |
           #     (players2 in l) |
           #    (players3 in l) |
           #     (players4 in l)
           #    ):
               # print(l)
        temp = pd.DataFrame([l])
            
        final2 = final2.append(temp)
            
    final2 = final2.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
        
    df_team_check = df_final_qb[['Player ID + Player Name','Team']]
        
    for i in range(1,6):
        print(i)
        final2 = pd.merge(final2, df_team_check, how = 'inner', left_on = i,
                          right_on = 'Player ID + Player Name',
                          suffixes = (None,None))
        team_col = 'Team' + str(i)
        final2[team_col] = final2['Team']
        final2 = final2.drop(columns = ['Team','Player ID + Player Name'])
    keep_list = []
    team1_v_team2 = []
    for i in range(0,len(final2)):
        team1_count = 0
        team2_count = 0
            #keep_list = []
        teams = final2[['Team1','Team2','Team3','Team4','Team5']]
        l = teams.iloc[i,:].values.tolist()
            #print(l)
        for j in l:
             #   print(j)
                
            if (j == team1):
                team1_count = team1_count + 1
            elif (j == team2):
                team2_count = team2_count + 1
             #   print(team1_count)
             #   print(team2_count)
        if ((team1_count > 4) | (team2_count > 4)):
            keep = 'No'
        else:
            keep = 'Yes'
                
        if ((team1_count == 2) & (team2_count == 3)):
            team1_team2 = '2:3'
        elif ((team1_count == 3) & (team2_count == 2)):
            team1_team2 = '3:2'
        elif ((team1_count == 4) & (team2_count == 1)):
            team1_team2 = '4:1'
        elif ((team1_count == 1) & (team2_count == 4)):
            team1_team2 = '1:4'
        else:
            team1_team2 = 'none'
                
          #  print(keep)
        keep_list.append(keep)
        team1_v_team2.append(team1_team2)
            #print(keep_list)
    final2['keep'] = keep_list
    final2['team1_team2_count'] = team1_v_team2
               
       # if(len(final2) < 33):
       #     m = len(final2)
       # else: 
       #     m = 33
       # final2 = final2.head(m)
    result = result.append(final2)
    
    result = result[result['keep'] == 'Yes']
    #result = result[[0,1,2,3,4,5]]
    result = result.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')

    
    return result

# %%
#fav: DAL
#spread: -8.6
#o/u: 49
#team1 =favorite
#team2 =underdog

test = create_single_game_simulations(df_final = df_final,
                                      team1 = 'DAL',
                                      team2 = 'NYJ',
                                      team1_pos = ['QB1','RB1','RB2','TE1','TE2',
                                                  'WR1','WR2','WR3',
                                                   'K1','D1'],
                                      team2_pos = ['QB1','RB1','RB2','RB3',
                                                   'TE1','TE2',
                                                   'WR1','WR2','WR3',
                                                   'K1','D1'])
                                      #outcomes = ['LH']#,
                                   #  players1 = '81393-22015:Russell Wilson',
                                   #  players2 = '81393-69213:Michael Pittman Jr.',
                                   #  players3 = '81393-6616:Matt Ryan',
                                  # #  players4 = "81556-85701:Ja'Marr Chase"
                                   #  )
# Out:
# team1:
# DAL
# team2:
# NYJ
# 130800
# 1
# 2
# 3
# 4
# 5

# %%
test.shape
# Out:
# (1069, 13)

# %%
test = test.drop_duplicates(subset = [1,2,3,4,5], keep = 'first')
test.to_csv('2023_week2_nyj_dal_all_predicted_lineups.csv')

# %%
test.sort_values(0, ascending = False).head(50)
# Out:
#          0                            1                            2  \
# 0     24.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 198   23.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 174   23.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 12    23.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 1     23.0   93784-12530:Dallas Cowboys     93784-56809:Allen Lazard
# 197   23.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 42    22.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 212   22.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 213   22.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 124   22.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 192   22.0   93784-12530:Dallas Cowboys     93784-31716:Dak Prescott
# 82    22.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 832   22.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 151   22.0     93784-103064:Breece Hall     93784-63759:Tony Pollard
# 25    22.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 24    22.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 22    22.0   93784-12530:Dallas Cowboys     93784-31716:Dak Prescott
# 180   22.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 186   22.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 761   22.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 176   22.0   93784-12530:Dallas Cowboys     93784-31716:Dak Prescott
# 3     22.0    93784-12544:New York Jets      93784-54140:Dalvin Cook
# 10    22.0     93784-103064:Breece Hall    93784-60451:Tyler Conklin
# 1009  21.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 462   21.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 155   21.0     93784-103064:Breece Hall  93784-103564:Garrett Wilson
# 145   21.0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 1010  21.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 80    21.0   93784-12530:Dallas Cowboys      93784-54140:Dalvin Cook
# 121   21.0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 1008  21.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 1026  21.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 153   21.0     93784-103064:Breece Hall     93784-31716:Dak Prescott
# 71    21.0    93784-60451:Tyler Conklin     93784-63759:Tony Pollard
# 70    21.0     93784-103064:Breece Hall    93784-12544:New York Jets
# 69    21.0  93784-103564:Garrett Wilson    93784-12544:New York Jets
# 983   21.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 998   21.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 206   21.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 208   21.0     93784-103064:Breece Hall  93784-103564:Garrett Wilson
# 393   21.0   93784-12530:Dallas Cowboys      93784-54140:Dalvin Cook
# 118   21.0  93784-103564:Garrett Wilson    93784-12544:New York Jets
# 177   21.0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 117   21.0     93784-103064:Breece Hall  93784-103564:Garrett Wilson
# 175   21.0  93784-103564:Garrett Wilson    93784-12544:New York Jets
# 181   21.0     93784-103064:Breece Hall    93784-12544:New York Jets
# 763   21.0   93784-12530:Dallas Cowboys      93784-54140:Dalvin Cook
# 426   21.0     93784-103064:Breece Hall  93784-103564:Garrett Wilson
# 125   21.0  93784-103564:Garrett Wilson   93784-12530:Dallas Cowboys
# 112   21.0     93784-63759:Tony Pollard      93784-86631:CeeDee Lamb
#
#                                3                           4  \
# 0       93784-63759:Tony Pollard     93784-86631:CeeDee Lamb
# 198    93784-12544:New York Jets    93784-63759:Tony Pollard
# 174     93784-31716:Dak Prescott    93784-63759:Tony Pollard
# 12      93784-31716:Dak Prescott     93784-86631:CeeDee Lamb
# 1       93784-63759:Tony Pollard     93784-86631:CeeDee Lamb
# 197    93784-12544:New York Jets    93784-63759:Tony Pollard
# 42      93784-63759:Tony Pollard     93784-90406:Zach Wilson
# 212    93784-12544:New York Jets    93784-31716:Dak Prescott
# 213    93784-12544:New York Jets    93784-31716:Dak Prescott
# 124     93784-63759:Tony Pollard  93784-69956:Michael Gallup
# 192    93784-60451:Tyler Conklin    93784-63759:Tony Pollard
# 82       93784-86631:CeeDee Lamb     93784-90406:Zach Wilson
# 832     93784-56809:Allen Lazard    93784-63759:Tony Pollard
# 151      93784-86631:CeeDee Lamb   93784-89680:Jake Ferguson
# 25       93784-54140:Dalvin Cook     93784-86631:CeeDee Lamb
# 24       93784-54140:Dalvin Cook     93784-86631:CeeDee Lamb
# 22       93784-54140:Dalvin Cook     93784-86631:CeeDee Lamb
# 180     93784-56809:Allen Lazard    93784-63759:Tony Pollard
# 186      93784-54140:Dalvin Cook    93784-63759:Tony Pollard
# 761     93784-63759:Tony Pollard  93784-69956:Michael Gallup
# 176     93784-56809:Allen Lazard    93784-63759:Tony Pollard
# 3       93784-63759:Tony Pollard     93784-86631:CeeDee Lamb
# 10      93784-63759:Tony Pollard     93784-86631:CeeDee Lamb
# 1009   93784-12544:New York Jets    93784-56809:Allen Lazard
# 462    93784-12544:New York Jets    93784-63759:Tony Pollard
# 155      93784-86631:CeeDee Lamb   93784-89680:Jake Ferguson
# 145     93784-63759:Tony Pollard   93784-89680:Jake Ferguson
# 1010    93784-31716:Dak Prescott   93784-60451:Tyler Conklin
# 80       93784-86631:CeeDee Lamb     93784-90406:Zach Wilson
# 121     93784-63759:Tony Pollard  93784-69956:Michael Gallup
# 1008   93784-12544:New York Jets    93784-56809:Allen Lazard
# 1026   93784-12544:New York Jets   93784-60451:Tyler Conklin
# 153      93784-86631:CeeDee Lamb   93784-89680:Jake Ferguson
# 71       93784-86631:CeeDee Lamb     93784-90406:Zach Wilson
# 70       93784-86631:CeeDee Lamb     93784-90406:Zach Wilson
# 69       93784-86631:CeeDee Lamb     93784-90406:Zach Wilson
# 983    93784-12544:New York Jets    93784-63759:Tony Pollard
# 998     93784-31716:Dak Prescott    93784-56809:Allen Lazard
# 206     93784-31716:Dak Prescott     93784-54140:Dalvin Cook
# 208   93784-12530:Dallas Cowboys     93784-54140:Dalvin Cook
# 393     93784-63759:Tony Pollard     93784-86631:CeeDee Lamb
# 118     93784-63759:Tony Pollard  93784-69956:Michael Gallup
# 177     93784-56809:Allen Lazard    93784-63759:Tony Pollard
# 117   93784-12530:Dallas Cowboys     93784-90406:Zach Wilson
# 175     93784-56809:Allen Lazard    93784-63759:Tony Pollard
# 181      93784-54140:Dalvin Cook    93784-63759:Tony Pollard
# 763     93784-63759:Tony Pollard  93784-69956:Michael Gallup
# 426   93784-12530:Dallas Cowboys     93784-86631:CeeDee Lamb
# 125     93784-31716:Dak Prescott  93784-69956:Michael Gallup
# 112    93784-89680:Jake Ferguson     93784-90406:Zach Wilson
#
#                                5 Team1 Team2 Team3 Team4 Team5 keep  \
# 0                 Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 198               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 174               Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 12                Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 1                 Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 197               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 42                Brandon Aubrey   DAL   NYJ   DAL   NYJ   DAL  Yes
# 212               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 213               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 124               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 192               Brandon Aubrey   DAL   DAL   NYJ   DAL   DAL  Yes
# 82                Brandon Aubrey   NYJ   DAL   DAL   NYJ   DAL  Yes
# 832      93784-86631:CeeDee Lamb   DAL   NYJ   NYJ   DAL   DAL  Yes
# 151               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 25                Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 24                Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 22                Brandon Aubrey   DAL   DAL   NYJ   DAL   DAL  Yes
# 180               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 186               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 761      93784-86631:CeeDee Lamb   DAL   NYJ   DAL   DAL   DAL  Yes
# 176               Brandon Aubrey   DAL   DAL   NYJ   DAL   DAL  Yes
# 3                 Brandon Aubrey   NYJ   NYJ   DAL   DAL   DAL  Yes
# 10                Brandon Aubrey   NYJ   NYJ   DAL   DAL   DAL  Yes
# 1009    93784-63759:Tony Pollard   NYJ   DAL   NYJ   NYJ   DAL  Yes
# 462    93784-89680:Jake Ferguson   NYJ   DAL   NYJ   DAL   DAL  Yes
# 155               Brandon Aubrey   NYJ   NYJ   DAL   DAL   DAL  Yes
# 145               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 1010    93784-63759:Tony Pollard   DAL   NYJ   DAL   NYJ   DAL  Yes
# 80                Brandon Aubrey   DAL   NYJ   DAL   NYJ   DAL  Yes
# 121               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 1008    93784-63759:Tony Pollard   NYJ   DAL   NYJ   NYJ   DAL  Yes
# 1026    93784-63759:Tony Pollard   NYJ   DAL   NYJ   NYJ   DAL  Yes
# 153               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 71                Brandon Aubrey   NYJ   DAL   DAL   NYJ   DAL  Yes
# 70                Brandon Aubrey   NYJ   NYJ   DAL   NYJ   DAL  Yes
# 69                Brandon Aubrey   NYJ   NYJ   DAL   NYJ   DAL  Yes
# 983   93784-69956:Michael Gallup   NYJ   DAL   NYJ   DAL   DAL  Yes
# 998     93784-63759:Tony Pollard   DAL   NYJ   DAL   NYJ   DAL  Yes
# 206               Brandon Aubrey   NYJ   DAL   DAL   NYJ   DAL  Yes
# 208               Brandon Aubrey   NYJ   NYJ   DAL   NYJ   DAL  Yes
# 393    93784-89680:Jake Ferguson   DAL   NYJ   DAL   DAL   DAL  Yes
# 118               Brandon Aubrey   NYJ   NYJ   DAL   DAL   DAL  Yes
# 177               Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 117               Brandon Aubrey   NYJ   NYJ   DAL   NYJ   DAL  Yes
# 175               Brandon Aubrey   NYJ   NYJ   NYJ   DAL   DAL  Yes
# 181               Brandon Aubrey   NYJ   NYJ   NYJ   DAL   DAL  Yes
# 763      93784-86631:CeeDee Lamb   DAL   NYJ   DAL   DAL   DAL  Yes
# 426    93784-89680:Jake Ferguson   NYJ   NYJ   DAL   DAL   DAL  Yes
# 125               Brandon Aubrey   NYJ   DAL   DAL   DAL   DAL  Yes
# 112               Brandon Aubrey   DAL   DAL   DAL   NYJ   DAL  Yes
#
#      team1_team2_count
# 0                  4:1
# 198                3:2
# 174                4:1
# 12                 4:1
# 1                  4:1
# 197                3:2
# 42                 3:2
# 212                3:2
# 213                3:2
# 124                4:1
# 192                4:1
# 82                 3:2
# 832                3:2
# 151                4:1
# 25                 3:2
# 24                 3:2
# 22                 4:1
# 180                3:2
# 186                3:2
# 761                4:1
# 176                4:1
# 3                  3:2
# 10                 3:2
# 1009               2:3
# 462                3:2
# 155                3:2
# 145                4:1
# 1010               3:2
# 80                 3:2
# 121                4:1
# 1008               2:3
# 1026               2:3
# 153                4:1
# 71                 3:2
# 70                 2:3
# 69                 2:3
# 983                3:2
# 998                3:2
# 206                3:2
# 208                2:3
# 393                4:1
# 118                3:2
# 177                3:2
# 117                2:3
# 175                2:3
# 181                2:3
# 763                4:1
# 426                3:2
# 125                4:1
# 112                4:1

# %%
#vegas odds:
#fav: PHI
#spread: -6.5
#o/u: 49

# %%
#team1 = BUF, so as heavy fav we will subset only 4:1 and 3:2
#fav should always get a '4:1'
team_ratio = ['4:1','3:2']#,'2:3','1:4']

# %%
test = test.sort_values(0, ascending = False)#.head(150)
test2 = test[test['team1_team2_count'].isin(team_ratio)]

# %%
test2#.to_csv('thu_night_wk13_lineups_test.csv')
# Out:
#         0                            1                            2  \
# 0    24.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 198  23.0     93784-103064:Breece Hall   93784-12530:Dallas Cowboys
# 174  23.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 12   23.0   93784-12530:Dallas Cowboys    93784-12544:New York Jets
# 1    23.0   93784-12530:Dallas Cowboys     93784-56809:Allen Lazard
# ..    ...                          ...                          ...
# 241  15.0  93784-103564:Garrett Wilson      93784-31207:C.J. Uzomah
# 934  15.0      93784-31207:C.J. Uzomah     93784-31716:Dak Prescott
# 300  15.0     93784-31716:Dak Prescott  93784-60957:KaVontae Turpin
# 335  15.0     93784-31716:Dak Prescott     93784-63759:Tony Pollard
# 325  15.0     93784-31716:Dak Prescott      93784-72297:Rico Dowdle
#
#                              3                         4  \
# 0     93784-63759:Tony Pollard   93784-86631:CeeDee Lamb
# 198  93784-12544:New York Jets  93784-63759:Tony Pollard
# 174   93784-31716:Dak Prescott  93784-63759:Tony Pollard
# 12    93784-31716:Dak Prescott   93784-86631:CeeDee Lamb
# 1     93784-63759:Tony Pollard   93784-86631:CeeDee Lamb
# ..                         ...                       ...
# 241   93784-31716:Dak Prescott  93784-63759:Tony Pollard
# 934    93784-54140:Dalvin Cook  93784-63759:Tony Pollard
# 300   93784-63759:Tony Pollard   93784-90406:Zach Wilson
# 335    93784-72297:Rico Dowdle   93784-90406:Zach Wilson
# 325    93784-86631:CeeDee Lamb   93784-90406:Zach Wilson
#
#                                  5 Team1 Team2 Team3 Team4 Team5 keep  \
# 0                   Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 198                 Brandon Aubrey   NYJ   DAL   NYJ   DAL   DAL  Yes
# 174                 Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 12                  Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# 1                   Brandon Aubrey   DAL   NYJ   DAL   DAL   DAL  Yes
# ..                             ...   ...   ...   ...   ...   ...  ...
# 241  93784-88816:Peyton Hendershot   NYJ   NYJ   DAL   DAL   DAL  Yes
# 934        93784-72297:Rico Dowdle   NYJ   DAL   NYJ   DAL   DAL  Yes
# 300     93784-93539:Michael Carter   DAL   DAL   DAL   NYJ   NYJ  Yes
# 335     93784-93539:Michael Carter   DAL   DAL   DAL   NYJ   NYJ  Yes
# 325     93784-93539:Michael Carter   DAL   DAL   DAL   NYJ   NYJ  Yes
#
#     team1_team2_count
# 0                 4:1
# 198               3:2
# 174               4:1
# 12                4:1
# 1                 4:1
# ..                ...
# 241               3:2
# 934               3:2
# 300               3:2
# 335               3:2
# 325               3:2
#
# [550 rows x 13 columns]

# %%
df_final
# Out:
#           Player ID + Player Name Position Team  Salary  \
# 64     93784-12530:Dallas Cowboys        D  DAL   10000
# 75                 Brandon Aubrey        K  DAL    9000
# 6         93784-86631:CeeDee Lamb       WR  DAL   14000
# 3        93784-63759:Tony Pollard       RB  DAL   16000
# 76      93784-12544:New York Jets        D  NYJ    9500
# 14       93784-103064:Breece Hall       RB  NYJ   13500
# 11    93784-103564:Garrett Wilson       WR  NYJ   14500
# 10       93784-31716:Dak Prescott       QB  DAL   15500
# 49      93784-89680:Jake Ferguson       TE  DAL    7500
# 48      93784-60451:Tyler Conklin       TE  NYJ    7500
# 15        93784-54140:Dalvin Cook       RB  NYJ   11500
# 26        93784-90406:Zach Wilson       QB  NYJ   13000
# 31     93784-69956:Michael Gallup       WR  DAL    8500
# 33       93784-56809:Allen Lazard       WR  NYJ    8500
# 34        93784-72297:Rico Dowdle       RB  DAL    8000
# 71    93784-60957:KaVontae Turpin       WR  DAL    6000
# 60        93784-31207:C.J. Uzomah       TE  NYJ    6500
# 39     93784-93539:Michael Carter       RB  NYJ    7000
# 52       93784-14257:Randall Cobb       WR  NYJ    6500
# 65  93784-88816:Peyton Hendershot       TE  DAL    5000
#
#               player_wk_year  Prob2  Tier
# 64                DAL 2 2023    5.0   5.0
# 75     Brandon Aubrey 2 2023    5.0   5.0
# 6         CeeDee Lamb 2 2023    5.0   5.0
# 3        Tony Pollard 2 2023    5.0   5.0
# 76                NYJ 2 2023    4.0   4.0
# 14        Breece Hall 2 2023    4.0   4.0
# 11     Garrett Wilson 2 2023    4.0   4.0
# 10       Dak Prescott 2 2023    4.0   4.0
# 49      Jake Ferguson 2 2023    3.0   3.0
# 48      Tyler Conklin 2 2023    3.0   3.0
# 15        Dalvin Cook 2 2023    3.0   3.0
# 26        Zach Wilson 2 2023    3.0   3.0
# 31     Michael Gallup 2 2023    3.0   3.0
# 33       Allen Lazard 2 2023    3.0   3.0
# 34        Rico Dowdle 2 2023    2.0   2.0
# 71    KaVontae Turpin 2 2023    2.0   2.0
# 60        C.J. Uzomah 2 2023    1.0   1.0
# 39     Michael Carter 2 2023    1.0   1.0
# 52       Randall Cobb 2 2023    1.0   1.0
# 65  Peyton Hendershot 2 2023    1.0   1.0

# %%
def create_mvp_lineups(test_df,
                       df_final,
                       team_ratios,
                      counts,
                      mvps):

    test_df = pd.DataFrame()
    team1_team2 = team_ratios #['4:1','4:1','4:1' ,'4:1', '3:2','3:2','3:2','3:2']
    count = counts #[40,20,10,5,40,20,10,15]
    mvp = mvps #['84053-62239:Josh Allen','84053-25079:Stefon Diggs', '84053-12526:Buffalo Bills','84053-6642:Nick Folk',
      #'84053-62239:Josh Allen','84053-25079:Stefon Diggs',
      #'84053-111540:Rhamondre Stevenson','84053-90584:Mac Jones']
    n = len(team1_team2)

    for z in range(0,n):
    
        teams = team1_team2[z]
        counts = count[z]
        mvps_filter = mvp[z]
        print(teams)
        test_new = test2[test2['team1_team2_count'] == teams]#.head(counts)
        print(len(test_new))
        #x = 0
       # while(x < counts):
        j = 0
        for pos in range(0,len(test_new)):
        #j = 0
        #pos = 0
        #while ((j <= counts) or (pos < len(test_new)) ):
        
            df_final_mvp = df_final['Player ID + Player Name'][df_final['Player ID + Player Name'].isin([mvps_filter])].values.tolist()
            df_final_1 = df_final['Player ID + Player Name'].values.tolist()
            df_final_2 = df_final['Player ID + Player Name'].values.tolist()
            df_final_3 = df_final['Player ID + Player Name'].values.tolist()
            df_final_4 = df_final['Player ID + Player Name'].values.tolist()

            l = test_new.iloc[pos, :].values.tolist()


            l_mvp = []
            l_1 = []
            l_2 = []
            l_3 = []
            l_4 = []

            for i in range(1,6):
               # print(l[i])
                if ((l[i] in df_final_mvp) & (len(l_mvp) < 1)):
                    l_mvp = l[i]
                    df_final_mvp.remove(l[i])
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])

                elif ((l[i] in (df_final_1)) & (len(l_1) < 1)):
                    l_1 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                    
                elif ((l[i] in (df_final_2)) & (len(l_2) < 1)):
                    l_2 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_3)) & (len(l_3) < 1)):
                    l_3 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
                elif ((l[i] in (df_final_4)) & (len(l_4) < 1)):
                    l_4 = l[i]
                    df_final_1.remove(l[i])
                    df_final_2.remove(l[i])
                    df_final_3.remove(l[i])
                    df_final_4.remove(l[i])
            
            final_l = [l_mvp, l_1, l_2, l_3, l_4]
            final_l = pd.DataFrame([final_l])
            if (len(l_mvp) > 2):
               # pos = pos + 1
                j = j + 1
            else:
              #  pos = pos + 1
                j = j
           # print(pos)
            #print(final_l)
            test_df = test_df.append(final_l)
            test_df = test_df[test_df[0].str.len() > 2]
            if (j == counts):
                break

            
    return test_df

# %%
df_final
# Out:
#           Player ID + Player Name Position Team  Salary  \
# 64     93784-12530:Dallas Cowboys        D  DAL   10000
# 75                 Brandon Aubrey        K  DAL    9000
# 6         93784-86631:CeeDee Lamb       WR  DAL   14000
# 3        93784-63759:Tony Pollard       RB  DAL   16000
# 76      93784-12544:New York Jets        D  NYJ    9500
# 14       93784-103064:Breece Hall       RB  NYJ   13500
# 11    93784-103564:Garrett Wilson       WR  NYJ   14500
# 10       93784-31716:Dak Prescott       QB  DAL   15500
# 49      93784-89680:Jake Ferguson       TE  DAL    7500
# 48      93784-60451:Tyler Conklin       TE  NYJ    7500
# 15        93784-54140:Dalvin Cook       RB  NYJ   11500
# 26        93784-90406:Zach Wilson       QB  NYJ   13000
# 31     93784-69956:Michael Gallup       WR  DAL    8500
# 33       93784-56809:Allen Lazard       WR  NYJ    8500
# 34        93784-72297:Rico Dowdle       RB  DAL    8000
# 71    93784-60957:KaVontae Turpin       WR  DAL    6000
# 60        93784-31207:C.J. Uzomah       TE  NYJ    6500
# 39     93784-93539:Michael Carter       RB  NYJ    7000
# 52       93784-14257:Randall Cobb       WR  NYJ    6500
# 65  93784-88816:Peyton Hendershot       TE  DAL    5000
#
#               player_wk_year  Prob2  Tier
# 64                DAL 2 2023    5.0   5.0
# 75     Brandon Aubrey 2 2023    5.0   5.0
# 6         CeeDee Lamb 2 2023    5.0   5.0
# 3        Tony Pollard 2 2023    5.0   5.0
# 76                NYJ 2 2023    4.0   4.0
# 14        Breece Hall 2 2023    4.0   4.0
# 11     Garrett Wilson 2 2023    4.0   4.0
# 10       Dak Prescott 2 2023    4.0   4.0
# 49      Jake Ferguson 2 2023    3.0   3.0
# 48      Tyler Conklin 2 2023    3.0   3.0
# 15        Dalvin Cook 2 2023    3.0   3.0
# 26        Zach Wilson 2 2023    3.0   3.0
# 31     Michael Gallup 2 2023    3.0   3.0
# 33       Allen Lazard 2 2023    3.0   3.0
# 34        Rico Dowdle 2 2023    2.0   2.0
# 71    KaVontae Turpin 2 2023    2.0   2.0
# 60        C.J. Uzomah 2 2023    1.0   1.0
# 39     Michael Carter 2 2023    1.0   1.0
# 52       Randall Cobb 2 2023    1.0   1.0
# 65  Peyton Hendershot 2 2023    1.0   1.0

# %%
team_ratios = [
               '4:1','4:1','4:1','4:1',#'4:1',#'4:1','4:1',
    
                '3:2','3:2','3:2','3:2'#,'3:2',#'3:2','3:2'
    
              # '2:3','2:3','2:3',#'2:3'#,#'2:3',#'2:3'#,
    
              # '1:4','1:4','1:4'#,'1:4'#,'1:4'
    
               
              ]
counts = [
    
    20,15,20,15,
    20,15,25,15
    
         ]
   
mvps = [
    '93784-63759:Tony Pollard',
    '93784-86631:CeeDee Lamb',
    '93784-31716:Dak Prescott',
    '93784-12530:Dallas Cowboys',
    
    '93784-63759:Tony Pollard',
    '93784-86631:CeeDee Lamb',
    '93784-31716:Dak Prescott',
    '93784-12530:Dallas Cowboys'
    
       ]


test_df = create_mvp_lineups(test_df = test2,
                       df_final = df_final,
                       team_ratios = team_ratios,
                      counts = counts,
                      mvps = mvps)
# Out:
# 4:1
# 146
# 4:1
# 146
# 4:1
# 146
# 4:1
# 146
# 3:2
# 404
# 3:2
# 404
# 3:2
# 404
# 3:2
# 404

# %%
test_df.head(50)
# Out:
#                           0                            1  \
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard  93784-103564:Garrett Wilson
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard     93784-103064:Breece Hall
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard    93784-12544:New York Jets
# 0  93784-63759:Tony Pollard    93784-12544:New York Jets
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard      93784-86631:CeeDee Lamb
# 0  93784-63759:Tony Pollard  93784-103564:Garrett Wilson
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0  93784-63759:Tony Pollard      93784-54140:Dalvin Cook
# 0  93784-63759:Tony Pollard     93784-103064:Breece Hall
# 0  93784-63759:Tony Pollard     93784-103064:Breece Hall
# 0  93784-63759:Tony Pollard  93784-103564:Garrett Wilson
# 0  93784-63759:Tony Pollard   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb     93784-103064:Breece Hall
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb     93784-103064:Breece Hall
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb     93784-63759:Tony Pollard
# 0   93784-86631:CeeDee Lamb   93784-12530:Dallas Cowboys
# 0   93784-86631:CeeDee Lamb      93784-54140:Dalvin Cook
# 0   93784-86631:CeeDee Lamb     93784-103064:Breece Hall
# 0   93784-86631:CeeDee Lamb     93784-103064:Breece Hall
# 0   93784-86631:CeeDee Lamb  93784-103564:Garrett Wilson
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott    93784-12544:New York Jets
# 0  93784-31716:Dak Prescott    93784-12544:New York Jets
# 0  93784-31716:Dak Prescott     93784-103064:Breece Hall
# 0  93784-31716:Dak Prescott  93784-103564:Garrett Wilson
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott   93784-12530:Dallas Cowboys
# 0  93784-31716:Dak Prescott  93784-103564:Garrett Wilson
# 0  93784-31716:Dak Prescott     93784-103064:Breece Hall
# 0  93784-31716:Dak Prescott     93784-103064:Breece Hall
#
#                              2                            3  \
# 0    93784-12544:New York Jets      93784-86631:CeeDee Lamb
# 0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 0     93784-56809:Allen Lazard      93784-86631:CeeDee Lamb
# 0   93784-12530:Dallas Cowboys   93784-69956:Michael Gallup
# 0     93784-31716:Dak Prescott    93784-60451:Tyler Conklin
# 0      93784-86631:CeeDee Lamb    93784-89680:Jake Ferguson
# 0    93784-12544:New York Jets   93784-69956:Michael Gallup
# 0     93784-31716:Dak Prescott     93784-56809:Allen Lazard
# 0     93784-31716:Dak Prescott    93784-89680:Jake Ferguson
# 0     93784-31716:Dak Prescott   93784-69956:Michael Gallup
# 0      93784-54140:Dalvin Cook      93784-86631:CeeDee Lamb
# 0      93784-54140:Dalvin Cook   93784-69956:Michael Gallup
# 0    93784-89680:Jake Ferguson      93784-90406:Zach Wilson
# 0   93784-12530:Dallas Cowboys      93784-72297:Rico Dowdle
# 0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 0      93784-86631:CeeDee Lamb    93784-89680:Jake Ferguson
# 0   93784-12530:Dallas Cowboys  93784-60957:KaVontae Turpin
# 0  93784-60957:KaVontae Turpin      93784-86631:CeeDee Lamb
# 0  93784-60957:KaVontae Turpin      93784-86631:CeeDee Lamb
# 0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 0    93784-12544:New York Jets     93784-63759:Tony Pollard
# 0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 0     93784-56809:Allen Lazard     93784-63759:Tony Pollard
# 0     93784-63759:Tony Pollard    93784-89680:Jake Ferguson
# 0     93784-31716:Dak Prescott      93784-54140:Dalvin Cook
# 0    93784-12544:New York Jets     93784-63759:Tony Pollard
# 0     93784-31716:Dak Prescott    93784-89680:Jake Ferguson
# 0      93784-54140:Dalvin Cook     93784-63759:Tony Pollard
# 0      93784-54140:Dalvin Cook     93784-63759:Tony Pollard
# 0    93784-89680:Jake Ferguson      93784-90406:Zach Wilson
# 0    93784-12544:New York Jets     93784-31716:Dak Prescott
# 0     93784-63759:Tony Pollard    93784-89680:Jake Ferguson
# 0   93784-12530:Dallas Cowboys  93784-60957:KaVontae Turpin
# 0  93784-60957:KaVontae Turpin     93784-63759:Tony Pollard
# 0  93784-60957:KaVontae Turpin     93784-63759:Tony Pollard
# 0    93784-12544:New York Jets     93784-63759:Tony Pollard
# 0    93784-12544:New York Jets      93784-86631:CeeDee Lamb
# 0    93784-60451:Tyler Conklin     93784-63759:Tony Pollard
# 0      93784-54140:Dalvin Cook      93784-86631:CeeDee Lamb
# 0     93784-56809:Allen Lazard     93784-63759:Tony Pollard
# 0     93784-63759:Tony Pollard    93784-89680:Jake Ferguson
# 0     93784-63759:Tony Pollard   93784-69956:Michael Gallup
# 0      93784-86631:CeeDee Lamb    93784-89680:Jake Ferguson
# 0   93784-12530:Dallas Cowboys   93784-69956:Michael Gallup
# 0    93784-12544:New York Jets     93784-63759:Tony Pollard
# 0    93784-12544:New York Jets   93784-69956:Michael Gallup
# 0    93784-12544:New York Jets     93784-63759:Tony Pollard
# 0   93784-12530:Dallas Cowboys  93784-60957:KaVontae Turpin
# 0  93784-60957:KaVontae Turpin     93784-63759:Tony Pollard
# 0   93784-12530:Dallas Cowboys  93784-60957:KaVontae Turpin
#
#                             4
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0     93784-86631:CeeDee Lamb
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0   93784-89680:Jake Ferguson
# 0     93784-86631:CeeDee Lamb
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0   93784-89680:Jake Ferguson
# 0              Brandon Aubrey
# 0     93784-86631:CeeDee Lamb
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0  93784-69956:Michael Gallup
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0  93784-69956:Michael Gallup
# 0              Brandon Aubrey
# 0   93784-89680:Jake Ferguson
# 0  93784-69956:Michael Gallup
# 0              Brandon Aubrey
# 0  93784-69956:Michael Gallup
# 0              Brandon Aubrey
# 0    93784-63759:Tony Pollard
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0              Brandon Aubrey
# 0   93784-89680:Jake Ferguson
# 0     93784-86631:CeeDee Lamb
# 0  93784-69956:Michael Gallup
# 0     93784-86631:CeeDee Lamb
# 0              Brandon Aubrey
# 0     93784-86631:CeeDee Lamb

# %%
#test_df.to_csv('backtest_wk9_thu_phi_hou_predicted_lineups.csv')
#test_df.to_csv('2023_wk2_thu_phi_min_predicted_lineups.csv')

# %%
# if (len(test_df) < 150):
#     n = len(test_df)
# else:
#     n = len(test_df)
# test_df.head(n).to_csv('week11_gb_ten_test.csv')
